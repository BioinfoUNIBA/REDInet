# %%
##################
### Author: Adriano Fonzino. email: adriano.fonzino@uniba.it
##################
import os
import pandas as pd
import numpy as np


# define util function for downstream analysis
def join_bonafides(bonafide_fp, bonafide_anno_filt):
    ### function to join bonafide with reditools info with bonafide with anno and filtered 
    ### NON-REP only Refseq
    # load bonafide with reditools alignment profiles/data
    bonafide = pd.read_table(bonafide_fp)
    print("Bonafide not-filted with REDItools info:")
    display(bonafide)
    # load annotated table filtered for positives NON-REP being in Refseq
    bonafide_anno_filt = pd.read_table(bonafide_anno_filt_fp)
    print("Bonafide annotated and filtered (NON-REP only Refseq):")
    display(bonafide_anno_filt)
    # inner join between bonafide with and without annotation/filtering
    joined = pd.merge(bonafide, bonafide_anno_filt, 
                      left_on=["wt_Region", "wt_Position"],
                      right_on=["Region", "Position"], how="inner")
    print("Common sites annotated with REDItools info:")
    display(joined)
    # print not common site (not Refseq)
    left_join = pd.merge(bonafide, bonafide_anno_filt, 
                        left_on=["wt_Region", "wt_Position"],
                        right_on=["Region", "Position"], how="left")
    print("Discared sites (via left join):")
    display(left_join[left_join["Class_y"].isna()])
    output_file = bonafide_fp + ".anno.filt_refseq.tsv"
    print("Save on disk joined with annotation and filtering to :", output_file)
    joined.to_csv(output_file, index=None, sep="\t")

    return joined

# %% [markdown]
# ## A549

# %%
### Couple 1
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/a549/SRR12492043.SRR12492044.control.outTable_773331943.gz_vs_SRR12492025.SRR12492026.siADARs.outTable_302610513.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/a549/outTable_773331943_outTable_302610513_bona_fide_sites_2.tsv"

couple1_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216177            A          1              193
# 1         chrX       216207            A          1              188
# 2         chrX       216235            A          1              188
# 3         chrX       216241            A          1              198
# 4         chrX       216248            A          1              213
# ...        ...          ...          ...        ...              ...
# 8828      chr8    145066886            A          1             2337
# 8829      chr8    145665516            A          0               71
# 8830      chr8    145677011            A          0              126
# 8831      chr8    145693720            A          1              160
# 8832      chr8    145742879            A          0               99
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        51.64        [189, 0, 4, 0]         AG          0.02      chrX  ...
# 1        52.04        [184, 0, 4, 0]         AG          0.02      chrX  ...
# 2        51.60        [185, 0, 3, 0]         AG          0.02      chrX  ...
# 3        52.23        [190, 0, 8, 0]         AG          0.04      chrX  ...
# 4        51.35        [204, 0, 9, 0]         AG          0.04      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 8828     51.77       [0, 0, 2337, 0]         AG          1.00      chr8  ...
# 8829     47.69         [1, 0, 70, 0]         AG          0.99      chr8  ...
# 8830     47.74        [0, 0, 126, 0]         AG          1.00      chr8  ...
# 8831     54.27        [0, 0, 160, 0]         AG          1.00      chr8  ...
# 8832     45.47        [60, 0, 39, 0]         AG          0.39      chr8  ...
#
#       gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs gFrequency  \
# 0           1            47   36.77        [47, 0, 0, 0]         -       0.00
# 1           1            45   36.64        [45, 0, 0, 0]         -       0.00
# 2           1            31   37.39        [31, 0, 0, 0]         -       0.00
# 3           1            35   37.29        [35, 0, 0, 0]         -       0.00
# 4           1            41   36.59        [41, 0, 0, 0]         -       0.00
# ...       ...           ...     ...                  ...       ...        ...
# 8828        1           106   36.79       [0, 0, 106, 0]        AG       1.00
# 8829        0           116   36.78       [0, 0, 116, 0]        AG       1.00
# 8830        0            98   36.48        [0, 0, 98, 0]        AG       1.00
# 8831        1           133   35.52       [0, 0, 133, 0]        AG       1.00
# 8832        0            51   35.49       [29, 0, 22, 0]        AG       0.43
#
#             Class  Class_binary  \
# 0         Editing             1
# 1         Editing             1
# 2         Editing             1
# 3         Editing             1
# 4         Editing             1
# ...           ...           ...
# 8828  Not-Editing             0
# 8829  Not-Editing             0
# 8830  Not-Editing             0
# 8831  Not-Editing             0
# 8832  Not-Editing             0
#
#                                               wt_sample  \
# 0     SRR12492043.SRR12492044.control.outTable_77333...
# 1     SRR12492043.SRR12492044.control.outTable_77333...
# 2     SRR12492043.SRR12492044.control.outTable_77333...
# 3     SRR12492043.SRR12492044.control.outTable_77333...
# 4     SRR12492043.SRR12492044.control.outTable_77333...
# ...                                                 ...
# 8828  SRR12492043.SRR12492044.control.outTable_77333...
# 8829  SRR12492043.SRR12492044.control.outTable_77333...
# 8830  SRR12492043.SRR12492044.control.outTable_77333...
# 8831  SRR12492043.SRR12492044.control.outTable_77333...
# 8832  SRR12492043.SRR12492044.control.outTable_77333...
#
#                                               ko_sample
# 0     SRR12492025.SRR12492026.siADARs.outTable_30261...
# 1     SRR12492025.SRR12492026.siADARs.outTable_30261...
# 2     SRR12492025.SRR12492026.siADARs.outTable_30261...
# 3     SRR12492025.SRR12492026.siADARs.outTable_30261...
# 4     SRR12492025.SRR12492026.siADARs.outTable_30261...
# ...                                                 ...
# 8828  SRR12492025.SRR12492026.siADARs.outTable_30261...
# 8829  SRR12492025.SRR12492026.siADARs.outTable_30261...
# 8830  SRR12492025.SRR12492026.siADARs.outTable_30261...
# 8831  SRR12492025.SRR12492026.siADARs.outTable_30261...
# 8832  SRR12492025.SRR12492026.siADARs.outTable_30261...
#
# [8833 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#      Region   Position  Class RMSK-Rep RMSK-Reg  \
# 0      chr1     879875      1        -        -
# 1      chr1     888639      0        -        -
# 2      chr1     888659      0        -        -
# 3      chr1     949654      0        -        -
# 4      chr1     979632      1        -        -
# ...     ...        ...    ...      ...      ...
# 8815   chrX  154349801      1     LINE    L1MD2
# 8816   chrX  154456747      0        -        -
# 8817   chrX  155252736      0        -        -
# 8818   chrX  155252758      0        -        -
# 8819   chrX  155253889      0        -        -
#
#                                      RefSeq-Rep    RefSeq-Reg
# 0     transcript,exon,3UTR&3UTR,exon,transcript  SAMD11&NOC2L
# 1                           transcript,CDS,exon         NOC2L
# 2                           transcript,CDS,exon         NOC2L
# 3                           transcript,CDS,exon         ISG15
# 4                           transcript,CDS,exon          AGRN
# ...                                         ...           ...
# 8815                       transcript,3UTR,exon         BRCC3
# 8816                        transcript,CDS,exon          VBP1
# 8817                            exon,transcript        WASH6P
# 8818                            exon,transcript        WASH6P
# 8819                            exon,transcript        WASH6P
#
# [8820 rows x 7 columns]
# Common sites annotated with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216241            A          1              198
# 1         chrX       216248            A          1              213
# 2         chrX       216249            A          1              211
# 3         chrX       216254            A          1              252
# 4         chrX       216260            A          1              264
# ...        ...          ...          ...        ...              ...
# 8815      chr8    145066886            A          1             2337
# 8816      chr8    145665516            A          0               71
# 8817      chr8    145677011            A          0              126
# 8818      chr8    145693720            A          1              160
# 8819      chr8    145742879            A          0               99
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        52.23        [190, 0, 8, 0]         AG          0.04      chrX  ...
# 1        51.35        [204, 0, 9, 0]         AG          0.04      chrX  ...
# 2        51.49        [208, 0, 3, 0]         AG          0.01      chrX  ...
# 3        49.59        [244, 0, 8, 0]         AG          0.03      chrX  ...
# 4        50.41       [245, 0, 19, 0]         AG          0.07      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 8815     51.77       [0, 0, 2337, 0]         AG          1.00      chr8  ...
# 8816     47.69         [1, 0, 70, 0]         AG          0.99      chr8  ...
# 8817     47.74        [0, 0, 126, 0]         AG          1.00      chr8  ...
# 8818     54.27        [0, 0, 160, 0]         AG          1.00      chr8  ...
# 8819     45.47        [60, 0, 39, 0]         AG          0.39      chr8  ...
#
#       Class_binary                                          wt_sample  \
# 0                1  SRR12492043.SRR12492044.control.outTable_77333...
# 1                1  SRR12492043.SRR12492044.control.outTable_77333...
# 2                1  SRR12492043.SRR12492044.control.outTable_77333...
# 3                1  SRR12492043.SRR12492044.control.outTable_77333...
# 4                1  SRR12492043.SRR12492044.control.outTable_77333...
# ...            ...                                                ...
# 8815             0  SRR12492043.SRR12492044.control.outTable_77333...
# 8816             0  SRR12492043.SRR12492044.control.outTable_77333...
# 8817             0  SRR12492043.SRR12492044.control.outTable_77333...
# 8818             0  SRR12492043.SRR12492044.control.outTable_77333...
# 8819             0  SRR12492043.SRR12492044.control.outTable_77333...
#
#                                               ko_sample  Region   Position  \
# 0     SRR12492025.SRR12492026.siADARs.outTable_30261...    chrX     216241
# 1     SRR12492025.SRR12492026.siADARs.outTable_30261...    chrX     216248
# 2     SRR12492025.SRR12492026.siADARs.outTable_30261...    chrX     216249
# 3     SRR12492025.SRR12492026.siADARs.outTable_30261...    chrX     216254
# 4     SRR12492025.SRR12492026.siADARs.outTable_30261...    chrX     216260
# ...                                                 ...     ...        ...
# 8815  SRR12492025.SRR12492026.siADARs.outTable_30261...    chr8  145066886
# 8816  SRR12492025.SRR12492026.siADARs.outTable_30261...    chr8  145665516
# 8817  SRR12492025.SRR12492026.siADARs.outTable_30261...    chr8  145677011
# 8818  SRR12492025.SRR12492026.siADARs.outTable_30261...    chr8  145693720
# 8819  SRR12492025.SRR12492026.siADARs.outTable_30261...    chr8  145742879
#
#      Class_y RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 1          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 2          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 3          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 4          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# ...      ...      ...       ...                   ...         ...
# 8815       0        -         -   transcript,CDS,exon       GRINA
# 8816       0        -         -   transcript,CDS,exon       TONSL
# 8817       0        -         -            transcript       CYHR1
# 8818       0        -         -   transcript,CDS,exon       KIFC2
# 8819       0        -         -   transcript,CDS,exon      RECQL4
#
# [8820 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216177            A          1              193
# 1         chrX       216207            A          1              188
# 2         chrX       216235            A          1              188
# 1177     chr10     33176866            A          0               89
# 1255     chr10     75537313            A          1               76
# 1822     chr17     66043302            A          1               78
# 2820     chr19     18668650            A          1              106
# 3036     chr19     49588692            A          1               55
# 3461      chr1     16126655            A          0              146
# 3705      chr1    145117054            A          1              165
# 6221      chr8     25367534            A          1               67
# 6353      chr8    145512840            A          0              567
# 6369      chrY     21152719            A          0             2348
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        51.64        [189, 0, 4, 0]         AG          0.02      chrX  ...
# 1        52.04        [184, 0, 4, 0]         AG          0.02      chrX  ...
# 2        51.60        [185, 0, 3, 0]         AG          0.02      chrX  ...
# 1177     49.30         [86, 0, 3, 0]         AG          0.03     chr10  ...
# 1255     56.67         [69, 0, 7, 0]         AG          0.09     chr10  ...
# 1822     52.21         [75, 0, 3, 0]         AG          0.04     chr17  ...
# 2820     60.35        [103, 0, 3, 0]         AG          0.03     chr19  ...
# 3036     46.69         [52, 0, 3, 0]         AG          0.05     chr19  ...
# 3461     56.97        [143, 0, 3, 0]         AG          0.02      chr1  ...
# 3705     52.72        [162, 0, 3, 0]         AG          0.02      chr1  ...
# 6221     50.46         [64, 0, 3, 0]         AG          0.04      chr8  ...
# 6353     56.01        [564, 0, 3, 0]         AG          0.01      chr8  ...
# 6369     54.76       [1, 0, 2347, 0]         AG          1.00      chrY  ...
#
#       Class_binary                                          wt_sample  \
# 0                1  SRR12492043.SRR12492044.control.outTable_77333...
# 1                1  SRR12492043.SRR12492044.control.outTable_77333...
# 2                1  SRR12492043.SRR12492044.control.outTable_77333...
# 1177             1  SRR12492043.SRR12492044.control.outTable_77333...
# 1255             1  SRR12492043.SRR12492044.control.outTable_77333...
# 1822             1  SRR12492043.SRR12492044.control.outTable_77333...
# 2820             1  SRR12492043.SRR12492044.control.outTable_77333...
# 3036             1  SRR12492043.SRR12492044.control.outTable_77333...
# 3461             1  SRR12492043.SRR12492044.control.outTable_77333...
# 3705             1  SRR12492043.SRR12492044.control.outTable_77333...
# 6221             1  SRR12492043.SRR12492044.control.outTable_77333...
# 6353             1  SRR12492043.SRR12492044.control.outTable_77333...
# 6369             0  SRR12492043.SRR12492044.control.outTable_77333...
#
#                                               ko_sample  Region  Position  \
# 0     SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 1     SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 2     SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 1177  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 1255  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 1822  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 2820  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 3036  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 3461  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 3705  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 6221  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 6353  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
# 6369  SRR12492025.SRR12492026.siADARs.outTable_30261...     NaN       NaN
#
#      Class_y RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 0        NaN      NaN       NaN        NaN         NaN
# 1        NaN      NaN       NaN        NaN         NaN
# 2        NaN      NaN       NaN        NaN         NaN
# 1177     NaN      NaN       NaN        NaN         NaN
# 1255     NaN      NaN       NaN        NaN         NaN
# 1822     NaN      NaN       NaN        NaN         NaN
# 2820     NaN      NaN       NaN        NaN         NaN
# 3036     NaN      NaN       NaN        NaN         NaN
# 3461     NaN      NaN       NaN        NaN         NaN
# 3705     NaN      NaN       NaN        NaN         NaN
# 6221     NaN      NaN       NaN        NaN         NaN
# 6353     NaN      NaN       NaN        NaN         NaN
# 6369     NaN      NaN       NaN        NaN         NaN
#
# [13 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/a549/SRR12492043.SRR12492044.control.outTable_773331943.gz_vs_SRR12492025.SRR12492026.siADARs.outTable_302610513.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 2
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/a549/SRR12492045.SRR12492046.control.outTable_535670354.gz_vs_SRR12492027.SRR12492028.siADARs.outTable_396704193.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/a549/outTable_535670354_outTable_396704193_bona_fide_sites_2.tsv"

couple2_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216177            A          1              194
# 1         chrX       216226            A          1              232
# 2         chrX       216238            A          1              231
# 3         chrX       216239            A          1              237
# 4         chrX       216241            A          1              229
# ...        ...          ...          ...        ...              ...
# 9333      chr8    145150832            A          1             2357
# 9334      chr8    145665516            A          0               96
# 9335      chr8    145677011            A          0              149
# 9336      chr8    145693720            A          1              157
# 9337      chr8    145742879            A          0              108
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        51.60        [188, 0, 6, 0]         AG          0.03      chrX  ...
# 1        51.86        [225, 0, 7, 0]         AG          0.03      chrX  ...
# 2        52.09        [228, 0, 3, 0]         AG          0.01      chrX  ...
# 3        51.42        [228, 0, 9, 0]         AG          0.04      chrX  ...
# 4        51.96        [221, 0, 8, 0]         AG          0.03      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 9333     49.45       [1, 0, 2356, 0]         AG          1.00      chr8  ...
# 9334     47.65         [3, 0, 93, 0]         AG          0.97      chr8  ...
# 9335     48.46        [0, 0, 149, 0]         AG          1.00      chr8  ...
# 9336     57.26        [0, 0, 157, 0]         AG          1.00      chr8  ...
# 9337     47.81        [58, 0, 50, 0]         AG          0.46      chr8  ...
#
#       gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs gFrequency  \
# 0           1            47   36.77        [47, 0, 0, 0]         -       0.00
# 1           1            41   36.37        [41, 0, 0, 0]         -       0.00
# 2           1            32   38.22        [32, 0, 0, 0]         -       0.00
# 3           1            31   37.87        [31, 0, 0, 0]         -       0.00
# 4           1            35   37.29        [35, 0, 0, 0]         -       0.00
# ...       ...           ...     ...                  ...       ...        ...
# 9333        1           101   34.99       [0, 0, 101, 0]        AG       1.00
# 9334        0           116   36.78       [0, 0, 116, 0]        AG       1.00
# 9335        0            98   36.48        [0, 0, 98, 0]        AG       1.00
# 9336        1           133   35.52       [0, 0, 133, 0]        AG       1.00
# 9337        0            51   35.49       [29, 0, 22, 0]        AG       0.43
#
#             Class  Class_binary  \
# 0         Editing             1
# 1         Editing             1
# 2         Editing             1
# 3         Editing             1
# 4         Editing             1
# ...           ...           ...
# 9333  Not-Editing             0
# 9334  Not-Editing             0
# 9335  Not-Editing             0
# 9336  Not-Editing             0
# 9337  Not-Editing             0
#
#                                               wt_sample  \
# 0     SRR12492045.SRR12492046.control.outTable_53567...
# 1     SRR12492045.SRR12492046.control.outTable_53567...
# 2     SRR12492045.SRR12492046.control.outTable_53567...
# 3     SRR12492045.SRR12492046.control.outTable_53567...
# 4     SRR12492045.SRR12492046.control.outTable_53567...
# ...                                                 ...
# 9333  SRR12492045.SRR12492046.control.outTable_53567...
# 9334  SRR12492045.SRR12492046.control.outTable_53567...
# 9335  SRR12492045.SRR12492046.control.outTable_53567...
# 9336  SRR12492045.SRR12492046.control.outTable_53567...
# 9337  SRR12492045.SRR12492046.control.outTable_53567...
#
#                                               ko_sample
# 0     SRR12492027.SRR12492028.siADARs.outTable_39670...
# 1     SRR12492027.SRR12492028.siADARs.outTable_39670...
# 2     SRR12492027.SRR12492028.siADARs.outTable_39670...
# 3     SRR12492027.SRR12492028.siADARs.outTable_39670...
# 4     SRR12492027.SRR12492028.siADARs.outTable_39670...
# ...                                                 ...
# 9333  SRR12492027.SRR12492028.siADARs.outTable_39670...
# 9334  SRR12492027.SRR12492028.siADARs.outTable_39670...
# 9335  SRR12492027.SRR12492028.siADARs.outTable_39670...
# 9336  SRR12492027.SRR12492028.siADARs.outTable_39670...
# 9337  SRR12492027.SRR12492028.siADARs.outTable_39670...
#
# [9338 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#      Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0      chr1     888639      0        -        -   transcript,CDS,exon
# 1      chr1     888659      0        -        -   transcript,CDS,exon
# 2      chr1     981931      0        -        -   transcript,CDS,exon
# 3      chr1     981995      1        -        -   transcript,CDS,exon
# 4      chr1    1018144      0        -        -  3UTR,exon,transcript
# ...     ...        ...    ...      ...      ...                   ...
# 9318   chrX  154456747      0        -        -   transcript,CDS,exon
# 9319   chrX  155171995      1        -        -  transcript,exon,3UTR
# 9320   chrX  155252736      0        -        -       exon,transcript
# 9321   chrX  155252758      0        -        -       exon,transcript
# 9322   chrX  155253889      0        -        -       exon,transcript
#
#      RefSeq-Reg
# 0         NOC2L
# 1         NOC2L
# 2          AGRN
# 3          AGRN
# 4      C1orf159
# ...         ...
# 9318       VBP1
# 9319      VAMP7
# 9320     WASH6P
# 9321     WASH6P
# 9322     WASH6P
#
# [9323 rows x 7 columns]
# Common sites annotated with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216239            A          1              237
# 1         chrX       216241            A          1              229
# 2         chrX       216247            A          1              248
# 3         chrX       216249            A          1              245
# 4         chrX       216254            A          1              273
# ...        ...          ...          ...        ...              ...
# 9318      chr8    145150832            A          1             2357
# 9319      chr8    145665516            A          0               96
# 9320      chr8    145677011            A          0              149
# 9321      chr8    145693720            A          1              157
# 9322      chr8    145742879            A          0              108
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        51.42        [228, 0, 9, 0]         AG          0.04      chrX  ...
# 1        51.96        [221, 0, 8, 0]         AG          0.03      chrX  ...
# 2        50.85       [233, 0, 15, 0]         AG          0.06      chrX  ...
# 3        50.73        [240, 0, 5, 0]         AG          0.02      chrX  ...
# 4        49.57        [266, 0, 7, 0]         AG          0.03      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 9318     49.45       [1, 0, 2356, 0]         AG          1.00      chr8  ...
# 9319     47.65         [3, 0, 93, 0]         AG          0.97      chr8  ...
# 9320     48.46        [0, 0, 149, 0]         AG          1.00      chr8  ...
# 9321     57.26        [0, 0, 157, 0]         AG          1.00      chr8  ...
# 9322     47.81        [58, 0, 50, 0]         AG          0.46      chr8  ...
#
#       Class_binary                                          wt_sample  \
# 0                1  SRR12492045.SRR12492046.control.outTable_53567...
# 1                1  SRR12492045.SRR12492046.control.outTable_53567...
# 2                1  SRR12492045.SRR12492046.control.outTable_53567...
# 3                1  SRR12492045.SRR12492046.control.outTable_53567...
# 4                1  SRR12492045.SRR12492046.control.outTable_53567...
# ...            ...                                                ...
# 9318             0  SRR12492045.SRR12492046.control.outTable_53567...
# 9319             0  SRR12492045.SRR12492046.control.outTable_53567...
# 9320             0  SRR12492045.SRR12492046.control.outTable_53567...
# 9321             0  SRR12492045.SRR12492046.control.outTable_53567...
# 9322             0  SRR12492045.SRR12492046.control.outTable_53567...
#
#                                               ko_sample  Region   Position  \
# 0     SRR12492027.SRR12492028.siADARs.outTable_39670...    chrX     216239
# 1     SRR12492027.SRR12492028.siADARs.outTable_39670...    chrX     216241
# 2     SRR12492027.SRR12492028.siADARs.outTable_39670...    chrX     216247
# 3     SRR12492027.SRR12492028.siADARs.outTable_39670...    chrX     216249
# 4     SRR12492027.SRR12492028.siADARs.outTable_39670...    chrX     216254
# ...                                                 ...     ...        ...
# 9318  SRR12492027.SRR12492028.siADARs.outTable_39670...    chr8  145150832
# 9319  SRR12492027.SRR12492028.siADARs.outTable_39670...    chr8  145665516
# 9320  SRR12492027.SRR12492028.siADARs.outTable_39670...    chr8  145677011
# 9321  SRR12492027.SRR12492028.siADARs.outTable_39670...    chr8  145693720
# 9322  SRR12492027.SRR12492028.siADARs.outTable_39670...    chr8  145742879
#
#      Class_y RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 1          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 2          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 3          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 4          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# ...      ...      ...       ...                   ...         ...
# 9318       0        -         -   transcript,CDS,exon        CYC1
# 9319       0        -         -   transcript,CDS,exon       TONSL
# 9320       0        -         -            transcript       CYHR1
# 9321       0        -         -   transcript,CDS,exon       KIFC2
# 9322       0        -         -   transcript,CDS,exon      RECQL4
#
# [9323 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216177            A          1              194
# 1         chrX       216226            A          1              232
# 2         chrX       216238            A          1              231
# 1045     chr11     61566244            A          0              110
# 1290     chr10     75537313            A          1               72
# 1297     chr10     75538589            A          1               57
# 1508     chr17      6544347            A          1              147
# 1895     chr17     61920198            A          0               86
# 3221     chr19     48972610            A          1              148
# 3266     chr19     56165648            A          1              504
# 3436      chr1     16126655            A          0              141
# 3659      chr1    145115778            A          1              511
# 5087      chr5     79783626            A          0               70
# 6328     chr21      9832938            A          1              117
# 6840      chrY     21152719            A          0             2539
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        51.60        [188, 0, 6, 0]         AG          0.03      chrX  ...
# 1        51.86        [225, 0, 7, 0]         AG          0.03      chrX  ...
# 2        52.09        [228, 0, 3, 0]         AG          0.01      chrX  ...
# 1045     51.11        [107, 0, 3, 0]         AG          0.03     chr11  ...
# 1290     50.79         [69, 0, 3, 0]         AG          0.04     chr10  ...
# 1297     57.33         [53, 0, 4, 0]         AG          0.07     chr10  ...
# 1508     48.06        [144, 0, 3, 0]         AG          0.02     chr17  ...
# 1895     52.64         [83, 0, 3, 0]         AG          0.03     chr17  ...
# 3221     48.66        [145, 0, 3, 0]         AG          0.02     chr19  ...
# 3266     57.19        [501, 0, 3, 0]         AG          0.01     chr19  ...
# 3436     54.56        [138, 0, 3, 0]         AG          0.02      chr1  ...
# 3659     49.76        [508, 0, 3, 0]         AG          0.01      chr1  ...
# 5087     58.06         [67, 0, 3, 0]         AG          0.04      chr5  ...
# 6328     52.56        [114, 0, 3, 0]         AG          0.03     chr21  ...
# 6840     54.76       [3, 0, 2536, 0]         AG          1.00      chrY  ...
#
#       Class_binary                                          wt_sample  \
# 0                1  SRR12492045.SRR12492046.control.outTable_53567...
# 1                1  SRR12492045.SRR12492046.control.outTable_53567...
# 2                1  SRR12492045.SRR12492046.control.outTable_53567...
# 1045             1  SRR12492045.SRR12492046.control.outTable_53567...
# 1290             1  SRR12492045.SRR12492046.control.outTable_53567...
# 1297             1  SRR12492045.SRR12492046.control.outTable_53567...
# 1508             1  SRR12492045.SRR12492046.control.outTable_53567...
# 1895             1  SRR12492045.SRR12492046.control.outTable_53567...
# 3221             1  SRR12492045.SRR12492046.control.outTable_53567...
# 3266             1  SRR12492045.SRR12492046.control.outTable_53567...
# 3436             1  SRR12492045.SRR12492046.control.outTable_53567...
# 3659             1  SRR12492045.SRR12492046.control.outTable_53567...
# 5087             1  SRR12492045.SRR12492046.control.outTable_53567...
# 6328             1  SRR12492045.SRR12492046.control.outTable_53567...
# 6840             0  SRR12492045.SRR12492046.control.outTable_53567...
#
#                                               ko_sample  Region  Position  \
# 0     SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 1     SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 2     SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 1045  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 1290  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 1297  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 1508  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 1895  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 3221  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 3266  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 3436  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 3659  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 5087  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 6328  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
# 6840  SRR12492027.SRR12492028.siADARs.outTable_39670...     NaN       NaN
#
#      Class_y RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 0        NaN      NaN       NaN        NaN         NaN
# 1        NaN      NaN       NaN        NaN         NaN
# 2        NaN      NaN       NaN        NaN         NaN
# 1045     NaN      NaN       NaN        NaN         NaN
# 1290     NaN      NaN       NaN        NaN         NaN
# 1297     NaN      NaN       NaN        NaN         NaN
# 1508     NaN      NaN       NaN        NaN         NaN
# 1895     NaN      NaN       NaN        NaN         NaN
# 3221     NaN      NaN       NaN        NaN         NaN
# 3266     NaN      NaN       NaN        NaN         NaN
# 3436     NaN      NaN       NaN        NaN         NaN
# 3659     NaN      NaN       NaN        NaN         NaN
# 5087     NaN      NaN       NaN        NaN         NaN
# 6328     NaN      NaN       NaN        NaN         NaN
# 6840     NaN      NaN       NaN        NaN         NaN
#
# [15 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/a549/SRR12492045.SRR12492046.control.outTable_535670354.gz_vs_SRR12492027.SRR12492028.siADARs.outTable_396704193.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 3
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/a549/SRR12492047.SRR12492048.control.outTable_192318299.gz_vs_SRR12492029.SRR12492030.siADARs.outTable_436061877.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/a549/outTable_192318299_outTable_436061877_bona_fide_sites_2.tsv"

couple3_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216254            A          1              273
# 1         chrX       216269            A          1              313
# 2         chrX       216272            A          1              332
# 3         chrX       216273            A          1              331
# 4         chrX       216309            A          1              425
# ...        ...          ...          ...        ...              ...
# 8830      chr8    144992361            A          0             1099
# 8831      chr8    145001031            A          0              926
# 8832      chr8    145677011            A          0              182
# 8833      chr8    145693720            A          1              157
# 8834      chr8    145742879            A          0              147
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        48.92       [261, 0, 12, 0]         AG          0.04      chrX  ...
# 1        50.32        [304, 0, 9, 0]         AG          0.03      chrX  ...
# 2        49.94       [312, 0, 20, 0]         AG          0.06      chrX  ...
# 3        49.74       [320, 0, 11, 0]         AG          0.03      chrX  ...
# 4        54.68        [416, 0, 9, 0]         AG          0.02      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 8830     50.93      [604, 0, 495, 0]         AG          0.45      chr8  ...
# 8831     50.92      [513, 0, 413, 0]         AG          0.45      chr8  ...
# 8832     46.22        [0, 0, 182, 0]         AG          1.00      chr8  ...
# 8833     55.40        [0, 0, 157, 0]         AG          1.00      chr8  ...
# 8834     46.37        [70, 0, 77, 0]         AG          0.52      chr8  ...
#
#       gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs gFrequency  \
# 0           1            37   37.54        [37, 0, 0, 0]         -       0.00
# 1           1            35   36.34        [35, 0, 0, 0]         -       0.00
# 2           1            35   37.43        [35, 0, 0, 0]         -       0.00
# 3           1            34   37.21        [34, 0, 0, 0]         -       0.00
# 4           1            35   35.94        [35, 0, 0, 0]         -       0.00
# ...       ...           ...     ...                  ...       ...        ...
# 8830        0            79   34.58       [33, 0, 46, 0]        AG       0.58
# 8831        0            75   35.93       [43, 0, 32, 0]        AG       0.43
# 8832        0            98   36.48        [0, 0, 98, 0]        AG       1.00
# 8833        1           133   35.52       [0, 0, 133, 0]        AG       1.00
# 8834        0            51   35.49       [29, 0, 22, 0]        AG       0.43
#
#             Class  Class_binary  \
# 0         Editing             1
# 1         Editing             1
# 2         Editing             1
# 3         Editing             1
# 4         Editing             1
# ...           ...           ...
# 8830  Not-Editing             0
# 8831  Not-Editing             0
# 8832  Not-Editing             0
# 8833  Not-Editing             0
# 8834  Not-Editing             0
#
#                                               wt_sample  \
# 0     SRR12492047.SRR12492048.control.outTable_19231...
# 1     SRR12492047.SRR12492048.control.outTable_19231...
# 2     SRR12492047.SRR12492048.control.outTable_19231...
# 3     SRR12492047.SRR12492048.control.outTable_19231...
# 4     SRR12492047.SRR12492048.control.outTable_19231...
# ...                                                 ...
# 8830  SRR12492047.SRR12492048.control.outTable_19231...
# 8831  SRR12492047.SRR12492048.control.outTable_19231...
# 8832  SRR12492047.SRR12492048.control.outTable_19231...
# 8833  SRR12492047.SRR12492048.control.outTable_19231...
# 8834  SRR12492047.SRR12492048.control.outTable_19231...
#
#                                               ko_sample
# 0     SRR12492029.SRR12492030.siADARs.outTable_43606...
# 1     SRR12492029.SRR12492030.siADARs.outTable_43606...
# 2     SRR12492029.SRR12492030.siADARs.outTable_43606...
# 3     SRR12492029.SRR12492030.siADARs.outTable_43606...
# 4     SRR12492029.SRR12492030.siADARs.outTable_43606...
# ...                                                 ...
# 8830  SRR12492029.SRR12492030.siADARs.outTable_43606...
# 8831  SRR12492029.SRR12492030.siADARs.outTable_43606...
# 8832  SRR12492029.SRR12492030.siADARs.outTable_43606...
# 8833  SRR12492029.SRR12492030.siADARs.outTable_43606...
# 8834  SRR12492029.SRR12492030.siADARs.outTable_43606...
#
# [8835 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#      Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0      chr1     888639      0        -        -   transcript,CDS,exon
# 1      chr1     888659      0        -        -   transcript,CDS,exon
# 2      chr1     949654      0        -        -   transcript,CDS,exon
# 3      chr1     979099      1        -        -   transcript,CDS,exon
# 4      chr1     981931      0        -        -   transcript,CDS,exon
# ...     ...        ...    ...      ...      ...                   ...
# 8820   chrX  154283100      1        -        -  transcript,exon,3UTR
# 8821   chrX  154350220      1     SINE    AluJr  transcript,3UTR,exon
# 8822   chrX  155252736      0        -        -       exon,transcript
# 8823   chrX  155252758      0        -        -       exon,transcript
# 8824   chrX  155253889      0        -        -       exon,transcript
#
#      RefSeq-Reg
# 0         NOC2L
# 1         NOC2L
# 2         ISG15
# 3          AGRN
# 4          AGRN
# ...         ...
# 8820     FUNDC2
# 8821      BRCC3
# 8822     WASH6P
# 8823     WASH6P
# 8824     WASH6P
#
# [8825 rows x 7 columns]
# Common sites annotated with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216273            A          1              331
# 1         chrX       216309            A          1              425
# 2         chrX       216326            A          1              406
# 3         chrX       216330            A          1              419
# 4         chrX       216336            A          1              431
# ...        ...          ...          ...        ...              ...
# 8820      chr8    144992361            A          0             1099
# 8821      chr8    145001031            A          0              926
# 8822      chr8    145677011            A          0              182
# 8823      chr8    145693720            A          1              157
# 8824      chr8    145742879            A          0              147
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        49.74       [320, 0, 11, 0]         AG          0.03      chrX  ...
# 1        54.68        [416, 0, 9, 0]         AG          0.02      chrX  ...
# 2        57.01        [403, 0, 3, 0]         AG          0.01      chrX  ...
# 3        57.22       [403, 0, 16, 0]         AG          0.04      chrX  ...
# 4        56.97        [422, 0, 9, 0]         AG          0.02      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 8820     50.93      [604, 0, 495, 0]         AG          0.45      chr8  ...
# 8821     50.92      [513, 0, 413, 0]         AG          0.45      chr8  ...
# 8822     46.22        [0, 0, 182, 0]         AG          1.00      chr8  ...
# 8823     55.40        [0, 0, 157, 0]         AG          1.00      chr8  ...
# 8824     46.37        [70, 0, 77, 0]         AG          0.52      chr8  ...
#
#       Class_binary                                          wt_sample  \
# 0                1  SRR12492047.SRR12492048.control.outTable_19231...
# 1                1  SRR12492047.SRR12492048.control.outTable_19231...
# 2                1  SRR12492047.SRR12492048.control.outTable_19231...
# 3                1  SRR12492047.SRR12492048.control.outTable_19231...
# 4                1  SRR12492047.SRR12492048.control.outTable_19231...
# ...            ...                                                ...
# 8820             0  SRR12492047.SRR12492048.control.outTable_19231...
# 8821             0  SRR12492047.SRR12492048.control.outTable_19231...
# 8822             0  SRR12492047.SRR12492048.control.outTable_19231...
# 8823             0  SRR12492047.SRR12492048.control.outTable_19231...
# 8824             0  SRR12492047.SRR12492048.control.outTable_19231...
#
#                                               ko_sample  Region   Position  \
# 0     SRR12492029.SRR12492030.siADARs.outTable_43606...    chrX     216273
# 1     SRR12492029.SRR12492030.siADARs.outTable_43606...    chrX     216309
# 2     SRR12492029.SRR12492030.siADARs.outTable_43606...    chrX     216326
# 3     SRR12492029.SRR12492030.siADARs.outTable_43606...    chrX     216330
# 4     SRR12492029.SRR12492030.siADARs.outTable_43606...    chrX     216336
# ...                                                 ...     ...        ...
# 8820  SRR12492029.SRR12492030.siADARs.outTable_43606...    chr8  144992361
# 8821  SRR12492029.SRR12492030.siADARs.outTable_43606...    chr8  145001031
# 8822  SRR12492029.SRR12492030.siADARs.outTable_43606...    chr8  145677011
# 8823  SRR12492029.SRR12492030.siADARs.outTable_43606...    chr8  145693720
# 8824  SRR12492029.SRR12492030.siADARs.outTable_43606...    chr8  145742879
#
#      Class_y RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 1          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 2          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 3          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# 4          1     SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# ...      ...      ...       ...                   ...         ...
# 8820       0        -         -   exon,transcript,CDS        PLEC
# 8821       0        -         -   transcript,CDS,exon        PLEC
# 8822       0        -         -            transcript       CYHR1
# 8823       0        -         -   transcript,CDS,exon       KIFC2
# 8824       0        -         -   transcript,CDS,exon      RECQL4
#
# [8825 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       216254            A          1              273
# 1         chrX       216269            A          1              313
# 2         chrX       216272            A          1              332
# 122       chrX     40440213            A          1              138
# 1172     chr11     93917323            A          1              128
# 2281     chr15     40687855            A          1               50
# 2909     chr19     36605791            A          0              671
# 3082     chr19     50640340            A          0              311
# 5607      chr1     16126621            A          0              175
# 6634      chrY     21153609            A          0             5083
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        48.92       [261, 0, 12, 0]         AG          0.04      chrX  ...
# 1        50.32        [304, 0, 9, 0]         AG          0.03      chrX  ...
# 2        49.94       [312, 0, 20, 0]         AG          0.06      chrX  ...
# 122      42.30        [135, 0, 3, 0]         AG          0.02      chrX  ...
# 1172     51.74        [124, 0, 4, 0]         AG          0.03     chr11  ...
# 2281     48.24         [46, 0, 4, 0]         AG          0.08     chr15  ...
# 2909     49.13        [667, 0, 4, 0]         AG          0.01     chr19  ...
# 3082     49.35        [308, 0, 3, 0]         AG          0.01     chr19  ...
# 5607     57.59        [172, 0, 3, 0]         AG          0.02      chr1  ...
# 6634     54.07       [0, 0, 5083, 0]         AG          1.00      chrY  ...
#
#       Class_binary                                          wt_sample  \
# 0                1  SRR12492047.SRR12492048.control.outTable_19231...
# 1                1  SRR12492047.SRR12492048.control.outTable_19231...
# 2                1  SRR12492047.SRR12492048.control.outTable_19231...
# 122              1  SRR12492047.SRR12492048.control.outTable_19231...
# 1172             1  SRR12492047.SRR12492048.control.outTable_19231...
# 2281             1  SRR12492047.SRR12492048.control.outTable_19231...
# 2909             1  SRR12492047.SRR12492048.control.outTable_19231...
# 3082             1  SRR12492047.SRR12492048.control.outTable_19231...
# 5607             1  SRR12492047.SRR12492048.control.outTable_19231...
# 6634             0  SRR12492047.SRR12492048.control.outTable_19231...
#
#                                               ko_sample  Region  Position  \
# 0     SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 1     SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 2     SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 122   SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 1172  SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 2281  SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 2909  SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 3082  SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 5607  SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
# 6634  SRR12492029.SRR12492030.siADARs.outTable_43606...     NaN       NaN
#
#      Class_y RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 0        NaN      NaN       NaN        NaN         NaN
# 1        NaN      NaN       NaN        NaN         NaN
# 2        NaN      NaN       NaN        NaN         NaN
# 122      NaN      NaN       NaN        NaN         NaN
# 1172     NaN      NaN       NaN        NaN         NaN
# 2281     NaN      NaN       NaN        NaN         NaN
# 2909     NaN      NaN       NaN        NaN         NaN
# 3082     NaN      NaN       NaN        NaN         NaN
# 5607     NaN      NaN       NaN        NaN         NaN
# 6634     NaN      NaN       NaN        NaN         NaN
#
# [10 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/a549/SRR12492047.SRR12492048.control.outTable_192318299.gz_vs_SRR12492029.SRR12492030.siADARs.outTable_436061877.gz.bonafide_final.tsv.anno.filt_refseq.tsv
