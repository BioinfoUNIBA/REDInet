# %%
##################
### Author: Adriano Fonzino. email: adriano.fonzino@uniba.it
##################
import os
import pandas as pd
import numpy as np


# define util function for downstream analysis
def join_bonafides(bonafide_fp, bonafide_anno_filt):
    ### function to join bonafide with reditools info with bonafide with anno and filtered 
    ### NON-REP only Refseq
    # load bonafide with reditools alignment profiles/data
    bonafide = pd.read_table(bonafide_fp)
    print("Bonafide not-filted with REDItools info:")
    display(bonafide)
    # load annotated table filtered for positives NON-REP being in Refseq
    bonafide_anno_filt = pd.read_table(bonafide_anno_filt_fp)
    print("Bonafide annotated and filtered (NON-REP only Refseq):")
    display(bonafide_anno_filt)
    # inner join between bonafide with and without annotation/filtering
    joined = pd.merge(bonafide, bonafide_anno_filt, 
                      left_on=["wt_Region", "wt_Position"],
                      right_on=["Region", "Position"], how="inner")
    print("Common sites annotated with REDItools info:")
    display(joined)
    # print not common site (not Refseq)
    left_join = pd.merge(bonafide, bonafide_anno_filt, 
                        left_on=["wt_Region", "wt_Position"],
                        right_on=["Region", "Position"], how="left")
    print("Discared sites (via left join):")
    display(left_join[left_join["Class_y"].isna()])
    output_file = bonafide_fp + ".anno.filt_refseq.tsv"
    print("Save on disk joined with annotation and filtering to :", output_file)
    joined.to_csv(output_file, index=None, sep="\t")

    return joined

# %% [markdown]
# ## Hek Pub. Data

# %%
### Couple 1
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_publicdata/SRR5564274.wildtype.outTable_724242056.gz_vs_SRR5564272.ADAR1_KO.outTable_816573740.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK/outTable_724242056_outTable_816573740_bona_fide_sites_2.tsv"

couple1_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       217844            A          1               32
# 1         chrX       217852            A          1               36
# 2         chrX       217930            A          1               44
# 3         chrX       217946            A          1               42
# 4         chrX       218542            A          1               32
# ...        ...          ...          ...        ...              ...
# 7019      chr8    124027628            A          0              103
# 7020      chr8    124031541            A          0              130
# 7021      chr8    132982824            A          1               33
# 7022      chr8    145066886            A          1               83
# 7023      chr8    145150832            A          1              169
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        36.72         [29, 0, 3, 0]         AG          0.09      chrX  ...
# 1        35.89        [25, 0, 11, 0]         AG          0.31      chrX  ...
# 2        35.32         [42, 0, 2, 0]         AG          0.05      chrX  ...
# 3        35.50         [39, 0, 3, 0]         AG          0.07      chrX  ...
# 4        36.38         [30, 0, 2, 0]         AG          0.06      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 7019     35.65        [0, 0, 103, 0]         AG          1.00      chr8  ...
# 7020     37.04        [53, 0, 77, 0]         AG          0.59      chr8  ...
# 7021     35.03         [0, 0, 33, 0]         AG          1.00      chr8  ...
# 7022     36.94         [0, 0, 83, 0]         AG          1.00      chr8  ...
# 7023     37.99        [0, 0, 169, 0]         AG          1.00      chr8  ...
#
#       gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs gFrequency  \
# 0           1            35   40.11        [35, 0, 0, 0]         -        0.0
# 1           1            33   40.64        [33, 0, 0, 0]         -        0.0
# 2           1            33   40.55        [33, 0, 0, 0]         -        0.0
# 3           1            38   40.82        [38, 0, 0, 0]         -        0.0
# 4           1            33   39.82        [33, 0, 0, 0]         -        0.0
# ...       ...           ...     ...                  ...       ...        ...
# 7019        0            53   40.45        [0, 0, 53, 0]        AG        1.0
# 7020        0            40   39.83       [16, 0, 24, 0]        AG        0.6
# 7021        1            40   41.92        [0, 0, 40, 0]        AG        1.0
# 7022        1            54   40.98        [0, 0, 54, 0]        AG        1.0
# 7023        1            33   40.00        [0, 0, 33, 0]        AG        1.0
#
#             Class  Class_binary                                  wt_sample  \
# 0         Editing             1  SRR5564274.wildtype.outTable_724242056.gz
# 1         Editing             1  SRR5564274.wildtype.outTable_724242056.gz
# 2         Editing             1  SRR5564274.wildtype.outTable_724242056.gz
# 3         Editing             1  SRR5564274.wildtype.outTable_724242056.gz
# 4         Editing             1  SRR5564274.wildtype.outTable_724242056.gz
# ...           ...           ...                                        ...
# 7019  Not-Editing             0  SRR5564274.wildtype.outTable_724242056.gz
# 7020  Not-Editing             0  SRR5564274.wildtype.outTable_724242056.gz
# 7021  Not-Editing             0  SRR5564274.wildtype.outTable_724242056.gz
# 7022  Not-Editing             0  SRR5564274.wildtype.outTable_724242056.gz
# 7023  Not-Editing             0  SRR5564274.wildtype.outTable_724242056.gz
#
#                                       ko_sample
# 0     SRR5564272.ADAR1_KO.outTable_816573740.gz
# 1     SRR5564272.ADAR1_KO.outTable_816573740.gz
# 2     SRR5564272.ADAR1_KO.outTable_816573740.gz
# 3     SRR5564272.ADAR1_KO.outTable_816573740.gz
# 4     SRR5564272.ADAR1_KO.outTable_816573740.gz
# ...                                         ...
# 7019  SRR5564272.ADAR1_KO.outTable_816573740.gz
# 7020  SRR5564272.ADAR1_KO.outTable_816573740.gz
# 7021  SRR5564272.ADAR1_KO.outTable_816573740.gz
# 7022  SRR5564272.ADAR1_KO.outTable_816573740.gz
# 7023  SRR5564272.ADAR1_KO.outTable_816573740.gz
#
# [7024 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#      Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0      chr1      16996      0        -        -       transcript,exon
# 1      chr1     881906      1        -        -   transcript,CDS,exon
# 2      chr1     888639      0        -        -   transcript,CDS,exon
# 3      chr1     888659      0        -        -   transcript,CDS,exon
# 4      chr1    1247494      0        -        -   transcript,CDS,exon
# ...     ...        ...    ...      ...      ...                   ...
# 7007   chrX  153296575      1        -        -   exon,transcript,CDS
# 7008   chrX  153583369      1        -        -   transcript,CDS,exon
# 7009   chrX  153633953      0        -        -  transcript,exon,5UTR
# 7010   chrX  153712377      1        -        -  3UTR,exon,transcript
# 7011   chrX  153993779      1        -        -   transcript,exon,CDS
#
#      RefSeq-Reg
# 0        WASH7P
# 1         NOC2L
# 2         NOC2L
# 3         NOC2L
# 4        INTS11
# ...         ...
# 7007      MECP2
# 7008       FLNA
# 7009   DNASE1L1
# 7010      UBL4A
# 7011       DKC1
#
# [7012 rows x 7 columns]
# Common sites annotated with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       217844            A          1               32
# 1         chrX       217852            A          1               36
# 2         chrX       217930            A          1               44
# 3         chrX       217946            A          1               42
# 4         chrX       218542            A          1               32
# ...        ...          ...          ...        ...              ...
# 7007      chr8    124027628            A          0              103
# 7008      chr8    124031541            A          0              130
# 7009      chr8    132982824            A          1               33
# 7010      chr8    145066886            A          1               83
# 7011      chr8    145150832            A          1              169
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        36.72         [29, 0, 3, 0]         AG          0.09      chrX  ...
# 1        35.89        [25, 0, 11, 0]         AG          0.31      chrX  ...
# 2        35.32         [42, 0, 2, 0]         AG          0.05      chrX  ...
# 3        35.50         [39, 0, 3, 0]         AG          0.07      chrX  ...
# 4        36.38         [30, 0, 2, 0]         AG          0.06      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 7007     35.65        [0, 0, 103, 0]         AG          1.00      chr8  ...
# 7008     37.04        [53, 0, 77, 0]         AG          0.59      chr8  ...
# 7009     35.03         [0, 0, 33, 0]         AG          1.00      chr8  ...
# 7010     36.94         [0, 0, 83, 0]         AG          1.00      chr8  ...
# 7011     37.99        [0, 0, 169, 0]         AG          1.00      chr8  ...
#
#       Class_binary                                  wt_sample  \
# 0                1  SRR5564274.wildtype.outTable_724242056.gz
# 1                1  SRR5564274.wildtype.outTable_724242056.gz
# 2                1  SRR5564274.wildtype.outTable_724242056.gz
# 3                1  SRR5564274.wildtype.outTable_724242056.gz
# 4                1  SRR5564274.wildtype.outTable_724242056.gz
# ...            ...                                        ...
# 7007             0  SRR5564274.wildtype.outTable_724242056.gz
# 7008             0  SRR5564274.wildtype.outTable_724242056.gz
# 7009             0  SRR5564274.wildtype.outTable_724242056.gz
# 7010             0  SRR5564274.wildtype.outTable_724242056.gz
# 7011             0  SRR5564274.wildtype.outTable_724242056.gz
#
#                                       ko_sample  Region   Position Class_y  \
# 0     SRR5564272.ADAR1_KO.outTable_816573740.gz    chrX     217844       1
# 1     SRR5564272.ADAR1_KO.outTable_816573740.gz    chrX     217852       1
# 2     SRR5564272.ADAR1_KO.outTable_816573740.gz    chrX     217930       1
# 3     SRR5564272.ADAR1_KO.outTable_816573740.gz    chrX     217946       1
# 4     SRR5564272.ADAR1_KO.outTable_816573740.gz    chrX     218542       1
# ...                                         ...     ...        ...     ...
# 7007  SRR5564272.ADAR1_KO.outTable_816573740.gz    chr8  124027628       0
# 7008  SRR5564272.ADAR1_KO.outTable_816573740.gz    chr8  124031541       0
# 7009  SRR5564272.ADAR1_KO.outTable_816573740.gz    chr8  132982824       0
# 7010  SRR5564272.ADAR1_KO.outTable_816573740.gz    chr8  145066886       0
# 7011  SRR5564272.ADAR1_KO.outTable_816573740.gz    chr8  145150832       0
#
#      RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 1        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 2        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 3        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 4        SINE    AluSx1  transcript,exon,3UTR      PLCXD1
# ...       ...       ...                   ...         ...
# 7007        -         -  3UTR,exon,transcript       DERL1
# 7008        -         -   transcript,CDS,exon       DERL1
# 7009        -         -   transcript,CDS,exon       EFR3A
# 7010        -         -   transcript,CDS,exon       GRINA
# 7011        -         -   transcript,CDS,exon        CYC1
#
# [7012 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 106       chrX    100098022            A          1               50
# 114       chrX    100600245            A          0               31
# 125       chrX    106364215            A          0               34
# 235      chr13     45907280            A          0               37
# 265      chr13     88337706            A          1               42
# 1083     chr17     56070347            A          0               30
# 1147     chr17     79844502            A          0               54
# 1438     chr15    102310012            A          0               32
# 2224     chr22     29899471            A          0               45
# 2467      chr7     50509149            A          0               39
# 3386      chr3    113433409            A          0               34
# 3739      chr2    176975169            A          1               95
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 106      35.60         [48, 0, 2, 0]         AG          0.04      chrX  ...
# 114      34.10         [29, 0, 2, 0]         AG          0.06      chrX  ...
# 125      36.65         [32, 0, 2, 0]         AG          0.06      chrX  ...
# 235      36.00         [35, 0, 2, 0]         AG          0.05     chr13  ...
# 265      36.38         [40, 0, 2, 0]         AG          0.05     chr13  ...
# 1083     41.60         [28, 0, 2, 0]         AG          0.07     chr17  ...
# 1147     36.30         [52, 0, 2, 0]         AG          0.04     chr17  ...
# 1438     35.62         [25, 0, 7, 0]         AG          0.22     chr15  ...
# 2224     35.29         [43, 0, 2, 0]         AG          0.04     chr22  ...
# 2467     35.69         [37, 0, 2, 0]         AG          0.05      chr7  ...
# 3386     35.18         [32, 0, 2, 0]         AG          0.06      chr3  ...
# 3739     36.25         [93, 0, 2, 0]         AG          0.02      chr2  ...
#
#       Class_binary                                  wt_sample  \
# 106              1  SRR5564274.wildtype.outTable_724242056.gz
# 114              1  SRR5564274.wildtype.outTable_724242056.gz
# 125              1  SRR5564274.wildtype.outTable_724242056.gz
# 235              1  SRR5564274.wildtype.outTable_724242056.gz
# 265              1  SRR5564274.wildtype.outTable_724242056.gz
# 1083             1  SRR5564274.wildtype.outTable_724242056.gz
# 1147             1  SRR5564274.wildtype.outTable_724242056.gz
# 1438             1  SRR5564274.wildtype.outTable_724242056.gz
# 2224             1  SRR5564274.wildtype.outTable_724242056.gz
# 2467             1  SRR5564274.wildtype.outTable_724242056.gz
# 3386             1  SRR5564274.wildtype.outTable_724242056.gz
# 3739             1  SRR5564274.wildtype.outTable_724242056.gz
#
#                                       ko_sample  Region  Position Class_y  \
# 106   SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 114   SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 125   SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 235   SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 265   SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 1083  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 1147  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 1438  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 2224  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 2467  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 3386  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
# 3739  SRR5564272.ADAR1_KO.outTable_816573740.gz     NaN       NaN     NaN
#
#      RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 106       NaN       NaN        NaN         NaN
# 114       NaN       NaN        NaN         NaN
# 125       NaN       NaN        NaN         NaN
# 235       NaN       NaN        NaN         NaN
# 265       NaN       NaN        NaN         NaN
# 1083      NaN       NaN        NaN         NaN
# 1147      NaN       NaN        NaN         NaN
# 1438      NaN       NaN        NaN         NaN
# 2224      NaN       NaN        NaN         NaN
# 2467      NaN       NaN        NaN         NaN
# 3386      NaN       NaN        NaN         NaN
# 3739      NaN       NaN        NaN         NaN
#
# [12 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_publicdata/SRR5564274.wildtype.outTable_724242056.gz_vs_SRR5564272.ADAR1_KO.outTable_816573740.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 2
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_publicdata/SRR5564275.wildtype.outTable_580067564.gz_vs_SRR5564273.ADAR1_KO.outTable_718392497.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK/outTable_580067564_outTable_718392497_bona_fide_sites_2.tsv"

couple2_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       217741            A          1               62
# 1         chrX       217778            A          1               55
# 2         chrX       217844            A          1               85
# 3         chrX       217875            A          1               79
# 4         chrX       217930            A          1               81
# ...        ...          ...          ...        ...              ...
# 8510      chr8    132982824            A          1               60
# 8511      chr8    144732418            A          1               83
# 8512      chr8    145066886            A          1              284
# 8513      chr8    145150832            A          1              361
# 8514      chr8    145665516            A          0               89
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        38.73         [58, 0, 4, 0]         AG          0.06      chrX  ...
# 1        39.98         [53, 0, 2, 0]         AG          0.04      chrX  ...
# 2        38.59         [81, 0, 4, 0]         AG          0.05      chrX  ...
# 3        36.59         [75, 0, 4, 0]         AG          0.05      chrX  ...
# 4        37.02         [79, 0, 2, 0]         AG          0.02      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 8510     35.33         [0, 0, 60, 0]         AG          1.00      chr8  ...
# 8511     35.73         [0, 0, 83, 0]         AG          1.00      chr8  ...
# 8512     36.31        [0, 0, 284, 0]         AG          1.00      chr8  ...
# 8513     37.37        [0, 0, 361, 0]         AG          1.00      chr8  ...
# 8514     35.35         [3, 0, 86, 0]         AG          0.97      chr8  ...
#
#       gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs gFrequency  \
# 0           1            31   40.71        [31, 0, 0, 0]         -        0.0
# 1           1            28   40.71        [28, 0, 0, 0]         -        0.0
# 2           1            35   40.11        [35, 0, 0, 0]         -        0.0
# 3           1            32   40.25        [32, 0, 0, 0]         -        0.0
# 4           1            33   40.55        [33, 0, 0, 0]         -        0.0
# ...       ...           ...     ...                  ...       ...        ...
# 8510        1            40   41.92        [0, 0, 40, 0]        AG        1.0
# 8511        1            35   39.74        [0, 0, 35, 0]        AG        1.0
# 8512        1            54   40.98        [0, 0, 54, 0]        AG        1.0
# 8513        1            33   40.00        [0, 0, 33, 0]        AG        1.0
# 8514        0            59   40.75        [0, 0, 59, 0]        AG        1.0
#
#             Class  Class_binary                                  wt_sample  \
# 0         Editing             1  SRR5564275.wildtype.outTable_580067564.gz
# 1         Editing             1  SRR5564275.wildtype.outTable_580067564.gz
# 2         Editing             1  SRR5564275.wildtype.outTable_580067564.gz
# 3         Editing             1  SRR5564275.wildtype.outTable_580067564.gz
# 4         Editing             1  SRR5564275.wildtype.outTable_580067564.gz
# ...           ...           ...                                        ...
# 8510  Not-Editing             0  SRR5564275.wildtype.outTable_580067564.gz
# 8511  Not-Editing             0  SRR5564275.wildtype.outTable_580067564.gz
# 8512  Not-Editing             0  SRR5564275.wildtype.outTable_580067564.gz
# 8513  Not-Editing             0  SRR5564275.wildtype.outTable_580067564.gz
# 8514  Not-Editing             0  SRR5564275.wildtype.outTable_580067564.gz
#
#                                       ko_sample
# 0     SRR5564273.ADAR1_KO.outTable_718392497.gz
# 1     SRR5564273.ADAR1_KO.outTable_718392497.gz
# 2     SRR5564273.ADAR1_KO.outTable_718392497.gz
# 3     SRR5564273.ADAR1_KO.outTable_718392497.gz
# 4     SRR5564273.ADAR1_KO.outTable_718392497.gz
# ...                                         ...
# 8510  SRR5564273.ADAR1_KO.outTable_718392497.gz
# 8511  SRR5564273.ADAR1_KO.outTable_718392497.gz
# 8512  SRR5564273.ADAR1_KO.outTable_718392497.gz
# 8513  SRR5564273.ADAR1_KO.outTable_718392497.gz
# 8514  SRR5564273.ADAR1_KO.outTable_718392497.gz
#
# [8515 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#      Region   Position  Class RMSK-Rep RMSK-Reg  \
# 0      chr1      20250      0     LINE       L3
# 1      chr1     879687      0        -        -
# 2      chr1     888639      0        -        -
# 3      chr1     888659      0        -        -
# 4      chr1     892600      1        -        -
# ...     ...        ...    ...      ...      ...
# 8500   chrX  153276787      1     SINE    AluJb
# 8501   chrX  153279606      1        -        -
# 8502   chrX  153593040      1        -        -
# 8503   chrX  153633953      0        -        -
# 8504   chrX  154019265      1        -        -
#
#                                      RefSeq-Rep    RefSeq-Reg
# 0                                    transcript        WASH7P
# 1     transcript,exon,3UTR&3UTR,exon,transcript  SAMD11&NOC2L
# 2                           transcript,CDS,exon         NOC2L
# 3                           transcript,CDS,exon         NOC2L
# 4                           transcript,CDS,exon         NOC2L
# ...                                         ...           ...
# 8500                       3UTR,exon,transcript         IRAK1
# 8501                        transcript,CDS,exon         IRAK1
# 8502                        transcript,CDS,exon          FLNA
# 8503                       transcript,exon,5UTR      DNASE1L1
# 8504                        transcript,CDS,exon          MPP1
#
# [8505 rows x 7 columns]
# Common sites annotated with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX       217741            A          1               62
# 1         chrX       217778            A          1               55
# 2         chrX       217844            A          1               85
# 3         chrX       217875            A          1               79
# 4         chrX       217930            A          1               81
# ...        ...          ...          ...        ...              ...
# 8500      chr8    132982824            A          1               60
# 8501      chr8    144732418            A          1               83
# 8502      chr8    145066886            A          1              284
# 8503      chr8    145150832            A          1              361
# 8504      chr8    145665516            A          0               89
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        38.73         [58, 0, 4, 0]         AG          0.06      chrX  ...
# 1        39.98         [53, 0, 2, 0]         AG          0.04      chrX  ...
# 2        38.59         [81, 0, 4, 0]         AG          0.05      chrX  ...
# 3        36.59         [75, 0, 4, 0]         AG          0.05      chrX  ...
# 4        37.02         [79, 0, 2, 0]         AG          0.02      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 8500     35.33         [0, 0, 60, 0]         AG          1.00      chr8  ...
# 8501     35.73         [0, 0, 83, 0]         AG          1.00      chr8  ...
# 8502     36.31        [0, 0, 284, 0]         AG          1.00      chr8  ...
# 8503     37.37        [0, 0, 361, 0]         AG          1.00      chr8  ...
# 8504     35.35         [3, 0, 86, 0]         AG          0.97      chr8  ...
#
#       Class_binary                                  wt_sample  \
# 0                1  SRR5564275.wildtype.outTable_580067564.gz
# 1                1  SRR5564275.wildtype.outTable_580067564.gz
# 2                1  SRR5564275.wildtype.outTable_580067564.gz
# 3                1  SRR5564275.wildtype.outTable_580067564.gz
# 4                1  SRR5564275.wildtype.outTable_580067564.gz
# ...            ...                                        ...
# 8500             0  SRR5564275.wildtype.outTable_580067564.gz
# 8501             0  SRR5564275.wildtype.outTable_580067564.gz
# 8502             0  SRR5564275.wildtype.outTable_580067564.gz
# 8503             0  SRR5564275.wildtype.outTable_580067564.gz
# 8504             0  SRR5564275.wildtype.outTable_580067564.gz
#
#                                       ko_sample  Region   Position Class_y  \
# 0     SRR5564273.ADAR1_KO.outTable_718392497.gz    chrX     217741       1
# 1     SRR5564273.ADAR1_KO.outTable_718392497.gz    chrX     217778       1
# 2     SRR5564273.ADAR1_KO.outTable_718392497.gz    chrX     217844       1
# 3     SRR5564273.ADAR1_KO.outTable_718392497.gz    chrX     217875       1
# 4     SRR5564273.ADAR1_KO.outTable_718392497.gz    chrX     217930       1
# ...                                         ...     ...        ...     ...
# 8500  SRR5564273.ADAR1_KO.outTable_718392497.gz    chr8  132982824       0
# 8501  SRR5564273.ADAR1_KO.outTable_718392497.gz    chr8  144732418       0
# 8502  SRR5564273.ADAR1_KO.outTable_718392497.gz    chr8  145066886       0
# 8503  SRR5564273.ADAR1_KO.outTable_718392497.gz    chr8  145150832       0
# 8504  SRR5564273.ADAR1_KO.outTable_718392497.gz    chr8  145665516       0
#
#      RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 1        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 2        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 3        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# 4        SINE     AluJb  transcript,exon,3UTR      PLCXD1
# ...       ...       ...                   ...         ...
# 8500        -         -   transcript,CDS,exon       EFR3A
# 8501        -         -   transcript,exon,CDS      ZNF623
# 8502        -         -   transcript,CDS,exon       GRINA
# 8503        -         -   transcript,CDS,exon        CYC1
# 8504        -         -   transcript,CDS,exon       TONSL
#
# [8505 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 284      chr13     45907280            A          0               46
# 859      chr11     93915583            A          1               54
# 1274     chr17     19015652            A          0              337
# 1422     chr17     56076332            A          0               66
# 1782     chr15     64653384            A          0               32
# 1877     chr14     21675776            A          0               45
# 4410      chr3     73026837            A          1              103
# 5308      chr1     62918927            A          1               64
# 5397      chr1    110899147            A          1               97
# 5423      chr1    111981770            A          0               36
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 284      36.78         [44, 0, 2, 0]         AG          0.04     chr13  ...
# 859      36.41         [52, 0, 2, 0]         AG          0.04     chr11  ...
# 1274     36.82        [335, 0, 2, 0]         AG          0.01     chr17  ...
# 1422     36.12         [64, 0, 2, 0]         AG          0.03     chr17  ...
# 1782     35.03         [30, 0, 2, 0]         AG          0.06     chr15  ...
# 1877     37.69         [43, 0, 2, 0]         AG          0.04     chr14  ...
# 4410     36.42        [101, 0, 2, 0]         AG          0.02      chr3  ...
# 5308     37.81         [62, 0, 2, 0]         AG          0.03      chr1  ...
# 5397     35.91         [95, 0, 2, 0]         AG          0.02      chr1  ...
# 5423     35.11         [34, 0, 2, 0]         AG          0.06      chr1  ...
#
#       Class_binary                                  wt_sample  \
# 284              1  SRR5564275.wildtype.outTable_580067564.gz
# 859              1  SRR5564275.wildtype.outTable_580067564.gz
# 1274             1  SRR5564275.wildtype.outTable_580067564.gz
# 1422             1  SRR5564275.wildtype.outTable_580067564.gz
# 1782             1  SRR5564275.wildtype.outTable_580067564.gz
# 1877             1  SRR5564275.wildtype.outTable_580067564.gz
# 4410             1  SRR5564275.wildtype.outTable_580067564.gz
# 5308             1  SRR5564275.wildtype.outTable_580067564.gz
# 5397             1  SRR5564275.wildtype.outTable_580067564.gz
# 5423             1  SRR5564275.wildtype.outTable_580067564.gz
#
#                                       ko_sample  Region  Position Class_y  \
# 284   SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 859   SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 1274  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 1422  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 1782  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 1877  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 4410  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 5308  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 5397  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
# 5423  SRR5564273.ADAR1_KO.outTable_718392497.gz     NaN       NaN     NaN
#
#      RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 284       NaN       NaN        NaN         NaN
# 859       NaN       NaN        NaN         NaN
# 1274      NaN       NaN        NaN         NaN
# 1422      NaN       NaN        NaN         NaN
# 1782      NaN       NaN        NaN         NaN
# 1877      NaN       NaN        NaN         NaN
# 4410      NaN       NaN        NaN         NaN
# 5308      NaN       NaN        NaN         NaN
# 5397      NaN       NaN        NaN         NaN
# 5423      NaN       NaN        NaN         NaN
#
# [10 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_publicdata/SRR5564275.wildtype.outTable_580067564.gz_vs_SRR5564273.ADAR1_KO.outTable_718392497.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 3
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_publicdata/SRR5564276.wildtype.outTable_181728208.gz_vs_SRR5564268.ADAR1_KO.outTable_854894021.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK/outTable_181728208_outTable_854894021_bona_fide_sites_2.tsv"

couple3_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       205483            A          1              180
# 1          chrX       215935            A          1               68
# 2          chrX       216802            A          1               51
# 3          chrX       216807            A          1               53
# 4          chrX       217393            A          1               43
# ...         ...          ...          ...        ...              ...
# 11064     chr21     47635176            A          0              134
# 11065     chr21     47705237            A          0              139
# 11066     chr21     47851753            A          1               62
# 11067     chr21     47862624            A          1               43
# 11068     chr21     48084628            A          1               97
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         36.29        [178, 0, 2, 0]         AG          0.01      chrX  ...
# 1         38.91         [66, 0, 2, 0]         AG          0.03      chrX  ...
# 2         37.86         [49, 0, 2, 0]         AG          0.04      chrX  ...
# 3         37.62         [50, 0, 3, 0]         AG          0.06      chrX  ...
# 4         35.02        [26, 0, 17, 0]         AG          0.40      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 11064     36.46        [74, 0, 60, 0]         AG          0.45     chr21  ...
# 11065     36.01       [31, 0, 108, 0]         AG          0.78     chr21  ...
# 11066     35.55        [44, 0, 18, 0]         AG          0.29     chr21  ...
# 11067     37.19         [0, 0, 43, 0]         AG          1.00     chr21  ...
# 11068     36.71         [0, 0, 97, 0]         AG          1.00     chr21  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            34   40.85        [34, 0, 0, 0]         -
# 1            1            30   39.40        [30, 0, 0, 0]         -
# 2            1            34   39.32        [34, 0, 0, 0]         -
# 3            1            31   39.45        [31, 0, 0, 0]         -
# 4            1            31   39.61        [31, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 11064        0            34   38.62        [26, 0, 8, 0]        AG
# 11065        0            46   40.98       [21, 0, 25, 0]        AG
# 11066        1            39   40.38       [29, 0, 10, 0]        AG
# 11067        1            46   41.33        [0, 0, 46, 0]        AG
# 11068        1            51   40.35        [0, 0, 51, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 11064       0.24  Not-Editing             0
# 11065       0.54  Not-Editing             0
# 11066       0.26  Not-Editing             0
# 11067       1.00  Not-Editing             0
# 11068       1.00  Not-Editing             0
#
#                                        wt_sample  \
# 0      SRR5564276.wildtype.outTable_181728208.gz
# 1      SRR5564276.wildtype.outTable_181728208.gz
# 2      SRR5564276.wildtype.outTable_181728208.gz
# 3      SRR5564276.wildtype.outTable_181728208.gz
# 4      SRR5564276.wildtype.outTable_181728208.gz
# ...                                          ...
# 11064  SRR5564276.wildtype.outTable_181728208.gz
# 11065  SRR5564276.wildtype.outTable_181728208.gz
# 11066  SRR5564276.wildtype.outTable_181728208.gz
# 11067  SRR5564276.wildtype.outTable_181728208.gz
# 11068  SRR5564276.wildtype.outTable_181728208.gz
#
#                                        ko_sample
# 0      SRR5564268.ADAR1_KO.outTable_854894021.gz
# 1      SRR5564268.ADAR1_KO.outTable_854894021.gz
# 2      SRR5564268.ADAR1_KO.outTable_854894021.gz
# 3      SRR5564268.ADAR1_KO.outTable_854894021.gz
# 4      SRR5564268.ADAR1_KO.outTable_854894021.gz
# ...                                          ...
# 11064  SRR5564268.ADAR1_KO.outTable_854894021.gz
# 11065  SRR5564268.ADAR1_KO.outTable_854894021.gz
# 11066  SRR5564268.ADAR1_KO.outTable_854894021.gz
# 11067  SRR5564268.ADAR1_KO.outTable_854894021.gz
# 11068  SRR5564268.ADAR1_KO.outTable_854894021.gz
#
# [11069 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg  \
# 0       chr1      16996      0        -        -
# 1       chr1     694459      0        -        -
# 2       chr1     879874      1        -        -
# 3       chr1     888639      0        -        -
# 4       chr1     888659      0        -        -
# ...      ...        ...    ...      ...      ...
# 11034   chrX  153633953      0        -        -
# 11035   chrX  153676847      1        -        -
# 11036   chrX  153676853      1        -        -
# 11037   chrX  153676854      1        -        -
# 11038   chrX  154350907      1     LINE    L1MD2
#
#                                       RefSeq-Rep    RefSeq-Reg
# 0                                transcript,exon        WASH7P
# 1                                transcript,exon  LOC100288069
# 2      transcript,exon,3UTR&3UTR,exon,transcript  SAMD11&NOC2L
# 3                            transcript,CDS,exon         NOC2L
# 4                            transcript,CDS,exon         NOC2L
# ...                                          ...           ...
# 11034                       transcript,exon,5UTR      DNASE1L1
# 11035                        transcript,CDS,exon        FAM50A
# 11036                        transcript,CDS,exon        FAM50A
# 11037                        transcript,CDS,exon        FAM50A
# 11038                       transcript,3UTR,exon         BRCC3
#
# [11039 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       205483            A          1              180
# 1          chrX       215935            A          1               68
# 2          chrX       216802            A          1               51
# 3          chrX       216807            A          1               53
# 4          chrX       217393            A          1               43
# ...         ...          ...          ...        ...              ...
# 11034     chr21     47635176            A          0              134
# 11035     chr21     47705237            A          0              139
# 11036     chr21     47851753            A          1               62
# 11037     chr21     47862624            A          1               43
# 11038     chr21     48084628            A          1               97
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         36.29        [178, 0, 2, 0]         AG          0.01      chrX  ...
# 1         38.91         [66, 0, 2, 0]         AG          0.03      chrX  ...
# 2         37.86         [49, 0, 2, 0]         AG          0.04      chrX  ...
# 3         37.62         [50, 0, 3, 0]         AG          0.06      chrX  ...
# 4         35.02        [26, 0, 17, 0]         AG          0.40      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 11034     36.46        [74, 0, 60, 0]         AG          0.45     chr21  ...
# 11035     36.01       [31, 0, 108, 0]         AG          0.78     chr21  ...
# 11036     35.55        [44, 0, 18, 0]         AG          0.29     chr21  ...
# 11037     37.19         [0, 0, 43, 0]         AG          1.00     chr21  ...
# 11038     36.71         [0, 0, 97, 0]         AG          1.00     chr21  ...
#
#        Class_binary                                  wt_sample  \
# 0                 1  SRR5564276.wildtype.outTable_181728208.gz
# 1                 1  SRR5564276.wildtype.outTable_181728208.gz
# 2                 1  SRR5564276.wildtype.outTable_181728208.gz
# 3                 1  SRR5564276.wildtype.outTable_181728208.gz
# 4                 1  SRR5564276.wildtype.outTable_181728208.gz
# ...             ...                                        ...
# 11034             0  SRR5564276.wildtype.outTable_181728208.gz
# 11035             0  SRR5564276.wildtype.outTable_181728208.gz
# 11036             0  SRR5564276.wildtype.outTable_181728208.gz
# 11037             0  SRR5564276.wildtype.outTable_181728208.gz
# 11038             0  SRR5564276.wildtype.outTable_181728208.gz
#
#                                        ko_sample  Region  Position Class_y  \
# 0      SRR5564268.ADAR1_KO.outTable_854894021.gz    chrX    205483       1
# 1      SRR5564268.ADAR1_KO.outTable_854894021.gz    chrX    215935       1
# 2      SRR5564268.ADAR1_KO.outTable_854894021.gz    chrX    216802       1
# 3      SRR5564268.ADAR1_KO.outTable_854894021.gz    chrX    216807       1
# 4      SRR5564268.ADAR1_KO.outTable_854894021.gz    chrX    217393       1
# ...                                          ...     ...       ...     ...
# 11034  SRR5564268.ADAR1_KO.outTable_854894021.gz   chr21  47635176       0
# 11035  SRR5564268.ADAR1_KO.outTable_854894021.gz   chr21  47705237       0
# 11036  SRR5564268.ADAR1_KO.outTable_854894021.gz   chr21  47851753       0
# 11037  SRR5564268.ADAR1_KO.outTable_854894021.gz   chr21  47862624       0
# 11038  SRR5564268.ADAR1_KO.outTable_854894021.gz   chr21  48084628       0
#
#       RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0            -         -   transcript,CDS,exon      PLCXD1
# 1            -         -   transcript,CDS,exon      PLCXD1
# 2         SINE     AluJr  transcript,exon,3UTR      PLCXD1
# 3         SINE     AluJr  transcript,exon,3UTR      PLCXD1
# 4         SINE     AluSx  transcript,exon,3UTR      PLCXD1
# ...        ...       ...                   ...         ...
# 11034        -         -   transcript,CDS,exon         LSS
# 11035        -         -  transcript,exon,5UTR      MCM3AP
# 11036        -         -   transcript,CDS,exon        PCNT
# 11037        -         -            transcript        PCNT
# 11038        -         -  transcript,exon,3UTR       PRMT2
#
# [11039 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 56        chrX     24072978            A          1              162
# 418      chr13     45907280            A          0               43
# 553      chr12     49324564            A          0               47
# 1199     chr11     93915353            A          1               39
# 1393     chr10     60159455            A          1               45
# 1955     chr17     56071470            A          0               46
# 1956     chr17     56075924            A          0               87
# 2044     chr17     79836854            A          0               62
# 2511     chr15     64651474            A          0               38
# 2517     chr15     64652749            A          0               30
# 2518     chr15     64653378            A          0               54
# 2519     chr15     64653384            A          0               56
# 2616     chr15    102310009            A          0               31
# 2617     chr15    102310012            A          0               31
# 3127     chr19     23402908            A          0               32
# 3330     chr19     56166043            A          1              154
# 4011      chr1    109605186            A          0              153
# 4039      chr1    110905329            A          1               44
# 4107      chr1    145292171            A          1               62
# 4119      chr1    145383073            A          1              157
# 4148      chr1    147736090            A          1              119
# 4154      chr1    148241878            A          1              368
# 4491      chr1    245010722            A          0              127
# 4537      chr6     27100817            A          1               43
# 5875      chr7    152340243            A          0               91
# 6048      chr5     44816095            A          1              123
# 6118      chr5     70330047            A          0               96
# 7204      chr3    113434294            A          0               45
# 7957      chr9     37506191            A          1              101
# 8314      chr8    145500213            A          0               53
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 56       38.59        [160, 0, 2, 0]         AG          0.01      chrX  ...
# 418      35.12         [40, 0, 3, 0]         AG          0.07     chr13  ...
# 553      37.02         [45, 0, 2, 0]         AG          0.04     chr12  ...
# 1199     34.97         [36, 0, 3, 0]         AG          0.08     chr11  ...
# 1393     34.93         [43, 0, 2, 0]         AG          0.04     chr10  ...
# 1955     34.35         [44, 0, 2, 0]         AG          0.04     chr17  ...
# 1956     36.76         [85, 0, 2, 0]         AG          0.02     chr17  ...
# 2044     35.90         [60, 0, 2, 0]         AG          0.03     chr17  ...
# 2511     36.95         [36, 0, 2, 0]         AG          0.05     chr15  ...
# 2517     35.00         [27, 0, 3, 0]         AG          0.10     chr15  ...
# 2518     35.30         [52, 0, 2, 0]         AG          0.04     chr15  ...
# 2519     35.57         [54, 0, 2, 0]         AG          0.04     chr15  ...
# 2616     36.97         [29, 0, 2, 0]         AG          0.06     chr15  ...
# 2617     37.90         [28, 0, 3, 0]         AG          0.10     chr15  ...
# 3127     35.25         [30, 0, 2, 0]         AG          0.06     chr19  ...
# 3330     37.33        [152, 0, 2, 0]         AG          0.01     chr19  ...
# 4011     36.97        [151, 0, 2, 0]         AG          0.01      chr1  ...
# 4039     36.68         [37, 0, 7, 0]         AG          0.16      chr1  ...
# 4107     37.11         [60, 0, 2, 0]         AG          0.03      chr1  ...
# 4119     35.39        [155, 0, 2, 0]         AG          0.01      chr1  ...
# 4148     36.84        [117, 0, 2, 0]         AG          0.02      chr1  ...
# 4154     34.85        [366, 0, 2, 0]         AG          0.01      chr1  ...
# 4491     37.35        [125, 0, 2, 0]         AG          0.02      chr1  ...
# 4537     34.05         [40, 0, 3, 0]         AG          0.07      chr6  ...
# 5875     36.48         [89, 0, 2, 0]         AG          0.02      chr7  ...
# 6048     35.56        [121, 0, 2, 0]         AG          0.02      chr5  ...
# 6118     35.92         [90, 0, 6, 0]         AG          0.06      chr5  ...
# 7204     36.62         [36, 0, 9, 0]         AG          0.20      chr3  ...
# 7957     35.17         [99, 0, 2, 0]         AG          0.02      chr9  ...
# 8314     35.85         [51, 0, 2, 0]         AG          0.04      chr8  ...
#
#       Class_binary                                  wt_sample  \
# 56               1  SRR5564276.wildtype.outTable_181728208.gz
# 418              1  SRR5564276.wildtype.outTable_181728208.gz
# 553              1  SRR5564276.wildtype.outTable_181728208.gz
# 1199             1  SRR5564276.wildtype.outTable_181728208.gz
# 1393             1  SRR5564276.wildtype.outTable_181728208.gz
# 1955             1  SRR5564276.wildtype.outTable_181728208.gz
# 1956             1  SRR5564276.wildtype.outTable_181728208.gz
# 2044             1  SRR5564276.wildtype.outTable_181728208.gz
# 2511             1  SRR5564276.wildtype.outTable_181728208.gz
# 2517             1  SRR5564276.wildtype.outTable_181728208.gz
# 2518             1  SRR5564276.wildtype.outTable_181728208.gz
# 2519             1  SRR5564276.wildtype.outTable_181728208.gz
# 2616             1  SRR5564276.wildtype.outTable_181728208.gz
# 2617             1  SRR5564276.wildtype.outTable_181728208.gz
# 3127             1  SRR5564276.wildtype.outTable_181728208.gz
# 3330             1  SRR5564276.wildtype.outTable_181728208.gz
# 4011             1  SRR5564276.wildtype.outTable_181728208.gz
# 4039             1  SRR5564276.wildtype.outTable_181728208.gz
# 4107             1  SRR5564276.wildtype.outTable_181728208.gz
# 4119             1  SRR5564276.wildtype.outTable_181728208.gz
# 4148             1  SRR5564276.wildtype.outTable_181728208.gz
# 4154             1  SRR5564276.wildtype.outTable_181728208.gz
# 4491             1  SRR5564276.wildtype.outTable_181728208.gz
# 4537             1  SRR5564276.wildtype.outTable_181728208.gz
# 5875             1  SRR5564276.wildtype.outTable_181728208.gz
# 6048             1  SRR5564276.wildtype.outTable_181728208.gz
# 6118             1  SRR5564276.wildtype.outTable_181728208.gz
# 7204             1  SRR5564276.wildtype.outTable_181728208.gz
# 7957             1  SRR5564276.wildtype.outTable_181728208.gz
# 8314             1  SRR5564276.wildtype.outTable_181728208.gz
#
#                                       ko_sample  Region  Position Class_y  \
# 56    SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 418   SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 553   SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 1199  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 1393  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 1955  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 1956  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2044  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2511  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2517  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2518  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2519  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2616  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 2617  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 3127  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 3330  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4011  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4039  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4107  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4119  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4148  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4154  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4491  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 4537  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 5875  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 6048  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 6118  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 7204  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 7957  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
# 8314  SRR5564268.ADAR1_KO.outTable_854894021.gz     NaN       NaN     NaN
#
#      RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 56        NaN       NaN        NaN         NaN
# 418       NaN       NaN        NaN         NaN
# 553       NaN       NaN        NaN         NaN
# 1199      NaN       NaN        NaN         NaN
# 1393      NaN       NaN        NaN         NaN
# 1955      NaN       NaN        NaN         NaN
# 1956      NaN       NaN        NaN         NaN
# 2044      NaN       NaN        NaN         NaN
# 2511      NaN       NaN        NaN         NaN
# 2517      NaN       NaN        NaN         NaN
# 2518      NaN       NaN        NaN         NaN
# 2519      NaN       NaN        NaN         NaN
# 2616      NaN       NaN        NaN         NaN
# 2617      NaN       NaN        NaN         NaN
# 3127      NaN       NaN        NaN         NaN
# 3330      NaN       NaN        NaN         NaN
# 4011      NaN       NaN        NaN         NaN
# 4039      NaN       NaN        NaN         NaN
# 4107      NaN       NaN        NaN         NaN
# 4119      NaN       NaN        NaN         NaN
# 4148      NaN       NaN        NaN         NaN
# 4154      NaN       NaN        NaN         NaN
# 4491      NaN       NaN        NaN         NaN
# 4537      NaN       NaN        NaN         NaN
# 5875      NaN       NaN        NaN         NaN
# 6048      NaN       NaN        NaN         NaN
# 6118      NaN       NaN        NaN         NaN
# 7204      NaN       NaN        NaN         NaN
# 7957      NaN       NaN        NaN         NaN
# 8314      NaN       NaN        NaN         NaN
#
# [30 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_publicdata/SRR5564276.wildtype.outTable_181728208.gz_vs_SRR5564268.ADAR1_KO.outTable_854894021.gz.bonafide_final.tsv.anno.filt_refseq.tsv
