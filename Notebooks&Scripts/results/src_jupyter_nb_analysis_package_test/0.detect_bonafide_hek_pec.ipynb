# %%
##################
### Author: Adriano Fonzino. email: adriano.fonzino@uniba.it
##################
import pandas as pd
import numpy as np
import pysam, gzip, os
from datetime import datetime

# %%
# define util function
def extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp):
    wt = pysam.TabixFile(wt_fp)
    ko = pysam.TabixFile(ko_fp)
    wgs = pysam.TabixFile(wgs_fp)
    bonafide = []
    start_time = datetime.now()
    with gzip.open(wt_fp) as wt_table:
        for c,s in enumerate(wt_table):
            site = s.decode("utf-8").rstrip().split("\t")
            if c % 50000000 == 0:
                print("Evaluated sites:", c)
            if site[0] == "Region":
                # store header
                header = site[:9]
            else:
                if site[0].startswith("chr"):
                    if site[0] != "chrM":
                        if site[2] == "A":
                            if site[4] != "-":
                                if int(site[4]) >= min_cov:
                                    if site[7] == "AG" and float(site[8]) >= 0.01:
                                        vector = eval(site[6])
                                        if vector[2] >= min_ag_subs:
                                            ko_query = [i for i in ko.fetch(site[0], int(site[1])-1, int(site[1]))]
                                            if len(ko_query) == 1:
                                                ko_query = ko_query[0].split("\t")
                                                if ko_query[4] != "-":
                                                    if int(ko_query[4]) >= min_cov:
                                                        wgs_query = [i for i in wgs.fetch(site[0], int(site[1])-1, int(site[1]))]
                                                        if len(wgs_query) == 1:
                                                            wgs_query = wgs_query[0].split("\t")
                                                            if wgs_query[9] != "-":
                                                                if int(wgs_query[9]) >= min_cov_wgs:
                                                                    whole_site = site[:9] + ko_query[:9] + wgs_query[0:4] + wgs_query[9:]
                                                                    bonafide.append(whole_site)
    print("Iteration on tabix outTables finished. Elapsed time: ", datetime.now()-start_time)
    columns=["wt_"+i for i in header]+["ko_"+i for i in header]+["g"+i for i in header]
    bonafide = pd.DataFrame(bonafide, columns=columns)
    
    # save to disk bonafide candidates
    output_file = os.path.join(output_folder, wt_name + "_vs_" + ko_name + ".bonafide_candidates.tsv")
    print("Save to disk bonafide candidates:", output_file)
    bonafide.to_csv(output_file, sep="\t", index=None)
    
    # load from disk to infer dtypes
    bonafide = pd.read_table(output_file)
    
    # drop unstranded
    bonafide = bonafide[(bonafide["wt_Strand"]!=2)&(bonafide["ko_Strand"]!=2)&(bonafide["gStrand"]!=2)].copy()
    
    # select concordand for strand for wt and ko
    # select only strand concordand sites
    bonafide = bonafide[bonafide["wt_Strand"] == bonafide["ko_Strand"]].copy()
    bonafide = bonafide[bonafide["ko_Strand"] == bonafide["gStrand"]].copy()
    bonafide.reset_index(inplace=True, drop=True)
    display(bonafide)
    pos = bonafide[(bonafide["wt_AllSubs"]=="AG")&(bonafide["ko_AllSubs"]=="-")&(bonafide["gAllSubs"]=="-")].copy()
    pos["Class"] = "Editing"
    pos["Class_binary"] = 1
    print("Pos:", pos.shape)
    neg = bonafide[(bonafide["wt_AllSubs"]=="AG")&(bonafide["ko_AllSubs"]=="AG")&(bonafide["gAllSubs"]=="AG")].copy()
    # select negs with 0.01 AG freq and min_ag_subs
    neg = neg.query("ko_Frequency >= 0.01")
    mask = []
    for cand in neg["ko_BaseCount[A,C,G,T]"]:
        vector = eval(cand)
        if vector[2] >= min_ag_subs:
            mask.append(True)
        else:
            mask.append(False)
    neg = neg[mask].copy()
    neg["Class"] = "Not-Editing"
    neg["Class_binary"] = 0
    print("Neg:", neg.shape)
    # merge pos and neg and add samples id
    bonafide_final = pd.concat([pos, neg])
    bonafide_final.reset_index(inplace=True, drop=True)
    bonafide_final["wt_sample"] = wt_name
    bonafide_final["ko_sample"] = ko_name
    
    display(bonafide_final)
    print(bonafide_final[["Class", "Class_binary"]].value_counts())
    
    # save to disk bonafide final
    output_file = os.path.join(output_folder, wt_name + "_vs_" + ko_name + ".bonafide_final.tsv")
    print("Save to disk bonafide final:", output_file)
    bonafide_final.to_csv(output_file, sep="\t", index=None)
    
    wt.close()
    ko.close()
    wgs.close()
    return bonafide_final

# %%
# define output folder
output_folder = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori"

# %%
# define wgs tabix outTable file path
wgs_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_adar_samples/SRR10129631.WGS.wildtype/DnaRna_59095329/outTable_59095329.gz"

# define common filters
min_cov = 50
min_cov_wgs = 10
min_ag_subs = 3

# %%
# couple 1 (KO1 vs OvE1)
wt_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK_ADAR1_p110_wt_1.OvE/DnaRna_530905096/outTable_530905096.gz"
ko_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_KO1.KO/DnaRna_905657585/outTable_905657585.gz"
wt_name = "HEK_ADAR1_p110_wt_1.OvE" + f".{os.path.basename(wt_fp)}"
ko_name = "HEK293T_KO1.KO" + f".{os.path.basename(ko_fp)}"
print(wt_name)
print(ko_name)

couple1 = extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp)
couple1
# Out:
# HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# HEK293T_KO1.KO.outTable_905657585.gz
# Evaluated sites: 0
# Evaluated sites: 50000000
# Evaluated sites: 100000000
# Evaluated sites: 150000000
# Evaluated sites: 200000000
# Evaluated sites: 250000000
# Iteration on tabix outTables finished. Elapsed time:  0:09:38.686462
# Save to disk bonafide candidates: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_candidates.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              383
# 1          chrX       299510            A          1              388
# 2          chrX       299513            A          1              385
# 3          chrX       299540            A          1              365
# 4          chrX       299543            A          1              368
# ...         ...          ...          ...        ...              ...
# 46885      chr8    144976278            A          0              490
# 46886      chr8    144977014            A          0              556
# 46887      chr8    144977019            A          0              548
# 46888      chr8    144977023            A          0              545
# 46889      chr8    144977113            A          0              706
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.11       [372, 0, 11, 0]         AG          0.03      chrX  ...
# 1         45.23      [281, 0, 107, 0]         AG          0.28      chrX  ...
# 2         45.16        [381, 0, 4, 0]         AG          0.01      chrX  ...
# 3         47.04        [359, 0, 6, 0]         AG          0.02      chrX  ...
# 4         47.25        [365, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 46885     48.16        [487, 0, 3, 0]         AG          0.01      chr8  ...
# 46886     45.21        [548, 0, 8, 0]         AG          0.01      chr8  ...
# 46887     45.91       [538, 0, 10, 0]         AG          0.02      chr8  ...
# 46888     46.35       [535, 0, 10, 0]         AG          0.02      chr8  ...
# 46889     46.29        [701, 0, 5, 0]         AG          0.01      chr8  ...
#
#        ko_Frequency gRegion  gPosition  gReference  gStrand gCoverage-q30  \
# 0              0.00    chrX     299493           A        1            30
# 1              0.00    chrX     299510           A        1            36
# 2              0.00    chrX     299513           A        1            34
# 3              0.00    chrX     299540           A        1            37
# 4              0.00    chrX     299543           A        1            39
# ...             ...     ...        ...         ...      ...           ...
# 46885          0.00    chr8  144976278           A        0            35
# 46886          0.03    chr8  144977014           A        0            40
# 46887          0.03    chr8  144977019           A        0            42
# 46888          0.03    chr8  144977023           A        0            39
# 46889          0.00    chr8  144977113           A        0            35
#
#       gMeanQ  gBaseCount[A,C,G,T] gAllSubs  gFrequency
# 0      40.47        [30, 0, 0, 0]        -         0.0
# 1      41.00        [36, 0, 0, 0]        -         0.0
# 2      41.35        [34, 0, 0, 0]        -         0.0
# 3      41.11        [37, 0, 0, 0]        -         0.0
# 4      42.33        [39, 0, 0, 0]        -         0.0
# ...      ...                  ...      ...         ...
# 46885  39.74        [35, 0, 0, 0]        -         0.0
# 46886  41.20        [40, 0, 0, 0]        -         0.0
# 46887  41.57        [42, 0, 0, 0]        -         0.0
# 46888  42.26        [39, 0, 0, 0]        -         0.0
# 46889  39.77        [35, 0, 0, 0]        -         0.0
#
# [46890 rows x 27 columns]
# Pos: (36152, 29)
# Neg: (3337, 29)
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              383
# 1          chrX       299510            A          1              388
# 2          chrX       299513            A          1              385
# 3          chrX       299540            A          1              365
# 4          chrX       299543            A          1              368
# ...         ...          ...          ...        ...              ...
# 39484      chr8    144451628            A          0              299
# 39485      chr8    144454002            A          0               59
# 39486      chr8    144460013            A          0               57
# 39487      chr8    144468337            A          1              420
# 39488      chr8    144931953            A          0              813
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.11       [372, 0, 11, 0]         AG          0.03      chrX  ...
# 1         45.23      [281, 0, 107, 0]         AG          0.28      chrX  ...
# 2         45.16        [381, 0, 4, 0]         AG          0.01      chrX  ...
# 3         47.04        [359, 0, 6, 0]         AG          0.02      chrX  ...
# 4         47.25        [365, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 39484     51.34       [244, 0, 55, 0]         AG          0.18      chr8  ...
# 39485     45.15         [0, 0, 59, 0]         AG          1.00      chr8  ...
# 39486     51.93        [41, 0, 16, 0]         AG          0.28      chr8  ...
# 39487     48.59        [0, 0, 420, 0]         AG          1.00      chr8  ...
# 39488     48.47      [191, 0, 622, 0]         AG          0.77      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 39484        0            43   40.12        [35, 0, 8, 0]        AG
# 39485        0            34   38.82        [0, 0, 34, 0]        AG
# 39486        0            33   39.91       [20, 0, 13, 0]        AG
# 39487        1            34   40.50        [0, 0, 34, 0]        AG
# 39488        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 39484       0.19  Not-Editing             0
# 39485       1.00  Not-Editing             0
# 39486       0.39  Not-Editing             0
# 39487       1.00  Not-Editing             0
# 39488       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 2      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 3      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 4      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# ...                                              ...
# 39484  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39485  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39486  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39487  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39488  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 39484  HEK293T_KO1.KO.outTable_905657585.gz
# 39485  HEK293T_KO1.KO.outTable_905657585.gz
# 39486  HEK293T_KO1.KO.outTable_905657585.gz
# 39487  HEK293T_KO1.KO.outTable_905657585.gz
# 39488  HEK293T_KO1.KO.outTable_905657585.gz
#
# [39489 rows x 31 columns]
# Class        Class_binary
# Editing      1               36152
# Not-Editing  0                3337
# dtype: int64
# Save to disk bonafide final: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_final.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              383
# 1          chrX       299510            A          1              388
# 2          chrX       299513            A          1              385
# 3          chrX       299540            A          1              365
# 4          chrX       299543            A          1              368
# ...         ...          ...          ...        ...              ...
# 39484      chr8    144451628            A          0              299
# 39485      chr8    144454002            A          0               59
# 39486      chr8    144460013            A          0               57
# 39487      chr8    144468337            A          1              420
# 39488      chr8    144931953            A          0              813
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.11       [372, 0, 11, 0]         AG          0.03      chrX  ...
# 1         45.23      [281, 0, 107, 0]         AG          0.28      chrX  ...
# 2         45.16        [381, 0, 4, 0]         AG          0.01      chrX  ...
# 3         47.04        [359, 0, 6, 0]         AG          0.02      chrX  ...
# 4         47.25        [365, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 39484     51.34       [244, 0, 55, 0]         AG          0.18      chr8  ...
# 39485     45.15         [0, 0, 59, 0]         AG          1.00      chr8  ...
# 39486     51.93        [41, 0, 16, 0]         AG          0.28      chr8  ...
# 39487     48.59        [0, 0, 420, 0]         AG          1.00      chr8  ...
# 39488     48.47      [191, 0, 622, 0]         AG          0.77      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 39484        0            43   40.12        [35, 0, 8, 0]        AG
# 39485        0            34   38.82        [0, 0, 34, 0]        AG
# 39486        0            33   39.91       [20, 0, 13, 0]        AG
# 39487        1            34   40.50        [0, 0, 34, 0]        AG
# 39488        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 39484       0.19  Not-Editing             0
# 39485       1.00  Not-Editing             0
# 39486       0.39  Not-Editing             0
# 39487       1.00  Not-Editing             0
# 39488       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 2      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 3      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 4      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# ...                                              ...
# 39484  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39485  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39486  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39487  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39488  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 39484  HEK293T_KO1.KO.outTable_905657585.gz
# 39485  HEK293T_KO1.KO.outTable_905657585.gz
# 39486  HEK293T_KO1.KO.outTable_905657585.gz
# 39487  HEK293T_KO1.KO.outTable_905657585.gz
# 39488  HEK293T_KO1.KO.outTable_905657585.gz
#
# [39489 rows x 31 columns]

# %%
# couple 2 (KO2 vs OvE2)
wt_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK_ADAR1_p110_wt_2.OvE/DnaRna_814257267/outTable_814257267.gz"
ko_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_KO2.KO/DnaRna_364841872/outTable_364841872.gz"
wt_name = "HEK_ADAR1_p110_wt_2.OvE" + f".{os.path.basename(wt_fp)}"
ko_name = "HEK293T_KO2.KO" + f".{os.path.basename(ko_fp)}"
print(wt_name)
print(ko_name)

couple2 = extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp)
couple2
# Out:
# HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# HEK293T_KO2.KO.outTable_364841872.gz
# Evaluated sites: 0
# Evaluated sites: 50000000
# Evaluated sites: 100000000
# Evaluated sites: 150000000
# Evaluated sites: 200000000
# Evaluated sites: 250000000
# Iteration on tabix outTables finished. Elapsed time:  0:09:40.769580
# Save to disk bonafide candidates: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_candidates.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              324
# 1          chrX       299510            A          1              318
# 2          chrX       299513            A          1              314
# 3          chrX       299543            A          1              303
# 4          chrX       299551            A          1              288
# ...         ...          ...          ...        ...              ...
# 45864      chr8    144974956            A          0              715
# 45865      chr8    144975042            A          0              785
# 45866      chr8    144975093            A          0              761
# 45867      chr8    144975890            A          0              328
# 45868      chr8    144977113            A          0              772
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         45.15        [320, 0, 4, 0]         AG          0.01      chrX  ...
# 1         45.16       [236, 0, 82, 0]         AG          0.26      chrX  ...
# 2         45.80        [305, 0, 9, 0]         AG          0.03      chrX  ...
# 3         45.42        [294, 0, 9, 0]         AG          0.03      chrX  ...
# 4         47.07        [283, 0, 5, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 45864     47.78       [701, 0, 14, 0]         AG          0.02      chr8  ...
# 45865     43.57        [781, 0, 4, 0]         AG          0.01      chr8  ...
# 45866     47.66        [753, 0, 8, 0]         AG          0.01      chr8  ...
# 45867     40.41        [324, 0, 4, 0]         AG          0.01      chr8  ...
# 45868     46.66        [768, 0, 4, 0]         AG          0.01      chr8  ...
#
#        ko_Frequency gRegion  gPosition  gReference  gStrand gCoverage-q30  \
# 0               0.0    chrX     299493           A        1            30
# 1               0.0    chrX     299510           A        1            36
# 2               0.0    chrX     299513           A        1            34
# 3               0.0    chrX     299543           A        1            39
# 4               0.0    chrX     299551           A        1            38
# ...             ...     ...        ...         ...      ...           ...
# 45864           0.0    chr8  144974956           A        0            50
# 45865           0.0    chr8  144975042           A        0            41
# 45866           0.0    chr8  144975093           A        0            41
# 45867           0.0    chr8  144975890           A        0            37
# 45868           0.0    chr8  144977113           A        0            35
#
#       gMeanQ  gBaseCount[A,C,G,T] gAllSubs  gFrequency
# 0      40.47        [30, 0, 0, 0]        -         0.0
# 1      41.00        [36, 0, 0, 0]        -         0.0
# 2      41.35        [34, 0, 0, 0]        -         0.0
# 3      42.33        [39, 0, 0, 0]        -         0.0
# 4      41.45        [38, 0, 0, 0]        -         0.0
# ...      ...                  ...      ...         ...
# 45864  41.06        [50, 0, 0, 0]        -         0.0
# 45865  39.22        [41, 0, 0, 0]        -         0.0
# 45866  40.15        [41, 0, 0, 0]        -         0.0
# 45867  39.70        [37, 0, 0, 0]        -         0.0
# 45868  39.77        [35, 0, 0, 0]        -         0.0
#
# [45869 rows x 27 columns]
# Pos: (34025, 29)
# Neg: (3458, 29)
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              324
# 1          chrX       299510            A          1              318
# 2          chrX       299513            A          1              314
# 3          chrX       299543            A          1              303
# 4          chrX       299551            A          1              288
# ...         ...          ...          ...        ...              ...
# 37478      chr8    144451628            A          0              276
# 37479      chr8    144457131            A          0               90
# 37480      chr8    144458636            A          0               95
# 37481      chr8    144468337            A          1              396
# 37482      chr8    144931953            A          0              797
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         45.15        [320, 0, 4, 0]         AG          0.01      chrX  ...
# 1         45.16       [236, 0, 82, 0]         AG          0.26      chrX  ...
# 2         45.80        [305, 0, 9, 0]         AG          0.03      chrX  ...
# 3         45.42        [294, 0, 9, 0]         AG          0.03      chrX  ...
# 4         47.07        [283, 0, 5, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 37478     48.17       [219, 0, 57, 0]         AG          0.21      chr8  ...
# 37479     46.32        [11, 0, 79, 0]         AG          0.88      chr8  ...
# 37480     51.41        [73, 0, 22, 0]         AG          0.23      chr8  ...
# 37481     49.43        [0, 0, 396, 0]         AG          1.00      chr8  ...
# 37482     47.27      [162, 0, 635, 0]         AG          0.80      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            39   42.33        [39, 0, 0, 0]         -
# 4            1            38   41.45        [38, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 37478        0            43   40.12        [35, 0, 8, 0]        AG
# 37479        0            35   39.86       [14, 0, 21, 0]        AG
# 37480        0            36   42.17       [19, 0, 17, 0]        AG
# 37481        1            34   40.50        [0, 0, 34, 0]        AG
# 37482        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 37478       0.19  Not-Editing             0
# 37479       0.60  Not-Editing             0
# 37480       0.47  Not-Editing             0
# 37481       1.00  Not-Editing             0
# 37482       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 1      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 2      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 4      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# ...                                              ...
# 37478  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37479  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37480  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37481  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37482  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
#
#                                   ko_sample
# 0      HEK293T_KO2.KO.outTable_364841872.gz
# 1      HEK293T_KO2.KO.outTable_364841872.gz
# 2      HEK293T_KO2.KO.outTable_364841872.gz
# 3      HEK293T_KO2.KO.outTable_364841872.gz
# 4      HEK293T_KO2.KO.outTable_364841872.gz
# ...                                     ...
# 37478  HEK293T_KO2.KO.outTable_364841872.gz
# 37479  HEK293T_KO2.KO.outTable_364841872.gz
# 37480  HEK293T_KO2.KO.outTable_364841872.gz
# 37481  HEK293T_KO2.KO.outTable_364841872.gz
# 37482  HEK293T_KO2.KO.outTable_364841872.gz
#
# [37483 rows x 31 columns]
# Class        Class_binary
# Editing      1               34025
# Not-Editing  0                3458
# dtype: int64
# Save to disk bonafide final: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_final.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              324
# 1          chrX       299510            A          1              318
# 2          chrX       299513            A          1              314
# 3          chrX       299543            A          1              303
# 4          chrX       299551            A          1              288
# ...         ...          ...          ...        ...              ...
# 37478      chr8    144451628            A          0              276
# 37479      chr8    144457131            A          0               90
# 37480      chr8    144458636            A          0               95
# 37481      chr8    144468337            A          1              396
# 37482      chr8    144931953            A          0              797
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         45.15        [320, 0, 4, 0]         AG          0.01      chrX  ...
# 1         45.16       [236, 0, 82, 0]         AG          0.26      chrX  ...
# 2         45.80        [305, 0, 9, 0]         AG          0.03      chrX  ...
# 3         45.42        [294, 0, 9, 0]         AG          0.03      chrX  ...
# 4         47.07        [283, 0, 5, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 37478     48.17       [219, 0, 57, 0]         AG          0.21      chr8  ...
# 37479     46.32        [11, 0, 79, 0]         AG          0.88      chr8  ...
# 37480     51.41        [73, 0, 22, 0]         AG          0.23      chr8  ...
# 37481     49.43        [0, 0, 396, 0]         AG          1.00      chr8  ...
# 37482     47.27      [162, 0, 635, 0]         AG          0.80      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            39   42.33        [39, 0, 0, 0]         -
# 4            1            38   41.45        [38, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 37478        0            43   40.12        [35, 0, 8, 0]        AG
# 37479        0            35   39.86       [14, 0, 21, 0]        AG
# 37480        0            36   42.17       [19, 0, 17, 0]        AG
# 37481        1            34   40.50        [0, 0, 34, 0]        AG
# 37482        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 37478       0.19  Not-Editing             0
# 37479       0.60  Not-Editing             0
# 37480       0.47  Not-Editing             0
# 37481       1.00  Not-Editing             0
# 37482       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 1      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 2      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 4      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# ...                                              ...
# 37478  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37479  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37480  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37481  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37482  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
#
#                                   ko_sample
# 0      HEK293T_KO2.KO.outTable_364841872.gz
# 1      HEK293T_KO2.KO.outTable_364841872.gz
# 2      HEK293T_KO2.KO.outTable_364841872.gz
# 3      HEK293T_KO2.KO.outTable_364841872.gz
# 4      HEK293T_KO2.KO.outTable_364841872.gz
# ...                                     ...
# 37478  HEK293T_KO2.KO.outTable_364841872.gz
# 37479  HEK293T_KO2.KO.outTable_364841872.gz
# 37480  HEK293T_KO2.KO.outTable_364841872.gz
# 37481  HEK293T_KO2.KO.outTable_364841872.gz
# 37482  HEK293T_KO2.KO.outTable_364841872.gz
#
# [37483 rows x 31 columns]

# %%
# couple 3 (KO3 vs OvE3)
wt_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK_ADAR1_p110_wt_3.OvE/DnaRna_208420383/outTable_208420383.gz"
ko_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_KO3.KO/DnaRna_597789462/outTable_597789462.gz"
wt_name = "HEK_ADAR1_p110_wt_3.OvE" + f".{os.path.basename(wt_fp)}"
ko_name = "HEK293T_KO3.KO" + f".{os.path.basename(ko_fp)}"
print(wt_name)
print(ko_name)

couple3 = extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp)
couple3
# Out:
# HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# HEK293T_KO3.KO.outTable_597789462.gz
# Evaluated sites: 0
# Evaluated sites: 50000000
# Evaluated sites: 100000000
# Evaluated sites: 150000000
# Evaluated sites: 200000000
# Evaluated sites: 250000000
# Iteration on tabix outTables finished. Elapsed time:  0:08:33.944579
# Save to disk bonafide candidates: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_candidates.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              297
# 1          chrX       299513            A          1              292
# 2          chrX       299548            A          1              262
# 3          chrX       299559            A          1              256
# 4          chrX       299568            A          1              262
# ...         ...          ...          ...        ...              ...
# 43422      chr8    144977023            A          0              429
# 43423      chr8    144977097            A          0              632
# 43424      chr8    144977113            A          0              633
# 43425      chr8    144977166            A          0              729
# 43426      chr8    144977374            A          0              565
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.47       [222, 0, 75, 0]         AG          0.25      chrX  ...
# 1         46.71        [287, 0, 5, 0]         AG          0.02      chrX  ...
# 2         46.18       [96, 0, 166, 0]         AG          0.63      chrX  ...
# 3         50.97        [251, 0, 5, 0]         AG          0.02      chrX  ...
# 4         51.22        [253, 0, 9, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 43422     46.02        [422, 0, 7, 0]         AG          0.02      chr8  ...
# 43423     46.09        [628, 0, 4, 0]         AG          0.01      chr8  ...
# 43424     47.99        [627, 0, 6, 0]         AG          0.01      chr8  ...
# 43425     48.06        [725, 0, 4, 0]         AG          0.01      chr8  ...
# 43426     47.93        [562, 0, 3, 0]         AG          0.01      chr8  ...
#
#        ko_Frequency gRegion  gPosition  gReference  gStrand gCoverage-q30  \
# 0              0.00    chrX     299510           A        1            36
# 1              0.00    chrX     299513           A        1            34
# 2              0.06    chrX     299548           A        1            36
# 3              0.00    chrX     299559           A        1            36
# 4              0.00    chrX     299568           A        1            34
# ...             ...     ...        ...         ...      ...           ...
# 43422          0.00    chr8  144977023           A        0            39
# 43423          0.00    chr8  144977097           A        0            35
# 43424          0.00    chr8  144977113           A        0            35
# 43425          0.00    chr8  144977166           A        0            42
# 43426          0.00    chr8  144977374           A        0            35
#
#       gMeanQ  gBaseCount[A,C,G,T] gAllSubs  gFrequency
# 0      41.00        [36, 0, 0, 0]        -         0.0
# 1      41.35        [34, 0, 0, 0]        -         0.0
# 2      42.81        [36, 0, 0, 0]        -         0.0
# 3      42.69        [36, 0, 0, 0]        -         0.0
# 4      40.47        [34, 0, 0, 0]        -         0.0
# ...      ...                  ...      ...         ...
# 43422  42.26        [39, 0, 0, 0]        -         0.0
# 43423  40.74        [35, 0, 0, 0]        -         0.0
# 43424  39.77        [35, 0, 0, 0]        -         0.0
# 43425  39.95        [42, 0, 0, 0]        -         0.0
# 43426  41.31        [35, 0, 0, 0]        -         0.0
#
# [43427 rows x 27 columns]
# Pos: (31893, 29)
# Neg: (3391, 29)
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              297
# 1          chrX       299513            A          1              292
# 2          chrX       299559            A          1              256
# 3          chrX       299568            A          1              262
# 4          chrX       299571            A          1              269
# ...         ...          ...          ...        ...              ...
# 35279      chr8    144458020            A          0               51
# 35280      chr8    144458072            A          0               52
# 35281      chr8    144468337            A          1              377
# 35282      chr8    144843461            A          1              122
# 35283      chr8    144931953            A          0              634
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.47       [222, 0, 75, 0]         AG          0.25      chrX  ...
# 1         46.71        [287, 0, 5, 0]         AG          0.02      chrX  ...
# 2         50.97        [251, 0, 5, 0]         AG          0.02      chrX  ...
# 3         51.22        [253, 0, 9, 0]         AG          0.03      chrX  ...
# 4         50.89        [262, 0, 7, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 35279     49.10         [0, 0, 51, 0]         AG          1.00      chr8  ...
# 35280     48.37         [0, 0, 52, 0]         AG          1.00      chr8  ...
# 35281     48.61        [0, 0, 377, 0]         AG          1.00      chr8  ...
# 35282     50.05        [24, 0, 98, 0]         AG          0.80      chr8  ...
# 35283     48.00      [118, 0, 516, 0]         AG          0.81      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            36   41.00        [36, 0, 0, 0]         -
# 1            1            34   41.35        [34, 0, 0, 0]         -
# 2            1            36   42.69        [36, 0, 0, 0]         -
# 3            1            34   40.47        [34, 0, 0, 0]         -
# 4            1            37   42.32        [37, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 35279        0            57   41.00        [0, 0, 57, 0]        AG
# 35280        0            48   41.33        [0, 0, 48, 0]        AG
# 35281        1            34   40.50        [0, 0, 34, 0]        AG
# 35282        1            46   40.46       [19, 0, 27, 0]        AG
# 35283        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 35279       1.00  Not-Editing             0
# 35280       1.00  Not-Editing             0
# 35281       1.00  Not-Editing             0
# 35282       0.59  Not-Editing             0
# 35283       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 1      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 3      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 4      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# ...                                              ...
# 35279  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35280  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35281  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35282  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35283  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
#
#                                   ko_sample
# 0      HEK293T_KO3.KO.outTable_597789462.gz
# 1      HEK293T_KO3.KO.outTable_597789462.gz
# 2      HEK293T_KO3.KO.outTable_597789462.gz
# 3      HEK293T_KO3.KO.outTable_597789462.gz
# 4      HEK293T_KO3.KO.outTable_597789462.gz
# ...                                     ...
# 35279  HEK293T_KO3.KO.outTable_597789462.gz
# 35280  HEK293T_KO3.KO.outTable_597789462.gz
# 35281  HEK293T_KO3.KO.outTable_597789462.gz
# 35282  HEK293T_KO3.KO.outTable_597789462.gz
# 35283  HEK293T_KO3.KO.outTable_597789462.gz
#
# [35284 rows x 31 columns]
# Class        Class_binary
# Editing      1               31893
# Not-Editing  0                3391
# dtype: int64
# Save to disk bonafide final: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_final.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              297
# 1          chrX       299513            A          1              292
# 2          chrX       299559            A          1              256
# 3          chrX       299568            A          1              262
# 4          chrX       299571            A          1              269
# ...         ...          ...          ...        ...              ...
# 35279      chr8    144458020            A          0               51
# 35280      chr8    144458072            A          0               52
# 35281      chr8    144468337            A          1              377
# 35282      chr8    144843461            A          1              122
# 35283      chr8    144931953            A          0              634
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.47       [222, 0, 75, 0]         AG          0.25      chrX  ...
# 1         46.71        [287, 0, 5, 0]         AG          0.02      chrX  ...
# 2         50.97        [251, 0, 5, 0]         AG          0.02      chrX  ...
# 3         51.22        [253, 0, 9, 0]         AG          0.03      chrX  ...
# 4         50.89        [262, 0, 7, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 35279     49.10         [0, 0, 51, 0]         AG          1.00      chr8  ...
# 35280     48.37         [0, 0, 52, 0]         AG          1.00      chr8  ...
# 35281     48.61        [0, 0, 377, 0]         AG          1.00      chr8  ...
# 35282     50.05        [24, 0, 98, 0]         AG          0.80      chr8  ...
# 35283     48.00      [118, 0, 516, 0]         AG          0.81      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            36   41.00        [36, 0, 0, 0]         -
# 1            1            34   41.35        [34, 0, 0, 0]         -
# 2            1            36   42.69        [36, 0, 0, 0]         -
# 3            1            34   40.47        [34, 0, 0, 0]         -
# 4            1            37   42.32        [37, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 35279        0            57   41.00        [0, 0, 57, 0]        AG
# 35280        0            48   41.33        [0, 0, 48, 0]        AG
# 35281        1            34   40.50        [0, 0, 34, 0]        AG
# 35282        1            46   40.46       [19, 0, 27, 0]        AG
# 35283        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 35279       1.00  Not-Editing             0
# 35280       1.00  Not-Editing             0
# 35281       1.00  Not-Editing             0
# 35282       0.59  Not-Editing             0
# 35283       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 1      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 3      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 4      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# ...                                              ...
# 35279  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35280  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35281  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35282  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35283  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
#
#                                   ko_sample
# 0      HEK293T_KO3.KO.outTable_597789462.gz
# 1      HEK293T_KO3.KO.outTable_597789462.gz
# 2      HEK293T_KO3.KO.outTable_597789462.gz
# 3      HEK293T_KO3.KO.outTable_597789462.gz
# 4      HEK293T_KO3.KO.outTable_597789462.gz
# ...                                     ...
# 35279  HEK293T_KO3.KO.outTable_597789462.gz
# 35280  HEK293T_KO3.KO.outTable_597789462.gz
# 35281  HEK293T_KO3.KO.outTable_597789462.gz
# 35282  HEK293T_KO3.KO.outTable_597789462.gz
# 35283  HEK293T_KO3.KO.outTable_597789462.gz
#
# [35284 rows x 31 columns]

# %%
# couple 4 (KO1 vs WT1)
wt_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_WT1.WT/DnaRna_599710609/outTable_599710609.gz"
ko_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_KO1.KO/DnaRna_905657585/outTable_905657585.gz"
wt_name = "HEK293T_WT1.WT" + f".{os.path.basename(wt_fp)}"
ko_name = "HEK293T_KO1.KO" + f".{os.path.basename(ko_fp)}"
print(wt_name)
print(ko_name)

couple4 = extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp)
couple4
# Out:
# HEK293T_WT1.WT.outTable_599710609.gz
# HEK293T_KO1.KO.outTable_905657585.gz
# Evaluated sites: 0
# Evaluated sites: 50000000
# Evaluated sites: 100000000
# Evaluated sites: 150000000
# Evaluated sites: 200000000
# Evaluated sites: 250000000
# Evaluated sites: 350000000
# Iteration on tabix outTables finished. Elapsed time:  0:10:35.784502
# Save to disk bonafide candidates: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT1.WT.outTable_599710609.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_candidates.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              371
# 1          chrX       299510            A          1              367
# 2          chrX       299513            A          1              367
# 3          chrX       299540            A          1              361
# 4          chrX       299543            A          1              367
# ...         ...          ...          ...        ...              ...
# 36345      chr8    144975093            A          0              387
# 36346      chr8    144975974            A          0              405
# 36347      chr8    144976539            A          0              458
# 36348      chr8    144977113            A          0              463
# 36349      chr8    144977265            A          0              391
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         44.71        [365, 0, 6, 0]         AG          0.02      chrX  ...
# 1         44.73       [332, 0, 35, 0]         AG          0.10      chrX  ...
# 2         44.63       [356, 0, 11, 0]         AG          0.03      chrX  ...
# 3         46.97        [356, 0, 5, 0]         AG          0.01      chrX  ...
# 4         46.54        [364, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 36345     50.61        [384, 0, 3, 0]         AG          0.01      chr8  ...
# 36346     50.03        [401, 0, 4, 0]         AG          0.01      chr8  ...
# 36347     46.62        [455, 0, 3, 0]         AG          0.01      chr8  ...
# 36348     46.75        [460, 0, 3, 0]         AG          0.01      chr8  ...
# 36349     47.28        [387, 0, 4, 0]         AG          0.01      chr8  ...
#
#        ko_Frequency gRegion  gPosition  gReference  gStrand gCoverage-q30  \
# 0               0.0    chrX     299493           A        1            30
# 1               0.0    chrX     299510           A        1            36
# 2               0.0    chrX     299513           A        1            34
# 3               0.0    chrX     299540           A        1            37
# 4               0.0    chrX     299543           A        1            39
# ...             ...     ...        ...         ...      ...           ...
# 36345           0.0    chr8  144975093           A        0            41
# 36346           0.0    chr8  144975974           A        0            39
# 36347           0.0    chr8  144976539           A        0            30
# 36348           0.0    chr8  144977113           A        0            35
# 36349           0.0    chr8  144977265           A        0            43
#
#       gMeanQ  gBaseCount[A,C,G,T] gAllSubs  gFrequency
# 0      40.47        [30, 0, 0, 0]        -         0.0
# 1      41.00        [36, 0, 0, 0]        -         0.0
# 2      41.35        [34, 0, 0, 0]        -         0.0
# 3      41.11        [37, 0, 0, 0]        -         0.0
# 4      42.33        [39, 0, 0, 0]        -         0.0
# ...      ...                  ...      ...         ...
# 36345  40.15        [41, 0, 0, 0]        -         0.0
# 36346  40.72        [39, 0, 0, 0]        -         0.0
# 36347  39.90        [30, 0, 0, 0]        -         0.0
# 36348  39.77        [35, 0, 0, 0]        -         0.0
# 36349  40.12        [43, 0, 0, 0]        -         0.0
#
# [36350 rows x 27 columns]
# Pos: (26275, 29)
# Neg: (3332, 29)
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              371
# 1          chrX       299510            A          1              367
# 2          chrX       299513            A          1              367
# 3          chrX       299540            A          1              361
# 4          chrX       299543            A          1              367
# ...         ...          ...          ...        ...              ...
# 29602      chr8    144451628            A          0              550
# 29603      chr8    144454002            A          0              136
# 29604      chr8    144460013            A          0               82
# 29605      chr8    144468337            A          1              937
# 29606      chr8    144931953            A          0              402
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         44.71        [365, 0, 6, 0]         AG          0.02      chrX  ...
# 1         44.73       [332, 0, 35, 0]         AG          0.10      chrX  ...
# 2         44.63       [356, 0, 11, 0]         AG          0.03      chrX  ...
# 3         46.97        [356, 0, 5, 0]         AG          0.01      chrX  ...
# 4         46.54        [364, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 29602     47.21      [430, 0, 120, 0]         AG          0.22      chr8  ...
# 29603     43.96        [0, 0, 136, 0]         AG          1.00      chr8  ...
# 29604     52.49        [69, 0, 13, 0]         AG          0.16      chr8  ...
# 29605     47.23        [3, 0, 934, 0]         AG          1.00      chr8  ...
# 29606     47.19      [101, 0, 301, 0]         AG          0.75      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 29602        0            43   40.12        [35, 0, 8, 0]        AG
# 29603        0            34   38.82        [0, 0, 34, 0]        AG
# 29604        0            33   39.91       [20, 0, 13, 0]        AG
# 29605        1            34   40.50        [0, 0, 34, 0]        AG
# 29606        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 29602       0.19  Not-Editing             0
# 29603       1.00  Not-Editing             0
# 29604       0.39  Not-Editing             0
# 29605       1.00  Not-Editing             0
# 29606       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT1.WT.outTable_599710609.gz
# 1      HEK293T_WT1.WT.outTable_599710609.gz
# 2      HEK293T_WT1.WT.outTable_599710609.gz
# 3      HEK293T_WT1.WT.outTable_599710609.gz
# 4      HEK293T_WT1.WT.outTable_599710609.gz
# ...                                     ...
# 29602  HEK293T_WT1.WT.outTable_599710609.gz
# 29603  HEK293T_WT1.WT.outTable_599710609.gz
# 29604  HEK293T_WT1.WT.outTable_599710609.gz
# 29605  HEK293T_WT1.WT.outTable_599710609.gz
# 29606  HEK293T_WT1.WT.outTable_599710609.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 29602  HEK293T_KO1.KO.outTable_905657585.gz
# 29603  HEK293T_KO1.KO.outTable_905657585.gz
# 29604  HEK293T_KO1.KO.outTable_905657585.gz
# 29605  HEK293T_KO1.KO.outTable_905657585.gz
# 29606  HEK293T_KO1.KO.outTable_905657585.gz
#
# [29607 rows x 31 columns]
# Class        Class_binary
# Editing      1               26275
# Not-Editing  0                3332
# dtype: int64
# Save to disk bonafide final: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT1.WT.outTable_599710609.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_final.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              371
# 1          chrX       299510            A          1              367
# 2          chrX       299513            A          1              367
# 3          chrX       299540            A          1              361
# 4          chrX       299543            A          1              367
# ...         ...          ...          ...        ...              ...
# 29602      chr8    144451628            A          0              550
# 29603      chr8    144454002            A          0              136
# 29604      chr8    144460013            A          0               82
# 29605      chr8    144468337            A          1              937
# 29606      chr8    144931953            A          0              402
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         44.71        [365, 0, 6, 0]         AG          0.02      chrX  ...
# 1         44.73       [332, 0, 35, 0]         AG          0.10      chrX  ...
# 2         44.63       [356, 0, 11, 0]         AG          0.03      chrX  ...
# 3         46.97        [356, 0, 5, 0]         AG          0.01      chrX  ...
# 4         46.54        [364, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 29602     47.21      [430, 0, 120, 0]         AG          0.22      chr8  ...
# 29603     43.96        [0, 0, 136, 0]         AG          1.00      chr8  ...
# 29604     52.49        [69, 0, 13, 0]         AG          0.16      chr8  ...
# 29605     47.23        [3, 0, 934, 0]         AG          1.00      chr8  ...
# 29606     47.19      [101, 0, 301, 0]         AG          0.75      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 29602        0            43   40.12        [35, 0, 8, 0]        AG
# 29603        0            34   38.82        [0, 0, 34, 0]        AG
# 29604        0            33   39.91       [20, 0, 13, 0]        AG
# 29605        1            34   40.50        [0, 0, 34, 0]        AG
# 29606        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 29602       0.19  Not-Editing             0
# 29603       1.00  Not-Editing             0
# 29604       0.39  Not-Editing             0
# 29605       1.00  Not-Editing             0
# 29606       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT1.WT.outTable_599710609.gz
# 1      HEK293T_WT1.WT.outTable_599710609.gz
# 2      HEK293T_WT1.WT.outTable_599710609.gz
# 3      HEK293T_WT1.WT.outTable_599710609.gz
# 4      HEK293T_WT1.WT.outTable_599710609.gz
# ...                                     ...
# 29602  HEK293T_WT1.WT.outTable_599710609.gz
# 29603  HEK293T_WT1.WT.outTable_599710609.gz
# 29604  HEK293T_WT1.WT.outTable_599710609.gz
# 29605  HEK293T_WT1.WT.outTable_599710609.gz
# 29606  HEK293T_WT1.WT.outTable_599710609.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 29602  HEK293T_KO1.KO.outTable_905657585.gz
# 29603  HEK293T_KO1.KO.outTable_905657585.gz
# 29604  HEK293T_KO1.KO.outTable_905657585.gz
# 29605  HEK293T_KO1.KO.outTable_905657585.gz
# 29606  HEK293T_KO1.KO.outTable_905657585.gz
#
# [29607 rows x 31 columns]

# %%
# couple 5 (KO2 vs WT2)
wt_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_WT2.WT/DnaRna_572868058/outTable_572868058.gz"
ko_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_KO2.KO/DnaRna_364841872/outTable_364841872.gz"
wt_name = "HEK293T_WT2.WT" + f".{os.path.basename(wt_fp)}"
ko_name = "HEK293T_KO2.KO" + f".{os.path.basename(ko_fp)}"
print(wt_name)
print(ko_name)

couple5 = extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp)
couple5
# Out:
# HEK293T_WT2.WT.outTable_572868058.gz
# HEK293T_KO2.KO.outTable_364841872.gz
# Evaluated sites: 0
# Evaluated sites: 50000000
# Evaluated sites: 100000000
# Evaluated sites: 150000000
# Evaluated sites: 200000000
# Evaluated sites: 250000000
# Iteration on tabix outTables finished. Elapsed time:  0:08:11.969366
# Save to disk bonafide candidates: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT2.WT.outTable_572868058.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_candidates.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              272
# 1          chrX       299513            A          1              263
# 2          chrX       299540            A          1              291
# 3          chrX       299548            A          1              270
# 4          chrX       299559            A          1              272
# ...         ...          ...          ...        ...              ...
# 31205      chr8    144974950            A          0              361
# 31206      chr8    144974956            A          0              349
# 31207      chr8    144977014            A          0              309
# 31208      chr8    144977019            A          0              325
# 31209      chr8    144977023            A          0              308
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         43.13       [239, 0, 33, 0]         AG          0.12      chrX  ...
# 1         43.09        [257, 0, 6, 0]         AG          0.02      chrX  ...
# 2         44.30        [288, 0, 3, 0]         AG          0.01      chrX  ...
# 3         43.62      [119, 0, 151, 0]         AG          0.56      chrX  ...
# 4         46.03        [267, 0, 5, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 31205     46.19        [354, 0, 7, 0]         AG          0.02      chr8  ...
# 31206     48.98        [342, 0, 7, 0]         AG          0.02      chr8  ...
# 31207     48.34       [299, 0, 10, 0]         AG          0.03      chr8  ...
# 31208     48.14       [310, 0, 15, 0]         AG          0.05      chr8  ...
# 31209     49.45       [294, 0, 14, 0]         AG          0.05      chr8  ...
#
#        ko_Frequency gRegion  gPosition  gReference  gStrand gCoverage-q30  \
# 0              0.00    chrX     299510           A        1            36
# 1              0.00    chrX     299513           A        1            34
# 2              0.00    chrX     299540           A        1            37
# 3              0.07    chrX     299548           A        1            36
# 4              0.00    chrX     299559           A        1            36
# ...             ...     ...        ...         ...      ...           ...
# 31205          0.00    chr8  144974950           A        0            45
# 31206          0.00    chr8  144974956           A        0            50
# 31207          0.01    chr8  144977014           A        0            40
# 31208          0.02    chr8  144977019           A        0            42
# 31209          0.01    chr8  144977023           A        0            39
#
#       gMeanQ  gBaseCount[A,C,G,T] gAllSubs  gFrequency
# 0      41.00        [36, 0, 0, 0]        -         0.0
# 1      41.35        [34, 0, 0, 0]        -         0.0
# 2      41.11        [37, 0, 0, 0]        -         0.0
# 3      42.81        [36, 0, 0, 0]        -         0.0
# 4      42.69        [36, 0, 0, 0]        -         0.0
# ...      ...                  ...      ...         ...
# 31205  40.98        [45, 0, 0, 0]        -         0.0
# 31206  41.06        [50, 0, 0, 0]        -         0.0
# 31207  41.20        [40, 0, 0, 0]        -         0.0
# 31208  41.57        [42, 0, 0, 0]        -         0.0
# 31209  42.26        [39, 0, 0, 0]        -         0.0
#
# [31210 rows x 27 columns]
# Pos: (20360, 29)
# Neg: (3460, 29)
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              272
# 1          chrX       299513            A          1              263
# 2          chrX       299540            A          1              291
# 3          chrX       299559            A          1              272
# 4          chrX       299568            A          1              271
# ...         ...          ...          ...        ...              ...
# 23815      chr8    144454002            A          0               86
# 23816      chr8    144457131            A          0               78
# 23817      chr8    144458636            A          0               90
# 23818      chr8    144468337            A          1              665
# 23819      chr8    144931953            A          0              296
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         43.13       [239, 0, 33, 0]         AG          0.12      chrX  ...
# 1         43.09        [257, 0, 6, 0]         AG          0.02      chrX  ...
# 2         44.30        [288, 0, 3, 0]         AG          0.01      chrX  ...
# 3         46.03        [267, 0, 5, 0]         AG          0.02      chrX  ...
# 4         46.60        [263, 0, 8, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 23815     45.73         [0, 0, 86, 0]         AG          1.00      chr8  ...
# 23816     45.86        [20, 0, 58, 0]         AG          0.74      chr8  ...
# 23817     44.97        [77, 0, 13, 0]         AG          0.14      chr8  ...
# 23818     48.87        [0, 0, 665, 0]         AG          1.00      chr8  ...
# 23819     46.25       [57, 0, 239, 0]         AG          0.81      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            36   41.00        [36, 0, 0, 0]         -
# 1            1            34   41.35        [34, 0, 0, 0]         -
# 2            1            37   41.11        [37, 0, 0, 0]         -
# 3            1            36   42.69        [36, 0, 0, 0]         -
# 4            1            34   40.47        [34, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 23815        0            34   38.82        [0, 0, 34, 0]        AG
# 23816        0            35   39.86       [14, 0, 21, 0]        AG
# 23817        0            36   42.17       [19, 0, 17, 0]        AG
# 23818        1            34   40.50        [0, 0, 34, 0]        AG
# 23819        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 23815       1.00  Not-Editing             0
# 23816       0.60  Not-Editing             0
# 23817       0.47  Not-Editing             0
# 23818       1.00  Not-Editing             0
# 23819       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT2.WT.outTable_572868058.gz
# 1      HEK293T_WT2.WT.outTable_572868058.gz
# 2      HEK293T_WT2.WT.outTable_572868058.gz
# 3      HEK293T_WT2.WT.outTable_572868058.gz
# 4      HEK293T_WT2.WT.outTable_572868058.gz
# ...                                     ...
# 23815  HEK293T_WT2.WT.outTable_572868058.gz
# 23816  HEK293T_WT2.WT.outTable_572868058.gz
# 23817  HEK293T_WT2.WT.outTable_572868058.gz
# 23818  HEK293T_WT2.WT.outTable_572868058.gz
# 23819  HEK293T_WT2.WT.outTable_572868058.gz
#
#                                   ko_sample
# 0      HEK293T_KO2.KO.outTable_364841872.gz
# 1      HEK293T_KO2.KO.outTable_364841872.gz
# 2      HEK293T_KO2.KO.outTable_364841872.gz
# 3      HEK293T_KO2.KO.outTable_364841872.gz
# 4      HEK293T_KO2.KO.outTable_364841872.gz
# ...                                     ...
# 23815  HEK293T_KO2.KO.outTable_364841872.gz
# 23816  HEK293T_KO2.KO.outTable_364841872.gz
# 23817  HEK293T_KO2.KO.outTable_364841872.gz
# 23818  HEK293T_KO2.KO.outTable_364841872.gz
# 23819  HEK293T_KO2.KO.outTable_364841872.gz
#
# [23820 rows x 31 columns]
# Class        Class_binary
# Editing      1               20360
# Not-Editing  0                3460
# dtype: int64
# Save to disk bonafide final: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT2.WT.outTable_572868058.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_final.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              272
# 1          chrX       299513            A          1              263
# 2          chrX       299540            A          1              291
# 3          chrX       299559            A          1              272
# 4          chrX       299568            A          1              271
# ...         ...          ...          ...        ...              ...
# 23815      chr8    144454002            A          0               86
# 23816      chr8    144457131            A          0               78
# 23817      chr8    144458636            A          0               90
# 23818      chr8    144468337            A          1              665
# 23819      chr8    144931953            A          0              296
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         43.13       [239, 0, 33, 0]         AG          0.12      chrX  ...
# 1         43.09        [257, 0, 6, 0]         AG          0.02      chrX  ...
# 2         44.30        [288, 0, 3, 0]         AG          0.01      chrX  ...
# 3         46.03        [267, 0, 5, 0]         AG          0.02      chrX  ...
# 4         46.60        [263, 0, 8, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 23815     45.73         [0, 0, 86, 0]         AG          1.00      chr8  ...
# 23816     45.86        [20, 0, 58, 0]         AG          0.74      chr8  ...
# 23817     44.97        [77, 0, 13, 0]         AG          0.14      chr8  ...
# 23818     48.87        [0, 0, 665, 0]         AG          1.00      chr8  ...
# 23819     46.25       [57, 0, 239, 0]         AG          0.81      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            36   41.00        [36, 0, 0, 0]         -
# 1            1            34   41.35        [34, 0, 0, 0]         -
# 2            1            37   41.11        [37, 0, 0, 0]         -
# 3            1            36   42.69        [36, 0, 0, 0]         -
# 4            1            34   40.47        [34, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 23815        0            34   38.82        [0, 0, 34, 0]        AG
# 23816        0            35   39.86       [14, 0, 21, 0]        AG
# 23817        0            36   42.17       [19, 0, 17, 0]        AG
# 23818        1            34   40.50        [0, 0, 34, 0]        AG
# 23819        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 23815       1.00  Not-Editing             0
# 23816       0.60  Not-Editing             0
# 23817       0.47  Not-Editing             0
# 23818       1.00  Not-Editing             0
# 23819       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT2.WT.outTable_572868058.gz
# 1      HEK293T_WT2.WT.outTable_572868058.gz
# 2      HEK293T_WT2.WT.outTable_572868058.gz
# 3      HEK293T_WT2.WT.outTable_572868058.gz
# 4      HEK293T_WT2.WT.outTable_572868058.gz
# ...                                     ...
# 23815  HEK293T_WT2.WT.outTable_572868058.gz
# 23816  HEK293T_WT2.WT.outTable_572868058.gz
# 23817  HEK293T_WT2.WT.outTable_572868058.gz
# 23818  HEK293T_WT2.WT.outTable_572868058.gz
# 23819  HEK293T_WT2.WT.outTable_572868058.gz
#
#                                   ko_sample
# 0      HEK293T_KO2.KO.outTable_364841872.gz
# 1      HEK293T_KO2.KO.outTable_364841872.gz
# 2      HEK293T_KO2.KO.outTable_364841872.gz
# 3      HEK293T_KO2.KO.outTable_364841872.gz
# 4      HEK293T_KO2.KO.outTable_364841872.gz
# ...                                     ...
# 23815  HEK293T_KO2.KO.outTable_364841872.gz
# 23816  HEK293T_KO2.KO.outTable_364841872.gz
# 23817  HEK293T_KO2.KO.outTable_364841872.gz
# 23818  HEK293T_KO2.KO.outTable_364841872.gz
# 23819  HEK293T_KO2.KO.outTable_364841872.gz
#
# [23820 rows x 31 columns]

# %%
# couple 6 (KO3 vs WT3)
wt_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_WT3.WT/DnaRna_110067244/outTable_110067244.gz"
ko_fp = "/lustre/bio_running/A_to_I_Pietro/model_test_2023/hek_pecori/HEK293T_KO3.KO/DnaRna_597789462/outTable_597789462.gz"
wt_name = "HEK293T_WT3.WT" + f".{os.path.basename(wt_fp)}"
ko_name = "HEK293T_KO3.KO" + f".{os.path.basename(ko_fp)}"
print(wt_name)
print(ko_name)

couple6 = extract_bonafide(wt_fp, ko_fp, wt_name, ko_name, wgs_fp)
couple6
# Out:
# HEK293T_WT3.WT.outTable_110067244.gz
# HEK293T_KO3.KO.outTable_597789462.gz
# Evaluated sites: 0
# Evaluated sites: 50000000
# Evaluated sites: 100000000
# Evaluated sites: 150000000
# Iteration on tabix outTables finished. Elapsed time:  0:05:45.616095
# Save to disk bonafide candidates: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT3.WT.outTable_110067244.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_candidates.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299431            A          1              229
# 1          chrX       299510            A          1              144
# 2          chrX       299548            A          1              133
# 3          chrX       299562            A          1              135
# 4          chrX       299568            A          1              137
# ...         ...          ...          ...        ...              ...
# 26412      chr8    144974950            A          0              230
# 26413      chr8    144977014            A          0              185
# 26414      chr8    144977019            A          0              179
# 26415      chr8    144977023            A          0              175
# 26416      chr8    144977113            A          0              201
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         49.54        [226, 0, 3, 0]         AG          0.01      chrX  ...
# 1         45.65       [121, 0, 23, 0]         AG          0.16      chrX  ...
# 2         47.57        [67, 0, 66, 0]         AG          0.50      chrX  ...
# 3         52.17        [131, 0, 4, 0]         AG          0.03      chrX  ...
# 4         52.31        [132, 0, 5, 0]         AG          0.04      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 26412     46.54        [223, 0, 7, 0]         AG          0.03      chr8  ...
# 26413     48.07        [180, 0, 5, 0]         AG          0.03      chr8  ...
# 26414     48.44        [173, 0, 6, 0]         AG          0.03      chr8  ...
# 26415     48.76        [169, 0, 6, 0]         AG          0.03      chr8  ...
# 26416     46.76        [198, 0, 3, 0]         AG          0.01      chr8  ...
#
#        ko_Frequency gRegion  gPosition  gReference  gStrand gCoverage-q30  \
# 0              0.00    chrX     299431           A        1            35
# 1              0.00    chrX     299510           A        1            36
# 2              0.06    chrX     299548           A        1            36
# 3              0.01    chrX     299562           A        1            34
# 4              0.00    chrX     299568           A        1            34
# ...             ...     ...        ...         ...      ...           ...
# 26412          0.00    chr8  144974950           A        0            45
# 26413          0.00    chr8  144977014           A        0            40
# 26414          0.00    chr8  144977019           A        0            42
# 26415          0.00    chr8  144977023           A        0            39
# 26416          0.00    chr8  144977113           A        0            35
#
#       gMeanQ  gBaseCount[A,C,G,T] gAllSubs  gFrequency
# 0      40.20        [35, 0, 0, 0]        -         0.0
# 1      41.00        [36, 0, 0, 0]        -         0.0
# 2      42.81        [36, 0, 0, 0]        -         0.0
# 3      42.56        [34, 0, 0, 0]        -         0.0
# 4      40.47        [34, 0, 0, 0]        -         0.0
# ...      ...                  ...      ...         ...
# 26412  40.98        [45, 0, 0, 0]        -         0.0
# 26413  41.20        [40, 0, 0, 0]        -         0.0
# 26414  41.57        [42, 0, 0, 0]        -         0.0
# 26415  42.26        [39, 0, 0, 0]        -         0.0
# 26416  39.77        [35, 0, 0, 0]        -         0.0
#
# [26417 rows x 27 columns]
# Pos: (16835, 29)
# Neg: (3229, 29)
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299431            A          1              229
# 1          chrX       299510            A          1              144
# 2          chrX       299568            A          1              137
# 3          chrX       299572            A          1              137
# 4          chrX       299574            A          1              133
# ...         ...          ...          ...        ...              ...
# 20059      chr8    144425879            A          0              158
# 20060      chr8    144440133            A          0              509
# 20061      chr8    144451628            A          0              220
# 20062      chr8    144468337            A          1              422
# 20063      chr8    144931953            A          0              163
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         49.54        [226, 0, 3, 0]         AG          0.01      chrX  ...
# 1         45.65       [121, 0, 23, 0]         AG          0.16      chrX  ...
# 2         52.31        [132, 0, 5, 0]         AG          0.04      chrX  ...
# 3         51.77       [125, 0, 12, 0]         AG          0.09      chrX  ...
# 4         51.55        [130, 0, 3, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 20059     40.91       [124, 0, 34, 0]         AG          0.22      chr8  ...
# 20060     47.75        [1, 0, 508, 0]         AG          1.00      chr8  ...
# 20061     49.34       [169, 0, 51, 0]         AG          0.23      chr8  ...
# 20062     46.23        [0, 0, 422, 0]         AG          1.00      chr8  ...
# 20063     50.32       [39, 0, 124, 0]         AG          0.76      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            35   40.20        [35, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   40.47        [34, 0, 0, 0]         -
# 3            1            40   42.10        [40, 0, 0, 0]         -
# 4            1            37   42.43        [37, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 20059        0            39   41.62       [28, 0, 11, 0]        AG
# 20060        0            59   40.75        [0, 0, 59, 0]        AG
# 20061        0            43   40.12        [35, 0, 8, 0]        AG
# 20062        1            34   40.50        [0, 0, 34, 0]        AG
# 20063        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 20059       0.28  Not-Editing             0
# 20060       1.00  Not-Editing             0
# 20061       0.19  Not-Editing             0
# 20062       1.00  Not-Editing             0
# 20063       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT3.WT.outTable_110067244.gz
# 1      HEK293T_WT3.WT.outTable_110067244.gz
# 2      HEK293T_WT3.WT.outTable_110067244.gz
# 3      HEK293T_WT3.WT.outTable_110067244.gz
# 4      HEK293T_WT3.WT.outTable_110067244.gz
# ...                                     ...
# 20059  HEK293T_WT3.WT.outTable_110067244.gz
# 20060  HEK293T_WT3.WT.outTable_110067244.gz
# 20061  HEK293T_WT3.WT.outTable_110067244.gz
# 20062  HEK293T_WT3.WT.outTable_110067244.gz
# 20063  HEK293T_WT3.WT.outTable_110067244.gz
#
#                                   ko_sample
# 0      HEK293T_KO3.KO.outTable_597789462.gz
# 1      HEK293T_KO3.KO.outTable_597789462.gz
# 2      HEK293T_KO3.KO.outTable_597789462.gz
# 3      HEK293T_KO3.KO.outTable_597789462.gz
# 4      HEK293T_KO3.KO.outTable_597789462.gz
# ...                                     ...
# 20059  HEK293T_KO3.KO.outTable_597789462.gz
# 20060  HEK293T_KO3.KO.outTable_597789462.gz
# 20061  HEK293T_KO3.KO.outTable_597789462.gz
# 20062  HEK293T_KO3.KO.outTable_597789462.gz
# 20063  HEK293T_KO3.KO.outTable_597789462.gz
#
# [20064 rows x 31 columns]
# Class        Class_binary
# Editing      1               16835
# Not-Editing  0                3229
# dtype: int64
# Save to disk bonafide final: /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT3.WT.outTable_110067244.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_final.tsv
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299431            A          1              229
# 1          chrX       299510            A          1              144
# 2          chrX       299568            A          1              137
# 3          chrX       299572            A          1              137
# 4          chrX       299574            A          1              133
# ...         ...          ...          ...        ...              ...
# 20059      chr8    144425879            A          0              158
# 20060      chr8    144440133            A          0              509
# 20061      chr8    144451628            A          0              220
# 20062      chr8    144468337            A          1              422
# 20063      chr8    144931953            A          0              163
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         49.54        [226, 0, 3, 0]         AG          0.01      chrX  ...
# 1         45.65       [121, 0, 23, 0]         AG          0.16      chrX  ...
# 2         52.31        [132, 0, 5, 0]         AG          0.04      chrX  ...
# 3         51.77       [125, 0, 12, 0]         AG          0.09      chrX  ...
# 4         51.55        [130, 0, 3, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 20059     40.91       [124, 0, 34, 0]         AG          0.22      chr8  ...
# 20060     47.75        [1, 0, 508, 0]         AG          1.00      chr8  ...
# 20061     49.34       [169, 0, 51, 0]         AG          0.23      chr8  ...
# 20062     46.23        [0, 0, 422, 0]         AG          1.00      chr8  ...
# 20063     50.32       [39, 0, 124, 0]         AG          0.76      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            35   40.20        [35, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   40.47        [34, 0, 0, 0]         -
# 3            1            40   42.10        [40, 0, 0, 0]         -
# 4            1            37   42.43        [37, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 20059        0            39   41.62       [28, 0, 11, 0]        AG
# 20060        0            59   40.75        [0, 0, 59, 0]        AG
# 20061        0            43   40.12        [35, 0, 8, 0]        AG
# 20062        1            34   40.50        [0, 0, 34, 0]        AG
# 20063        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 20059       0.28  Not-Editing             0
# 20060       1.00  Not-Editing             0
# 20061       0.19  Not-Editing             0
# 20062       1.00  Not-Editing             0
# 20063       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT3.WT.outTable_110067244.gz
# 1      HEK293T_WT3.WT.outTable_110067244.gz
# 2      HEK293T_WT3.WT.outTable_110067244.gz
# 3      HEK293T_WT3.WT.outTable_110067244.gz
# 4      HEK293T_WT3.WT.outTable_110067244.gz
# ...                                     ...
# 20059  HEK293T_WT3.WT.outTable_110067244.gz
# 20060  HEK293T_WT3.WT.outTable_110067244.gz
# 20061  HEK293T_WT3.WT.outTable_110067244.gz
# 20062  HEK293T_WT3.WT.outTable_110067244.gz
# 20063  HEK293T_WT3.WT.outTable_110067244.gz
#
#                                   ko_sample
# 0      HEK293T_KO3.KO.outTable_597789462.gz
# 1      HEK293T_KO3.KO.outTable_597789462.gz
# 2      HEK293T_KO3.KO.outTable_597789462.gz
# 3      HEK293T_KO3.KO.outTable_597789462.gz
# 4      HEK293T_KO3.KO.outTable_597789462.gz
# ...                                     ...
# 20059  HEK293T_KO3.KO.outTable_597789462.gz
# 20060  HEK293T_KO3.KO.outTable_597789462.gz
# 20061  HEK293T_KO3.KO.outTable_597789462.gz
# 20062  HEK293T_KO3.KO.outTable_597789462.gz
# 20063  HEK293T_KO3.KO.outTable_597789462.gz
#
# [20064 rows x 31 columns]

# %%
# concat into a uniq dataset
bonafide_final_full = pd.concat([couple1, couple2, couple3, couple4, couple5, couple6])
bonafide_final_full
# Out:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              383
# 1          chrX       299510            A          1              388
# 2          chrX       299513            A          1              385
# 3          chrX       299540            A          1              365
# 4          chrX       299543            A          1              368
# ...         ...          ...          ...        ...              ...
# 20059      chr8    144425879            A          0              158
# 20060      chr8    144440133            A          0              509
# 20061      chr8    144451628            A          0              220
# 20062      chr8    144468337            A          1              422
# 20063      chr8    144931953            A          0              163
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.11       [372, 0, 11, 0]         AG          0.03      chrX  ...
# 1         45.23      [281, 0, 107, 0]         AG          0.28      chrX  ...
# 2         45.16        [381, 0, 4, 0]         AG          0.01      chrX  ...
# 3         47.04        [359, 0, 6, 0]         AG          0.02      chrX  ...
# 4         47.25        [365, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 20059     40.91       [124, 0, 34, 0]         AG          0.22      chr8  ...
# 20060     47.75        [1, 0, 508, 0]         AG          1.00      chr8  ...
# 20061     49.34       [169, 0, 51, 0]         AG          0.23      chr8  ...
# 20062     46.23        [0, 0, 422, 0]         AG          1.00      chr8  ...
# 20063     50.32       [39, 0, 124, 0]         AG          0.76      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 20059        0            39   41.62       [28, 0, 11, 0]        AG
# 20060        0            59   40.75        [0, 0, 59, 0]        AG
# 20061        0            43   40.12        [35, 0, 8, 0]        AG
# 20062        1            34   40.50        [0, 0, 34, 0]        AG
# 20063        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 20059       0.28  Not-Editing             0
# 20060       1.00  Not-Editing             0
# 20061       0.19  Not-Editing             0
# 20062       1.00  Not-Editing             0
# 20063       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 2      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 3      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 4      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# ...                                              ...
# 20059           HEK293T_WT3.WT.outTable_110067244.gz
# 20060           HEK293T_WT3.WT.outTable_110067244.gz
# 20061           HEK293T_WT3.WT.outTable_110067244.gz
# 20062           HEK293T_WT3.WT.outTable_110067244.gz
# 20063           HEK293T_WT3.WT.outTable_110067244.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 20059  HEK293T_KO3.KO.outTable_597789462.gz
# 20060  HEK293T_KO3.KO.outTable_597789462.gz
# 20061  HEK293T_KO3.KO.outTable_597789462.gz
# 20062  HEK293T_KO3.KO.outTable_597789462.gz
# 20063  HEK293T_KO3.KO.outTable_597789462.gz
#
# [185747 rows x 31 columns]

# %%
# save to disk bonafide final
output_file = os.path.join(output_folder, "bonafide_final_MERGED.tsv")
print("Save to disk bonafide final MERGED (all couples):", output_file)
bonafide_final_full.to_csv(output_file, sep="\t", index=None)
# Out:
# Save to disk bonafide final MERGED (all couples): /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/bonafide_final_MERGED.tsv

# %%
bonafide_final_full.Class.value_counts()
# Out:
# Editing        165540
# Not-Editing     20207
# Name: Class, dtype: int64

# %%
bonafide_final_full.groupby("Class")[["wt_Frequency", "ko_Frequency", "gFrequency"]].describe().T
# Out:
# Class                     Editing   Not-Editing
# wt_Frequency count  165540.000000  20207.000000
#              mean        0.068067      0.773307
#              std         0.105301      0.293680
#              min         0.010000      0.010000
#              25%         0.010000      0.540000
#              50%         0.030000      1.000000
#              75%         0.070000      1.000000
#              max         1.000000      1.000000
# ko_Frequency count  165540.000000  20207.000000
#              mean        0.000000      0.778779
#              std         0.000000      0.300289
#              min         0.000000      0.010000
#              25%         0.000000      0.540000
#              50%         0.000000      1.000000
#              75%         0.000000      1.000000
#              max         0.000000      1.000000
# gFrequency   count  165540.000000  20207.000000
#              mean        0.000000      0.759843
#              std         0.000000      0.301888
#              min         0.000000      0.010000
#              25%         0.000000      0.530000
#              50%         0.000000      1.000000
#              75%         0.000000      1.000000
#              max         0.000000      1.000000
