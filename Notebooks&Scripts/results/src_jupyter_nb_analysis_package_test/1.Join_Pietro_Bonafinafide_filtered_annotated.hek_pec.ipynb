# %%
##################
### Author: Adriano Fonzino. email: adriano.fonzino@uniba.it
##################
import os
import pandas as pd
import numpy as np


# define util function for downstream analysis
def join_bonafides(bonafide_fp, bonafide_anno_filt):
    ### function to join bonafide with reditools info with bonafide with anno and filtered 
    ### NON-REP only Refseq
    # load bonafide with reditools alignment profiles/data
    bonafide = pd.read_table(bonafide_fp)
    print("Bonafide not-filted with REDItools info:")
    display(bonafide)
    # load annotated table filtered for positives NON-REP being in Refseq
    bonafide_anno_filt = pd.read_table(bonafide_anno_filt_fp)
    print("Bonafide annotated and filtered (NON-REP only Refseq):")
    display(bonafide_anno_filt)
    # inner join between bonafide with and without annotation/filtering
    joined = pd.merge(bonafide, bonafide_anno_filt, 
                      left_on=["wt_Region", "wt_Position"],
                      right_on=["Region", "Position"], how="inner")
    print("Common sites annotated with REDItools info:")
    display(joined)
    # print not common site (not Refseq)
    left_join = pd.merge(bonafide, bonafide_anno_filt, 
                        left_on=["wt_Region", "wt_Position"],
                        right_on=["Region", "Position"], how="left")
    print("Discared sites (via left join):")
    display(left_join[left_join["Class_y"].isna()])
    output_file = bonafide_fp + ".anno.filt_refseq.tsv"
    print("Save on disk joined with annotation and filtering to :", output_file)
    joined.to_csv(output_file, index=None, sep="\t")

    return joined

# %% [markdown]
# ## Hek Pec.

# %%
### Couple 1
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK293T/outTable_530905096_outTable_905657585_bona_fide_sites_2.tsv"

couple1_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              383
# 1          chrX       299510            A          1              388
# 2          chrX       299513            A          1              385
# 3          chrX       299540            A          1              365
# 4          chrX       299543            A          1              368
# ...         ...          ...          ...        ...              ...
# 39484      chr8    144451628            A          0              299
# 39485      chr8    144454002            A          0               59
# 39486      chr8    144460013            A          0               57
# 39487      chr8    144468337            A          1              420
# 39488      chr8    144931953            A          0              813
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.11       [372, 0, 11, 0]         AG          0.03      chrX  ...
# 1         45.23      [281, 0, 107, 0]         AG          0.28      chrX  ...
# 2         45.16        [381, 0, 4, 0]         AG          0.01      chrX  ...
# 3         47.04        [359, 0, 6, 0]         AG          0.02      chrX  ...
# 4         47.25        [365, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 39484     51.34       [244, 0, 55, 0]         AG          0.18      chr8  ...
# 39485     45.15         [0, 0, 59, 0]         AG          1.00      chr8  ...
# 39486     51.93        [41, 0, 16, 0]         AG          0.28      chr8  ...
# 39487     48.59        [0, 0, 420, 0]         AG          1.00      chr8  ...
# 39488     48.47      [191, 0, 622, 0]         AG          0.77      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 39484        0            43   40.12        [35, 0, 8, 0]        AG
# 39485        0            34   38.82        [0, 0, 34, 0]        AG
# 39486        0            33   39.91       [20, 0, 13, 0]        AG
# 39487        1            34   40.50        [0, 0, 34, 0]        AG
# 39488        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 39484       0.19  Not-Editing             0
# 39485       1.00  Not-Editing             0
# 39486       0.39  Not-Editing             0
# 39487       1.00  Not-Editing             0
# 39488       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 2      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 3      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 4      HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# ...                                              ...
# 39484  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39485  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39486  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39487  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39488  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 39484  HEK293T_KO1.KO.outTable_905657585.gz
# 39485  HEK293T_KO1.KO.outTable_905657585.gz
# 39486  HEK293T_KO1.KO.outTable_905657585.gz
# 39487  HEK293T_KO1.KO.outTable_905657585.gz
# 39488  HEK293T_KO1.KO.outTable_905657585.gz
#
# [39489 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0       chr1      16996      0        -        -       transcript,exon
# 1       chr1     632061      1        -        -       exon,transcript
# 2       chr1     926428      0        -        -            transcript
# 3       chr1     926744      0        -        -            transcript
# 4       chr1     953259      0        -        -   transcript,CDS,exon
# ...      ...        ...    ...      ...      ...                   ...
# 39392   chrX  154512401      1     SINE   AluSz6   transcript,CDS,exon
# 39393   chrX  154777624      1        -        -  transcript,3UTR,exon
# 39394   chrX  155055080      1        -        -  transcript,exon,3UTR
# 39395   chrX  156023071      0        -        -       exon,transcript
# 39396   chrX  156023093      0        -        -       exon,transcript
#
#       RefSeq-Reg
# 0         WASH7P
# 1       MTCO1P12
# 2         SAMD11
# 3         SAMD11
# 4          NOC2L
# ...          ...
# 39392      FAM3A
# 39393       DKC1
# 39394     FUNDC2
# 39395     WASH6P
# 39396     WASH6P
#
# [39397 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              383
# 1          chrX       299510            A          1              388
# 2          chrX       299513            A          1              385
# 3          chrX       299540            A          1              365
# 4          chrX       299543            A          1              368
# ...         ...          ...          ...        ...              ...
# 39392      chr8    144451628            A          0              299
# 39393      chr8    144454002            A          0               59
# 39394      chr8    144460013            A          0               57
# 39395      chr8    144468337            A          1              420
# 39396      chr8    144931953            A          0              813
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.11       [372, 0, 11, 0]         AG          0.03      chrX  ...
# 1         45.23      [281, 0, 107, 0]         AG          0.28      chrX  ...
# 2         45.16        [381, 0, 4, 0]         AG          0.01      chrX  ...
# 3         47.04        [359, 0, 6, 0]         AG          0.02      chrX  ...
# 4         47.25        [365, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 39392     51.34       [244, 0, 55, 0]         AG          0.18      chr8  ...
# 39393     45.15         [0, 0, 59, 0]         AG          1.00      chr8  ...
# 39394     51.93        [41, 0, 16, 0]         AG          0.28      chr8  ...
# 39395     48.59        [0, 0, 420, 0]         AG          1.00      chr8  ...
# 39396     48.47      [191, 0, 622, 0]         AG          0.77      chr8  ...
#
#        Class_binary                                      wt_sample  \
# 0                 1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1                 1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 2                 1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 3                 1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 4                 1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# ...             ...                                            ...
# 39392             0  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39393             0  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39394             0  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39395             0  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 39396             0  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
#
#                                   ko_sample  Region   Position Class_y  \
# 0      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299493       1
# 1      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299510       1
# 2      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299513       1
# 3      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299540       1
# 4      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299543       1
# ...                                     ...     ...        ...     ...
# 39392  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144451628       0
# 39393  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144454002       0
# 39394  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144460013       0
# 39395  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144468337       0
# 39396  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144931953       0
#
#       RMSK-Rep  RMSK-Reg             RefSeq-Rep            RefSeq-Reg
# 0         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 1         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 2         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 3         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 4         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# ...        ...       ...                    ...                   ...
# 39392        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 39393        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 39394        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 39395        -         -    transcript,CDS,exon                 KIFC2
# 39396        -         -    exon,transcript,CDS                 ZNF16
#
# [39397 rows x 38 columns]
# Discared sites (via left join):
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 1020       chrX    100842937            A          1              373
# 1130       chrX    101343611            A          0              292
# 1750      chr13     52455105            A          0              217
# 1847      chr12      3040871            A          1              160
# 3716      chr11     33073863            A          1              205
# ...         ...          ...          ...        ...              ...
# 35299      chr8     29061325            A          1              258
# 35300      chr8     29063918            A          1              251
# 35301      chr8     29063919            A          1              249
# 35609      chr8     51899504            A          1              333
# 35610      chr8     51899829            A          1              245
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 1020      47.42        [369, 0, 4, 0]         AG          0.01      chrX  ...
# 1130      46.29        [289, 0, 3, 0]         AG          0.01      chrX  ...
# 1750      42.74        [214, 0, 3, 0]         AG          0.01     chr13  ...
# 1847      52.64        [157, 0, 3, 0]         AG          0.02     chr12  ...
# 3716      53.91       [171, 0, 34, 0]         AG          0.17     chr11  ...
# ...         ...                   ...        ...           ...       ...  ...
# 35299     47.03        [255, 0, 3, 0]         AG          0.01      chr8  ...
# 35300     45.07       [235, 0, 16, 0]         AG          0.06      chr8  ...
# 35301     45.51        [246, 0, 3, 0]         AG          0.01      chr8  ...
# 35609     46.92        [327, 0, 6, 0]         AG          0.02      chr8  ...
# 35610     46.17        [242, 0, 3, 0]         AG          0.01      chr8  ...
#
#        Class_binary                                      wt_sample  \
# 1020              1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1130              1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1750              1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 1847              1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 3716              1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# ...             ...                                            ...
# 35299             1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 35300             1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 35301             1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 35609             1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
# 35610             1  HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz
#
#                                   ko_sample  Region  Position Class_y  \
# 1020   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 1130   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 1750   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 1847   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 3716   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# ...                                     ...     ...       ...     ...
# 35299  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 35300  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 35301  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 35609  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 35610  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
#
#       RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 1020       NaN       NaN        NaN         NaN
# 1130       NaN       NaN        NaN         NaN
# 1750       NaN       NaN        NaN         NaN
# 1847       NaN       NaN        NaN         NaN
# 3716       NaN       NaN        NaN         NaN
# ...        ...       ...        ...         ...
# 35299      NaN       NaN        NaN         NaN
# 35300      NaN       NaN        NaN         NaN
# 35301      NaN       NaN        NaN         NaN
# 35609      NaN       NaN        NaN         NaN
# 35610      NaN       NaN        NaN         NaN
#
# [92 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_1.OvE.outTable_530905096.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 2
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK293T/outTable_814257267_outTable_364841872_bona_fide_sites_2.tsv"

couple2_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              324
# 1          chrX       299510            A          1              318
# 2          chrX       299513            A          1              314
# 3          chrX       299543            A          1              303
# 4          chrX       299551            A          1              288
# ...         ...          ...          ...        ...              ...
# 37478      chr8    144451628            A          0              276
# 37479      chr8    144457131            A          0               90
# 37480      chr8    144458636            A          0               95
# 37481      chr8    144468337            A          1              396
# 37482      chr8    144931953            A          0              797
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         45.15        [320, 0, 4, 0]         AG          0.01      chrX  ...
# 1         45.16       [236, 0, 82, 0]         AG          0.26      chrX  ...
# 2         45.80        [305, 0, 9, 0]         AG          0.03      chrX  ...
# 3         45.42        [294, 0, 9, 0]         AG          0.03      chrX  ...
# 4         47.07        [283, 0, 5, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 37478     48.17       [219, 0, 57, 0]         AG          0.21      chr8  ...
# 37479     46.32        [11, 0, 79, 0]         AG          0.88      chr8  ...
# 37480     51.41        [73, 0, 22, 0]         AG          0.23      chr8  ...
# 37481     49.43        [0, 0, 396, 0]         AG          1.00      chr8  ...
# 37482     47.27      [162, 0, 635, 0]         AG          0.80      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            39   42.33        [39, 0, 0, 0]         -
# 4            1            38   41.45        [38, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 37478        0            43   40.12        [35, 0, 8, 0]        AG
# 37479        0            35   39.86       [14, 0, 21, 0]        AG
# 37480        0            36   42.17       [19, 0, 17, 0]        AG
# 37481        1            34   40.50        [0, 0, 34, 0]        AG
# 37482        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 37478       0.19  Not-Editing             0
# 37479       0.60  Not-Editing             0
# 37480       0.47  Not-Editing             0
# 37481       1.00  Not-Editing             0
# 37482       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 1      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 2      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 4      HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# ...                                              ...
# 37478  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37479  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37480  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37481  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37482  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
#
#                                   ko_sample
# 0      HEK293T_KO2.KO.outTable_364841872.gz
# 1      HEK293T_KO2.KO.outTable_364841872.gz
# 2      HEK293T_KO2.KO.outTable_364841872.gz
# 3      HEK293T_KO2.KO.outTable_364841872.gz
# 4      HEK293T_KO2.KO.outTable_364841872.gz
# ...                                     ...
# 37478  HEK293T_KO2.KO.outTable_364841872.gz
# 37479  HEK293T_KO2.KO.outTable_364841872.gz
# 37480  HEK293T_KO2.KO.outTable_364841872.gz
# 37481  HEK293T_KO2.KO.outTable_364841872.gz
# 37482  HEK293T_KO2.KO.outTable_364841872.gz
#
# [37483 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0       chr1      14610      0        -        -       exon,transcript
# 1       chr1      16961      1        -        -       transcript,exon
# 2       chr1      16996      0        -        -       transcript,exon
# 3       chr1     729312      1        -        -       exon,transcript
# 4       chr1     753804      1     SINE    AluJo            transcript
# ...      ...        ...    ...      ...      ...                   ...
# 37410   chrX  154512401      1     SINE   AluSz6   transcript,CDS,exon
# 37411   chrX  155121871      1     SINE    AluJr  transcript,3UTR,exon
# 37412   chrX  155121872      1     SINE    AluJr  transcript,3UTR,exon
# 37413   chrX  156023071      0        -        -       exon,transcript
# 37414   chrX  156023093      0        -        -       exon,transcript
#
#          RefSeq-Reg
# 0            WASH7P
# 1            WASH7P
# 2            WASH7P
# 3      LOC100288069
# 4      LOC100288069
# ...             ...
# 37410         FAM3A
# 37411         BRCC3
# 37412         BRCC3
# 37413        WASH6P
# 37414        WASH6P
#
# [37415 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              324
# 1          chrX       299510            A          1              318
# 2          chrX       299513            A          1              314
# 3          chrX       299543            A          1              303
# 4          chrX       299551            A          1              288
# ...         ...          ...          ...        ...              ...
# 37410      chr8    144451628            A          0              276
# 37411      chr8    144457131            A          0               90
# 37412      chr8    144458636            A          0               95
# 37413      chr8    144468337            A          1              396
# 37414      chr8    144931953            A          0              797
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         45.15        [320, 0, 4, 0]         AG          0.01      chrX  ...
# 1         45.16       [236, 0, 82, 0]         AG          0.26      chrX  ...
# 2         45.80        [305, 0, 9, 0]         AG          0.03      chrX  ...
# 3         45.42        [294, 0, 9, 0]         AG          0.03      chrX  ...
# 4         47.07        [283, 0, 5, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 37410     48.17       [219, 0, 57, 0]         AG          0.21      chr8  ...
# 37411     46.32        [11, 0, 79, 0]         AG          0.88      chr8  ...
# 37412     51.41        [73, 0, 22, 0]         AG          0.23      chr8  ...
# 37413     49.43        [0, 0, 396, 0]         AG          1.00      chr8  ...
# 37414     47.27      [162, 0, 635, 0]         AG          0.80      chr8  ...
#
#        Class_binary                                      wt_sample  \
# 0                 1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 1                 1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 2                 1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3                 1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 4                 1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# ...             ...                                            ...
# 37410             0  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37411             0  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37412             0  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37413             0  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 37414             0  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
#
#                                   ko_sample  Region   Position Class_y  \
# 0      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299493       1
# 1      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299510       1
# 2      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299513       1
# 3      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299543       1
# 4      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299551       1
# ...                                     ...     ...        ...     ...
# 37410  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144451628       0
# 37411  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144457131       0
# 37412  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144458636       0
# 37413  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144468337       0
# 37414  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144931953       0
#
#       RMSK-Rep  RMSK-Reg             RefSeq-Rep            RefSeq-Reg
# 0         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 1         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 2         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 3         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 4         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# ...        ...       ...                    ...                   ...
# 37410        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 37411        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 37412        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 37413        -         -    transcript,CDS,exon                 KIFC2
# 37414        -         -    exon,transcript,CDS                 ZNF16
#
# [37415 rows x 38 columns]
# Discared sites (via left join):
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 2201      chr12     56731567            A          0              622
# 2202      chr12     56731568            A          0              664
# 3496      chr11     33073863            A          1              159
# 3497      chr11     33073882            A          1              179
# 3498      chr11     33073924            A          1              171
# ...         ...          ...          ...        ...              ...
# 31696      chr1    161422242            A          1              179
# 32473      chr1    243851376            A          1              239
# 32475      chr1    244849504            A          0              132
# 33186      chr8     29063918            A          1              218
# 33503      chr8     51900152            A          1              191
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 2201      44.49        [613, 0, 9, 0]         AG          0.01     chr12  ...
# 2202      44.12       [652, 0, 12, 0]         AG          0.02     chr12  ...
# 3496      51.98       [135, 0, 24, 0]         AG          0.15     chr11  ...
# 3497      47.34        [176, 0, 3, 0]         AG          0.02     chr11  ...
# 3498      50.06        [168, 0, 3, 0]         AG          0.02     chr11  ...
# ...         ...                   ...        ...           ...       ...  ...
# 31696     47.34        [175, 0, 4, 0]         AG          0.02      chr1  ...
# 32473     46.29        [235, 0, 4, 0]         AG          0.02      chr1  ...
# 32475     43.25        [129, 0, 3, 0]         AG          0.02      chr1  ...
# 33186     47.64        [209, 0, 9, 0]         AG          0.04      chr8  ...
# 33503     44.09        [188, 0, 3, 0]         AG          0.02      chr8  ...
#
#        Class_binary                                      wt_sample  \
# 2201              1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 2202              1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3496              1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3497              1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 3498              1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# ...             ...                                            ...
# 31696             1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 32473             1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 32475             1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 33186             1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
# 33503             1  HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz
#
#                                   ko_sample  Region  Position Class_y  \
# 2201   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 2202   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 3496   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 3497   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 3498   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# ...                                     ...     ...       ...     ...
# 31696  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 32473  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 32475  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 33186  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 33503  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
#
#       RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 2201       NaN       NaN        NaN         NaN
# 2202       NaN       NaN        NaN         NaN
# 3496       NaN       NaN        NaN         NaN
# 3497       NaN       NaN        NaN         NaN
# 3498       NaN       NaN        NaN         NaN
# ...        ...       ...        ...         ...
# 31696      NaN       NaN        NaN         NaN
# 32473      NaN       NaN        NaN         NaN
# 32475      NaN       NaN        NaN         NaN
# 33186      NaN       NaN        NaN         NaN
# 33503      NaN       NaN        NaN         NaN
#
# [68 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_2.OvE.outTable_814257267.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 3
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK293T/outTable_208420383_outTable_597789462_bona_fide_sites_2.tsv"

couple3_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              297
# 1          chrX       299513            A          1              292
# 2          chrX       299559            A          1              256
# 3          chrX       299568            A          1              262
# 4          chrX       299571            A          1              269
# ...         ...          ...          ...        ...              ...
# 35279      chr8    144458020            A          0               51
# 35280      chr8    144458072            A          0               52
# 35281      chr8    144468337            A          1              377
# 35282      chr8    144843461            A          1              122
# 35283      chr8    144931953            A          0              634
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.47       [222, 0, 75, 0]         AG          0.25      chrX  ...
# 1         46.71        [287, 0, 5, 0]         AG          0.02      chrX  ...
# 2         50.97        [251, 0, 5, 0]         AG          0.02      chrX  ...
# 3         51.22        [253, 0, 9, 0]         AG          0.03      chrX  ...
# 4         50.89        [262, 0, 7, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 35279     49.10         [0, 0, 51, 0]         AG          1.00      chr8  ...
# 35280     48.37         [0, 0, 52, 0]         AG          1.00      chr8  ...
# 35281     48.61        [0, 0, 377, 0]         AG          1.00      chr8  ...
# 35282     50.05        [24, 0, 98, 0]         AG          0.80      chr8  ...
# 35283     48.00      [118, 0, 516, 0]         AG          0.81      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            36   41.00        [36, 0, 0, 0]         -
# 1            1            34   41.35        [34, 0, 0, 0]         -
# 2            1            36   42.69        [36, 0, 0, 0]         -
# 3            1            34   40.47        [34, 0, 0, 0]         -
# 4            1            37   42.32        [37, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 35279        0            57   41.00        [0, 0, 57, 0]        AG
# 35280        0            48   41.33        [0, 0, 48, 0]        AG
# 35281        1            34   40.50        [0, 0, 34, 0]        AG
# 35282        1            46   40.46       [19, 0, 27, 0]        AG
# 35283        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 35279       1.00  Not-Editing             0
# 35280       1.00  Not-Editing             0
# 35281       1.00  Not-Editing             0
# 35282       0.59  Not-Editing             0
# 35283       0.64  Not-Editing             0
#
#                                            wt_sample  \
# 0      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 1      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 3      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 4      HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# ...                                              ...
# 35279  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35280  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35281  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35282  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35283  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
#
#                                   ko_sample
# 0      HEK293T_KO3.KO.outTable_597789462.gz
# 1      HEK293T_KO3.KO.outTable_597789462.gz
# 2      HEK293T_KO3.KO.outTable_597789462.gz
# 3      HEK293T_KO3.KO.outTable_597789462.gz
# 4      HEK293T_KO3.KO.outTable_597789462.gz
# ...                                     ...
# 35279  HEK293T_KO3.KO.outTable_597789462.gz
# 35280  HEK293T_KO3.KO.outTable_597789462.gz
# 35281  HEK293T_KO3.KO.outTable_597789462.gz
# 35282  HEK293T_KO3.KO.outTable_597789462.gz
# 35283  HEK293T_KO3.KO.outTable_597789462.gz
#
# [35284 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg           RefSeq-Rep  \
# 0       chr1      16996      0        -        -      transcript,exon
# 1       chr1     942472      1        -        -  transcript,CDS,exon
# 2       chr1     953259      0        -        -  transcript,CDS,exon
# 3       chr1    1009082      1     SINE    AluJb                    -
# 4       chr1    1009083      1     SINE    AluJb                    -
# ...      ...        ...    ...      ...      ...                  ...
# 35218   chrX  154512392      1     SINE   AluSz6  transcript,CDS,exon
# 35219   chrX  154512393      1     SINE   AluSz6  transcript,CDS,exon
# 35220   chrX  154512401      1     SINE   AluSz6  transcript,CDS,exon
# 35221   chrX  156023071      0        -        -      exon,transcript
# 35222   chrX  156023093      0        -        -      exon,transcript
#
#       RefSeq-Reg
# 0         WASH7P
# 1         SAMD11
# 2          NOC2L
# 3              -
# 4              -
# ...          ...
# 35218      FAM3A
# 35219      FAM3A
# 35220      FAM3A
# 35221     WASH6P
# 35222     WASH6P
#
# [35223 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              297
# 1          chrX       299513            A          1              292
# 2          chrX       299559            A          1              256
# 3          chrX       299568            A          1              262
# 4          chrX       299571            A          1              269
# ...         ...          ...          ...        ...              ...
# 35218      chr8    144458020            A          0               51
# 35219      chr8    144458072            A          0               52
# 35220      chr8    144468337            A          1              377
# 35221      chr8    144843461            A          1              122
# 35222      chr8    144931953            A          0              634
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         46.47       [222, 0, 75, 0]         AG          0.25      chrX  ...
# 1         46.71        [287, 0, 5, 0]         AG          0.02      chrX  ...
# 2         50.97        [251, 0, 5, 0]         AG          0.02      chrX  ...
# 3         51.22        [253, 0, 9, 0]         AG          0.03      chrX  ...
# 4         50.89        [262, 0, 7, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 35218     49.10         [0, 0, 51, 0]         AG          1.00      chr8  ...
# 35219     48.37         [0, 0, 52, 0]         AG          1.00      chr8  ...
# 35220     48.61        [0, 0, 377, 0]         AG          1.00      chr8  ...
# 35221     50.05        [24, 0, 98, 0]         AG          0.80      chr8  ...
# 35222     48.00      [118, 0, 516, 0]         AG          0.81      chr8  ...
#
#        Class_binary                                      wt_sample  \
# 0                 1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 1                 1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2                 1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 3                 1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 4                 1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# ...             ...                                            ...
# 35218             0  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35219             0  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35220             0  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35221             0  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 35222             0  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
#
#                                   ko_sample  Region   Position Class_y  \
# 0      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299510       1
# 1      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299513       1
# 2      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299559       1
# 3      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299568       1
# 4      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299571       1
# ...                                     ...     ...        ...     ...
# 35218  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144458020       0
# 35219  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144458072       0
# 35220  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144468337       0
# 35221  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144843461       0
# 35222  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144931953       0
#
#       RMSK-Rep  RMSK-Reg                       RefSeq-Rep  \
# 0         SINE    AluSx1             transcript,exon,3UTR
# 1         SINE    AluSx1             transcript,exon,3UTR
# 2         SINE    AluSx1             transcript,exon,3UTR
# 3         SINE    AluSx1             transcript,exon,3UTR
# 4         SINE    AluSx1             transcript,exon,3UTR
# ...        ...       ...                              ...
# 35218        -         -            transcript$transcript
# 35219        -         -            transcript$transcript
# 35220        -         -              transcript,CDS,exon
# 35221     SINE      AluY  transcript,exon,3UTR&transcript
# 35222        -         -              exon,transcript,CDS
#
#                  RefSeq-Reg
# 0                    PLCXD1
# 1                    PLCXD1
# 2                    PLCXD1
# 3                    PLCXD1
# 4                    PLCXD1
# ...                     ...
# 35218  CYHR1$LOC84773-CYHR1
# 35219  CYHR1$LOC84773-CYHR1
# 35220                 KIFC2
# 35221           ZNF7&COMMD5
# 35222                 ZNF16
#
# [35223 rows x 38 columns]
# Discared sites (via left join):
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 218        chrX      1383756            A          0              122
# 1073       chrX    101343610            A          0              298
# 2086      chr12     56731567            A          0              536
# 2087      chr12     56731568            A          0              569
# 2088      chr12     56731569            A          0              572
# ...         ...          ...          ...        ...              ...
# 30483      chr1    247190161            A          0              145
# 31115      chr8     29060517            A          1              211
# 31116      chr8     29063918            A          1              172
# 31117      chr8     29063962            A          1              201
# 31636      chr8    120523885            A          1              100
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 218       49.93        [119, 0, 3, 0]         AG          0.02      chrX  ...
# 1073      44.86        [294, 0, 4, 0]         AG          0.01      chrX  ...
# 2086      49.16        [533, 0, 3, 0]         AG          0.01     chr12  ...
# 2087      48.91        [560, 0, 9, 0]         AG          0.02     chr12  ...
# 2088      49.01        [568, 0, 4, 0]         AG          0.01     chr12  ...
# ...         ...                   ...        ...           ...       ...  ...
# 30483     47.55        [142, 0, 3, 0]         AG          0.02      chr1  ...
# 31115     45.70        [208, 0, 3, 0]         AG          0.01      chr8  ...
# 31116     49.68        [163, 0, 9, 0]         AG          0.05      chr8  ...
# 31117     48.54        [198, 0, 3, 0]         AG          0.01      chr8  ...
# 31636     49.45         [97, 0, 3, 0]         AG          0.03      chr8  ...
#
#        Class_binary                                      wt_sample  \
# 218               1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 1073              1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2086              1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2087              1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 2088              1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# ...             ...                                            ...
# 30483             1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 31115             1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 31116             1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 31117             1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
# 31636             1  HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz
#
#                                   ko_sample  Region  Position Class_y  \
# 218    HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 1073   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 2086   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 2087   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 2088   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# ...                                     ...     ...       ...     ...
# 30483  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 31115  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 31116  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 31117  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 31636  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
#
#       RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 218        NaN       NaN        NaN         NaN
# 1073       NaN       NaN        NaN         NaN
# 2086       NaN       NaN        NaN         NaN
# 2087       NaN       NaN        NaN         NaN
# 2088       NaN       NaN        NaN         NaN
# ...        ...       ...        ...         ...
# 30483      NaN       NaN        NaN         NaN
# 31115      NaN       NaN        NaN         NaN
# 31116      NaN       NaN        NaN         NaN
# 31117      NaN       NaN        NaN         NaN
# 31636      NaN       NaN        NaN         NaN
#
# [61 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK_ADAR1_p110_wt_3.OvE.outTable_208420383.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 4
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT1.WT.outTable_599710609.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK293T/outTable_599710609_outTable_905657585_bona_fide_sites_2.tsv"

couple4_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              371
# 1          chrX       299510            A          1              367
# 2          chrX       299513            A          1              367
# 3          chrX       299540            A          1              361
# 4          chrX       299543            A          1              367
# ...         ...          ...          ...        ...              ...
# 29602      chr8    144451628            A          0              550
# 29603      chr8    144454002            A          0              136
# 29604      chr8    144460013            A          0               82
# 29605      chr8    144468337            A          1              937
# 29606      chr8    144931953            A          0              402
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         44.71        [365, 0, 6, 0]         AG          0.02      chrX  ...
# 1         44.73       [332, 0, 35, 0]         AG          0.10      chrX  ...
# 2         44.63       [356, 0, 11, 0]         AG          0.03      chrX  ...
# 3         46.97        [356, 0, 5, 0]         AG          0.01      chrX  ...
# 4         46.54        [364, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 29602     47.21      [430, 0, 120, 0]         AG          0.22      chr8  ...
# 29603     43.96        [0, 0, 136, 0]         AG          1.00      chr8  ...
# 29604     52.49        [69, 0, 13, 0]         AG          0.16      chr8  ...
# 29605     47.23        [3, 0, 934, 0]         AG          1.00      chr8  ...
# 29606     47.19      [101, 0, 301, 0]         AG          0.75      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            30   40.47        [30, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   41.35        [34, 0, 0, 0]         -
# 3            1            37   41.11        [37, 0, 0, 0]         -
# 4            1            39   42.33        [39, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 29602        0            43   40.12        [35, 0, 8, 0]        AG
# 29603        0            34   38.82        [0, 0, 34, 0]        AG
# 29604        0            33   39.91       [20, 0, 13, 0]        AG
# 29605        1            34   40.50        [0, 0, 34, 0]        AG
# 29606        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 29602       0.19  Not-Editing             0
# 29603       1.00  Not-Editing             0
# 29604       0.39  Not-Editing             0
# 29605       1.00  Not-Editing             0
# 29606       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT1.WT.outTable_599710609.gz
# 1      HEK293T_WT1.WT.outTable_599710609.gz
# 2      HEK293T_WT1.WT.outTable_599710609.gz
# 3      HEK293T_WT1.WT.outTable_599710609.gz
# 4      HEK293T_WT1.WT.outTable_599710609.gz
# ...                                     ...
# 29602  HEK293T_WT1.WT.outTable_599710609.gz
# 29603  HEK293T_WT1.WT.outTable_599710609.gz
# 29604  HEK293T_WT1.WT.outTable_599710609.gz
# 29605  HEK293T_WT1.WT.outTable_599710609.gz
# 29606  HEK293T_WT1.WT.outTable_599710609.gz
#
#                                   ko_sample
# 0      HEK293T_KO1.KO.outTable_905657585.gz
# 1      HEK293T_KO1.KO.outTable_905657585.gz
# 2      HEK293T_KO1.KO.outTable_905657585.gz
# 3      HEK293T_KO1.KO.outTable_905657585.gz
# 4      HEK293T_KO1.KO.outTable_905657585.gz
# ...                                     ...
# 29602  HEK293T_KO1.KO.outTable_905657585.gz
# 29603  HEK293T_KO1.KO.outTable_905657585.gz
# 29604  HEK293T_KO1.KO.outTable_905657585.gz
# 29605  HEK293T_KO1.KO.outTable_905657585.gz
# 29606  HEK293T_KO1.KO.outTable_905657585.gz
#
# [29607 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg  \
# 0       chr1      14610      0        -        -
# 1       chr1      14818      1        -        -
# 2       chr1      16996      0        -        -
# 3       chr1     908025      0        -        -
# 4       chr1     918085      1        -        -
# ...      ...        ...    ...      ...      ...
# 29543   chrX  154531396      1        -        -
# 29544   chrX  154533043      1        -        -
# 29545   chrX  156023071      0        -        -
# 29546   chrX  156023093      0        -        -
# 29547   chrX  156025047      1        -        -
#
#                             RefSeq-Rep           RefSeq-Reg
# 0                      exon,transcript               WASH7P
# 1                      exon,transcript               WASH7P
# 2                      transcript,exon               WASH7P
# 3                      transcript,exon            LOC284600
# 4      transcript,exon&transcript,exon  LOC284600&LINC02593
# ...                                ...                  ...
# 29543             3UTR,exon,transcript                 G6PD
# 29544              transcript,CDS,exon                 G6PD
# 29545                  exon,transcript               WASH6P
# 29546                  exon,transcript               WASH6P
# 29547                  exon,transcript               WASH6P
#
# [29548 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299493            A          1              371
# 1          chrX       299510            A          1              367
# 2          chrX       299513            A          1              367
# 3          chrX       299540            A          1              361
# 4          chrX       299543            A          1              367
# ...         ...          ...          ...        ...              ...
# 29543      chr8    144451628            A          0              550
# 29544      chr8    144454002            A          0              136
# 29545      chr8    144460013            A          0               82
# 29546      chr8    144468337            A          1              937
# 29547      chr8    144931953            A          0              402
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         44.71        [365, 0, 6, 0]         AG          0.02      chrX  ...
# 1         44.73       [332, 0, 35, 0]         AG          0.10      chrX  ...
# 2         44.63       [356, 0, 11, 0]         AG          0.03      chrX  ...
# 3         46.97        [356, 0, 5, 0]         AG          0.01      chrX  ...
# 4         46.54        [364, 0, 3, 0]         AG          0.01      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 29543     47.21      [430, 0, 120, 0]         AG          0.22      chr8  ...
# 29544     43.96        [0, 0, 136, 0]         AG          1.00      chr8  ...
# 29545     52.49        [69, 0, 13, 0]         AG          0.16      chr8  ...
# 29546     47.23        [3, 0, 934, 0]         AG          1.00      chr8  ...
# 29547     47.19      [101, 0, 301, 0]         AG          0.75      chr8  ...
#
#        Class_binary                             wt_sample  \
# 0                 1  HEK293T_WT1.WT.outTable_599710609.gz
# 1                 1  HEK293T_WT1.WT.outTable_599710609.gz
# 2                 1  HEK293T_WT1.WT.outTable_599710609.gz
# 3                 1  HEK293T_WT1.WT.outTable_599710609.gz
# 4                 1  HEK293T_WT1.WT.outTable_599710609.gz
# ...             ...                                   ...
# 29543             0  HEK293T_WT1.WT.outTable_599710609.gz
# 29544             0  HEK293T_WT1.WT.outTable_599710609.gz
# 29545             0  HEK293T_WT1.WT.outTable_599710609.gz
# 29546             0  HEK293T_WT1.WT.outTable_599710609.gz
# 29547             0  HEK293T_WT1.WT.outTable_599710609.gz
#
#                                   ko_sample  Region   Position Class_y  \
# 0      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299493       1
# 1      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299510       1
# 2      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299513       1
# 3      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299540       1
# 4      HEK293T_KO1.KO.outTable_905657585.gz    chrX     299543       1
# ...                                     ...     ...        ...     ...
# 29543  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144451628       0
# 29544  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144454002       0
# 29545  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144460013       0
# 29546  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144468337       0
# 29547  HEK293T_KO1.KO.outTable_905657585.gz    chr8  144931953       0
#
#       RMSK-Rep  RMSK-Reg             RefSeq-Rep            RefSeq-Reg
# 0         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 1         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 2         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 3         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 4         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# ...        ...       ...                    ...                   ...
# 29543        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 29544        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 29545        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 29546        -         -    transcript,CDS,exon                 KIFC2
# 29547        -         -    exon,transcript,CDS                 ZNF16
#
# [29548 rows x 38 columns]
# Discared sites (via left join):
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 1412      chr12       911483            A          0              101
# 1579      chr12     50924901            A          1              172
# 1819      chr12     56731568            A          0              598
# 2831      chr11     33073863            A          1              266
# 2846      chr11     33075037            A          1              379
# 3011      chr11     64778665            A          0              653
# 3012      chr11     64778666            A          0              669
# 3013      chr11     64778697            A          0              591
# 8173      chr15     66335262            A          0              193
# 8174      chr15     66335395            A          0              316
# 8633      chr15    101769765            A          0              189
# 8634      chr15    101769768            A          0              189
# 8635      chr15    101769769            A          0              192
# 8636      chr15    101769777            A          0              207
# 8637      chr15    101769778            A          0              212
# 8638      chr15    101769787            A          0              231
# 8639      chr15    101769800            A          0              231
# 8640      chr15    101769801            A          0              232
# 8641      chr15    101769819            A          0              216
# 8642      chr15    101769820            A          0              218
# 9295      chr14    105417220            A          0              183
# 9986      chr19     11694853            A          0              180
# 9987      chr19     11694863            A          0              176
# 10606     chr19     34733381            A          0              121
# 11256     chr19     57819907            A          1              485
# 11475     chr19     57866748            A          1              287
# 11476     chr19     57866752            A          1              295
# 11500     chr19     57867215            A          1              368
# 11529     chr19     58558917            A          0              424
# 13839      chr4    173330971            A          0              332
# 14907     chr20     23637977            A          0              391
# 15345      chr9     35732642            A          1              472
# 15943      chr9    137129593            A          0              413
# 16245      chr7     44574398            A          0              235
# 16861      chr7    100867368            A          1              222
# 17161      chr7    128529747            A          0              209
# 17418      chr5      1597096            A          0              270
# 17881      chr5     71033180            A          0              158
# 17884      chr5     71034220            A          0              326
# 17885      chr5     71034228            A          0              363
# 19645      chr3     72977686            A          1              437
# 20220      chr3    186826847            A          0              440
# 20791      chr2     74832832            A          0              462
# 21376      chr2    176116552            A          1              464
# 21905      chr1       997459            A          0              507
# 23118      chr1     37802580            A          1              391
# 23806      chr1    110055000            A          1              214
# 23809      chr1    110057607            A          1              302
# 23810      chr1    110057688            A          1              274
# 23811      chr1    110058173            A          1              146
# 23836      chr1    112969405            A          1              201
# 24078      chr1    150611740            A          0              208
# 24421      chr1    161422213            A          1              152
# 25661      chr8     29056213            A          1              295
# 25662      chr8     29059649            A          1              331
# 25663      chr8     29062680            A          1              530
# 25664      chr8     29063908            A          1              460
# 25887      chr8     43130273            A          1              479
# 26234      chr8    144104185            A          0              322
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 1412      44.33         [98, 0, 3, 0]         AG          0.03     chr12  ...
# 1579      44.74        [169, 0, 3, 0]         AG          0.02     chr12  ...
# 1819      45.94        [595, 0, 3, 0]         AG          0.01     chr12  ...
# 2831      52.87       [252, 0, 14, 0]         AG          0.05     chr11  ...
# 2846      42.55        [373, 0, 6, 0]         AG          0.02     chr11  ...
# 3011      63.02        [648, 0, 5, 0]         AG          0.01     chr11  ...
# 3012      64.38        [665, 0, 4, 0]         AG          0.01     chr11  ...
# 3013      55.21        [588, 0, 3, 0]         AG          0.01     chr11  ...
# 8173      43.08        [189, 0, 4, 0]         AG          0.02     chr15  ...
# 8174      51.51       [306, 0, 10, 0]         AG          0.03     chr15  ...
# 8633      49.92       [176, 0, 13, 0]         AG          0.07     chr15  ...
# 8634      50.58        [186, 0, 3, 0]         AG          0.02     chr15  ...
# 8635      49.75        [185, 0, 7, 0]         AG          0.04     chr15  ...
# 8636      49.49       [174, 0, 33, 0]         AG          0.16     chr15  ...
# 8637      50.90       [178, 0, 34, 0]         AG          0.16     chr15  ...
# 8638      51.78       [202, 0, 29, 0]         AG          0.13     chr15  ...
# 8639      54.72        [222, 0, 9, 0]         AG          0.04     chr15  ...
# 8640      54.44        [229, 0, 3, 0]         AG          0.01     chr15  ...
# 8641      51.74        [213, 0, 3, 0]         AG          0.01     chr15  ...
# 8642      51.60        [214, 0, 4, 0]         AG          0.02     chr15  ...
# 9295      43.32        [180, 0, 3, 0]         AG          0.02     chr14  ...
# 9986      53.52       [150, 0, 30, 0]         AG          0.17     chr19  ...
# 9987      53.37        [169, 0, 7, 0]         AG          0.04     chr19  ...
# 10606     40.04        [118, 0, 3, 0]         AG          0.02     chr19  ...
# 11256     48.31        [482, 0, 3, 0]         AG          0.01     chr19  ...
# 11475     48.74       [275, 0, 12, 0]         AG          0.04     chr19  ...
# 11476     49.45        [291, 0, 4, 0]         AG          0.01     chr19  ...
# 11500     50.38        [365, 0, 3, 0]         AG          0.01     chr19  ...
# 11529     45.93        [421, 0, 3, 0]         AG          0.01     chr19  ...
# 13839     44.58        [329, 0, 3, 0]         AG          0.01      chr4  ...
# 14907     48.60        [388, 0, 3, 0]         AG          0.01     chr20  ...
# 15345     42.90        [469, 0, 3, 0]         AG          0.01      chr9  ...
# 15943     48.44        [409, 0, 4, 0]         AG          0.01      chr9  ...
# 16245     49.34        [228, 0, 7, 0]         AG          0.03      chr7  ...
# 16861     50.05        [219, 0, 3, 0]         AG          0.01      chr7  ...
# 17161     56.89        [202, 0, 7, 0]         AG          0.03      chr7  ...
# 17418     49.83        [267, 0, 3, 0]         AG          0.01      chr5  ...
# 17881     44.18        [155, 0, 3, 0]         AG          0.02      chr5  ...
# 17884     50.66       [291, 0, 35, 0]         AG          0.11      chr5  ...
# 17885     50.49        [358, 0, 5, 0]         AG          0.01      chr5  ...
# 19645     50.59        [433, 0, 4, 0]         AG          0.01      chr3  ...
# 20220     46.31        [437, 0, 3, 0]         AG          0.01      chr3  ...
# 20791     53.35        [459, 0, 3, 0]         AG          0.01      chr2  ...
# 21376     44.73        [461, 0, 3, 0]         AG          0.01      chr2  ...
# 21905     45.22        [504, 0, 3, 0]         AG          0.01      chr1  ...
# 23118     45.13        [387, 0, 4, 0]         AG          0.01      chr1  ...
# 23806     42.52        [211, 0, 3, 0]         AG          0.01      chr1  ...
# 23809     43.80        [299, 0, 3, 0]         AG          0.01      chr1  ...
# 23810     44.64        [271, 0, 3, 0]         AG          0.01      chr1  ...
# 23811     44.77        [143, 0, 3, 0]         AG          0.02      chr1  ...
# 23836     47.05        [198, 0, 3, 0]         AG          0.01      chr1  ...
# 24078     50.53        [205, 0, 3, 0]         AG          0.01      chr1  ...
# 24421     46.00        [149, 0, 3, 0]         AG          0.02      chr1  ...
# 25661     47.66        [292, 0, 3, 0]         AG          0.01      chr8  ...
# 25662     45.60        [326, 0, 5, 0]         AG          0.02      chr8  ...
# 25663     47.83        [527, 0, 3, 0]         AG          0.01      chr8  ...
# 25664     45.52        [457, 0, 3, 0]         AG          0.01      chr8  ...
# 25887     43.90        [476, 0, 3, 0]         AG          0.01      chr8  ...
# 26234     48.22        [319, 0, 3, 0]         AG          0.01      chr8  ...
#
#        Class_binary                             wt_sample  \
# 1412              1  HEK293T_WT1.WT.outTable_599710609.gz
# 1579              1  HEK293T_WT1.WT.outTable_599710609.gz
# 1819              1  HEK293T_WT1.WT.outTable_599710609.gz
# 2831              1  HEK293T_WT1.WT.outTable_599710609.gz
# 2846              1  HEK293T_WT1.WT.outTable_599710609.gz
# 3011              1  HEK293T_WT1.WT.outTable_599710609.gz
# 3012              1  HEK293T_WT1.WT.outTable_599710609.gz
# 3013              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8173              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8174              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8633              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8634              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8635              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8636              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8637              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8638              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8639              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8640              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8641              1  HEK293T_WT1.WT.outTable_599710609.gz
# 8642              1  HEK293T_WT1.WT.outTable_599710609.gz
# 9295              1  HEK293T_WT1.WT.outTable_599710609.gz
# 9986              1  HEK293T_WT1.WT.outTable_599710609.gz
# 9987              1  HEK293T_WT1.WT.outTable_599710609.gz
# 10606             1  HEK293T_WT1.WT.outTable_599710609.gz
# 11256             1  HEK293T_WT1.WT.outTable_599710609.gz
# 11475             1  HEK293T_WT1.WT.outTable_599710609.gz
# 11476             1  HEK293T_WT1.WT.outTable_599710609.gz
# 11500             1  HEK293T_WT1.WT.outTable_599710609.gz
# 11529             1  HEK293T_WT1.WT.outTable_599710609.gz
# 13839             1  HEK293T_WT1.WT.outTable_599710609.gz
# 14907             1  HEK293T_WT1.WT.outTable_599710609.gz
# 15345             1  HEK293T_WT1.WT.outTable_599710609.gz
# 15943             1  HEK293T_WT1.WT.outTable_599710609.gz
# 16245             1  HEK293T_WT1.WT.outTable_599710609.gz
# 16861             1  HEK293T_WT1.WT.outTable_599710609.gz
# 17161             1  HEK293T_WT1.WT.outTable_599710609.gz
# 17418             1  HEK293T_WT1.WT.outTable_599710609.gz
# 17881             1  HEK293T_WT1.WT.outTable_599710609.gz
# 17884             1  HEK293T_WT1.WT.outTable_599710609.gz
# 17885             1  HEK293T_WT1.WT.outTable_599710609.gz
# 19645             1  HEK293T_WT1.WT.outTable_599710609.gz
# 20220             1  HEK293T_WT1.WT.outTable_599710609.gz
# 20791             1  HEK293T_WT1.WT.outTable_599710609.gz
# 21376             1  HEK293T_WT1.WT.outTable_599710609.gz
# 21905             1  HEK293T_WT1.WT.outTable_599710609.gz
# 23118             1  HEK293T_WT1.WT.outTable_599710609.gz
# 23806             1  HEK293T_WT1.WT.outTable_599710609.gz
# 23809             1  HEK293T_WT1.WT.outTable_599710609.gz
# 23810             1  HEK293T_WT1.WT.outTable_599710609.gz
# 23811             1  HEK293T_WT1.WT.outTable_599710609.gz
# 23836             1  HEK293T_WT1.WT.outTable_599710609.gz
# 24078             1  HEK293T_WT1.WT.outTable_599710609.gz
# 24421             1  HEK293T_WT1.WT.outTable_599710609.gz
# 25661             1  HEK293T_WT1.WT.outTable_599710609.gz
# 25662             1  HEK293T_WT1.WT.outTable_599710609.gz
# 25663             1  HEK293T_WT1.WT.outTable_599710609.gz
# 25664             1  HEK293T_WT1.WT.outTable_599710609.gz
# 25887             1  HEK293T_WT1.WT.outTable_599710609.gz
# 26234             1  HEK293T_WT1.WT.outTable_599710609.gz
#
#                                   ko_sample  Region  Position Class_y  \
# 1412   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 1579   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 1819   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 2831   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 2846   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 3011   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 3012   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 3013   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8173   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8174   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8633   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8634   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8635   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8636   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8637   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8638   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8639   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8640   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8641   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 8642   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 9295   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 9986   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 9987   HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 10606  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 11256  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 11475  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 11476  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 11500  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 11529  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 13839  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 14907  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 15345  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 15943  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 16245  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 16861  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 17161  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 17418  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 17881  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 17884  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 17885  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 19645  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 20220  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 20791  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 21376  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 21905  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 23118  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 23806  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 23809  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 23810  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 23811  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 23836  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 24078  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 24421  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 25661  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 25662  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 25663  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 25664  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 25887  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
# 26234  HEK293T_KO1.KO.outTable_905657585.gz     NaN       NaN     NaN
#
#       RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 1412       NaN       NaN        NaN         NaN
# 1579       NaN       NaN        NaN         NaN
# 1819       NaN       NaN        NaN         NaN
# 2831       NaN       NaN        NaN         NaN
# 2846       NaN       NaN        NaN         NaN
# 3011       NaN       NaN        NaN         NaN
# 3012       NaN       NaN        NaN         NaN
# 3013       NaN       NaN        NaN         NaN
# 8173       NaN       NaN        NaN         NaN
# 8174       NaN       NaN        NaN         NaN
# 8633       NaN       NaN        NaN         NaN
# 8634       NaN       NaN        NaN         NaN
# 8635       NaN       NaN        NaN         NaN
# 8636       NaN       NaN        NaN         NaN
# 8637       NaN       NaN        NaN         NaN
# 8638       NaN       NaN        NaN         NaN
# 8639       NaN       NaN        NaN         NaN
# 8640       NaN       NaN        NaN         NaN
# 8641       NaN       NaN        NaN         NaN
# 8642       NaN       NaN        NaN         NaN
# 9295       NaN       NaN        NaN         NaN
# 9986       NaN       NaN        NaN         NaN
# 9987       NaN       NaN        NaN         NaN
# 10606      NaN       NaN        NaN         NaN
# 11256      NaN       NaN        NaN         NaN
# 11475      NaN       NaN        NaN         NaN
# 11476      NaN       NaN        NaN         NaN
# 11500      NaN       NaN        NaN         NaN
# 11529      NaN       NaN        NaN         NaN
# 13839      NaN       NaN        NaN         NaN
# 14907      NaN       NaN        NaN         NaN
# 15345      NaN       NaN        NaN         NaN
# 15943      NaN       NaN        NaN         NaN
# 16245      NaN       NaN        NaN         NaN
# 16861      NaN       NaN        NaN         NaN
# 17161      NaN       NaN        NaN         NaN
# 17418      NaN       NaN        NaN         NaN
# 17881      NaN       NaN        NaN         NaN
# 17884      NaN       NaN        NaN         NaN
# 17885      NaN       NaN        NaN         NaN
# 19645      NaN       NaN        NaN         NaN
# 20220      NaN       NaN        NaN         NaN
# 20791      NaN       NaN        NaN         NaN
# 21376      NaN       NaN        NaN         NaN
# 21905      NaN       NaN        NaN         NaN
# 23118      NaN       NaN        NaN         NaN
# 23806      NaN       NaN        NaN         NaN
# 23809      NaN       NaN        NaN         NaN
# 23810      NaN       NaN        NaN         NaN
# 23811      NaN       NaN        NaN         NaN
# 23836      NaN       NaN        NaN         NaN
# 24078      NaN       NaN        NaN         NaN
# 24421      NaN       NaN        NaN         NaN
# 25661      NaN       NaN        NaN         NaN
# 25662      NaN       NaN        NaN         NaN
# 25663      NaN       NaN        NaN         NaN
# 25664      NaN       NaN        NaN         NaN
# 25887      NaN       NaN        NaN         NaN
# 26234      NaN       NaN        NaN         NaN
#
# [59 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT1.WT.outTable_599710609.gz_vs_HEK293T_KO1.KO.outTable_905657585.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 5
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT2.WT.outTable_572868058.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK293T/outTable_572868058_outTable_364841872_bona_fide_sites_2.tsv"

couple5_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              272
# 1          chrX       299513            A          1              263
# 2          chrX       299540            A          1              291
# 3          chrX       299559            A          1              272
# 4          chrX       299568            A          1              271
# ...         ...          ...          ...        ...              ...
# 23815      chr8    144454002            A          0               86
# 23816      chr8    144457131            A          0               78
# 23817      chr8    144458636            A          0               90
# 23818      chr8    144468337            A          1              665
# 23819      chr8    144931953            A          0              296
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         43.13       [239, 0, 33, 0]         AG          0.12      chrX  ...
# 1         43.09        [257, 0, 6, 0]         AG          0.02      chrX  ...
# 2         44.30        [288, 0, 3, 0]         AG          0.01      chrX  ...
# 3         46.03        [267, 0, 5, 0]         AG          0.02      chrX  ...
# 4         46.60        [263, 0, 8, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 23815     45.73         [0, 0, 86, 0]         AG          1.00      chr8  ...
# 23816     45.86        [20, 0, 58, 0]         AG          0.74      chr8  ...
# 23817     44.97        [77, 0, 13, 0]         AG          0.14      chr8  ...
# 23818     48.87        [0, 0, 665, 0]         AG          1.00      chr8  ...
# 23819     46.25       [57, 0, 239, 0]         AG          0.81      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            36   41.00        [36, 0, 0, 0]         -
# 1            1            34   41.35        [34, 0, 0, 0]         -
# 2            1            37   41.11        [37, 0, 0, 0]         -
# 3            1            36   42.69        [36, 0, 0, 0]         -
# 4            1            34   40.47        [34, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 23815        0            34   38.82        [0, 0, 34, 0]        AG
# 23816        0            35   39.86       [14, 0, 21, 0]        AG
# 23817        0            36   42.17       [19, 0, 17, 0]        AG
# 23818        1            34   40.50        [0, 0, 34, 0]        AG
# 23819        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 23815       1.00  Not-Editing             0
# 23816       0.60  Not-Editing             0
# 23817       0.47  Not-Editing             0
# 23818       1.00  Not-Editing             0
# 23819       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT2.WT.outTable_572868058.gz
# 1      HEK293T_WT2.WT.outTable_572868058.gz
# 2      HEK293T_WT2.WT.outTable_572868058.gz
# 3      HEK293T_WT2.WT.outTable_572868058.gz
# 4      HEK293T_WT2.WT.outTable_572868058.gz
# ...                                     ...
# 23815  HEK293T_WT2.WT.outTable_572868058.gz
# 23816  HEK293T_WT2.WT.outTable_572868058.gz
# 23817  HEK293T_WT2.WT.outTable_572868058.gz
# 23818  HEK293T_WT2.WT.outTable_572868058.gz
# 23819  HEK293T_WT2.WT.outTable_572868058.gz
#
#                                   ko_sample
# 0      HEK293T_KO2.KO.outTable_364841872.gz
# 1      HEK293T_KO2.KO.outTable_364841872.gz
# 2      HEK293T_KO2.KO.outTable_364841872.gz
# 3      HEK293T_KO2.KO.outTable_364841872.gz
# 4      HEK293T_KO2.KO.outTable_364841872.gz
# ...                                     ...
# 23815  HEK293T_KO2.KO.outTable_364841872.gz
# 23816  HEK293T_KO2.KO.outTable_364841872.gz
# 23817  HEK293T_KO2.KO.outTable_364841872.gz
# 23818  HEK293T_KO2.KO.outTable_364841872.gz
# 23819  HEK293T_KO2.KO.outTable_364841872.gz
#
# [23820 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0       chr1      14610      0        -        -       exon,transcript
# 1       chr1      16996      0        -        -       transcript,exon
# 2       chr1     753811      1     SINE    AluJo            transcript
# 3       chr1     753830      1     SINE    AluJo            transcript
# 4       chr1     926428      0        -        -            transcript
# ...      ...        ...    ...      ...      ...                   ...
# 23782   chrX  154531460      1        -        -  3UTR,exon,transcript
# 23783   chrX  155919829      1        -        -   transcript,CDS,exon
# 23784   chrX  156023071      0        -        -       exon,transcript
# 23785   chrX  156023093      0        -        -       exon,transcript
# 23786   chrX  156024224      0        -        -       exon,transcript
#
#          RefSeq-Reg
# 0            WASH7P
# 1            WASH7P
# 2      LOC100288069
# 3      LOC100288069
# 4            SAMD11
# ...             ...
# 23782          G6PD
# 23783         VAMP7
# 23784        WASH6P
# 23785        WASH6P
# 23786        WASH6P
#
# [23787 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299510            A          1              272
# 1          chrX       299513            A          1              263
# 2          chrX       299540            A          1              291
# 3          chrX       299559            A          1              272
# 4          chrX       299568            A          1              271
# ...         ...          ...          ...        ...              ...
# 23782      chr8    144454002            A          0               86
# 23783      chr8    144457131            A          0               78
# 23784      chr8    144458636            A          0               90
# 23785      chr8    144468337            A          1              665
# 23786      chr8    144931953            A          0              296
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         43.13       [239, 0, 33, 0]         AG          0.12      chrX  ...
# 1         43.09        [257, 0, 6, 0]         AG          0.02      chrX  ...
# 2         44.30        [288, 0, 3, 0]         AG          0.01      chrX  ...
# 3         46.03        [267, 0, 5, 0]         AG          0.02      chrX  ...
# 4         46.60        [263, 0, 8, 0]         AG          0.03      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 23782     45.73         [0, 0, 86, 0]         AG          1.00      chr8  ...
# 23783     45.86        [20, 0, 58, 0]         AG          0.74      chr8  ...
# 23784     44.97        [77, 0, 13, 0]         AG          0.14      chr8  ...
# 23785     48.87        [0, 0, 665, 0]         AG          1.00      chr8  ...
# 23786     46.25       [57, 0, 239, 0]         AG          0.81      chr8  ...
#
#        Class_binary                             wt_sample  \
# 0                 1  HEK293T_WT2.WT.outTable_572868058.gz
# 1                 1  HEK293T_WT2.WT.outTable_572868058.gz
# 2                 1  HEK293T_WT2.WT.outTable_572868058.gz
# 3                 1  HEK293T_WT2.WT.outTable_572868058.gz
# 4                 1  HEK293T_WT2.WT.outTable_572868058.gz
# ...             ...                                   ...
# 23782             0  HEK293T_WT2.WT.outTable_572868058.gz
# 23783             0  HEK293T_WT2.WT.outTable_572868058.gz
# 23784             0  HEK293T_WT2.WT.outTable_572868058.gz
# 23785             0  HEK293T_WT2.WT.outTable_572868058.gz
# 23786             0  HEK293T_WT2.WT.outTable_572868058.gz
#
#                                   ko_sample  Region   Position Class_y  \
# 0      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299510       1
# 1      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299513       1
# 2      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299540       1
# 3      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299559       1
# 4      HEK293T_KO2.KO.outTable_364841872.gz    chrX     299568       1
# ...                                     ...     ...        ...     ...
# 23782  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144454002       0
# 23783  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144457131       0
# 23784  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144458636       0
# 23785  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144468337       0
# 23786  HEK293T_KO2.KO.outTable_364841872.gz    chr8  144931953       0
#
#       RMSK-Rep  RMSK-Reg             RefSeq-Rep            RefSeq-Reg
# 0         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 1         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 2         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 3         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 4         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# ...        ...       ...                    ...                   ...
# 23782        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 23783        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 23784        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 23785        -         -    transcript,CDS,exon                 KIFC2
# 23786        -         -    exon,transcript,CDS                 ZNF16
#
# [23787 rows x 38 columns]
# Discared sites (via left join):
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 641        chrX    100842597            A          1              203
# 757        chrX    119019378            A          1              175
# 758        chrX    119022136            A          1              159
# 2186      chr11     33073863            A          1              179
# 6184      chr15     66335262            A          0              133
# 6534      chr15    101769787            A          0              128
# 6535      chr15    101769799            A          0              129
# 6536      chr15    101769800            A          0              125
# 6537      chr15    101769801            A          0              126
# 6538      chr15    101769806            A          0              123
# 6539      chr15    101769809            A          0              124
# 7011      chr14     88563036            A          1              238
# 7602      chr19     11694853            A          0              115
# 8811      chr19     57866748            A          1              225
# 8812      chr19     57866752            A          1              234
# 9178       chr6     30556514            A          0              356
# 10172      chr4     37864794            A          1               82
# 11340     chr20      3189380            A          0               81
# 11851      chr9     35087032            A          0               74
# 12024      chr9     97857927            A          1               75
# 13283      chr7    128529747            A          0              141
# 13287      chr7    128641229            A          1              139
# 13288      chr7    128641230            A          1              139
# 13839      chr5     71034220            A          0              238
# 15672      chr3    186827040            A          0              143
# 16647      chr2    176150678            A          1              169
# 17052      chr1       996898            A          0              472
# 17491      chr1     16229724            A          0              123
# 17492      chr1     16231012            A          0              119
# 18034      chr1     37801928            A          1              252
# 18355      chr1     53838373            A          0              274
# 19396      chr1    228182996            A          1               72
# 19671     chr21     44977036            A          1              431
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 641       51.46        [200, 0, 3, 0]         AG          0.01      chrX  ...
# 757       44.83        [172, 0, 3, 0]         AG          0.02      chrX  ...
# 758       46.23        [156, 0, 3, 0]         AG          0.02      chrX  ...
# 2186      53.94       [166, 0, 13, 0]         AG          0.07     chr11  ...
# 6184      41.83        [128, 0, 5, 0]         AG          0.04     chr15  ...
# 6534      45.09       [118, 0, 10, 0]         AG          0.08     chr15  ...
# 6535      50.77        [125, 0, 4, 0]         AG          0.03     chr15  ...
# 6536      51.78       [115, 0, 10, 0]         AG          0.08     chr15  ...
# 6537      52.05        [122, 0, 4, 0]         AG          0.03     chr15  ...
# 6538      51.80        [118, 0, 5, 0]         AG          0.04     chr15  ...
# 6539      50.73       [112, 0, 12, 0]         AG          0.10     chr15  ...
# 7011      42.59        [235, 0, 3, 0]         AG          0.01     chr14  ...
# 7602      52.76       [101, 0, 14, 0]         AG          0.12     chr19  ...
# 8811      47.75        [217, 0, 8, 0]         AG          0.04     chr19  ...
# 8812      48.48        [230, 0, 4, 0]         AG          0.02     chr19  ...
# 9178      45.38        [353, 0, 3, 0]         AG          0.01      chr6  ...
# 10172     48.72         [78, 0, 4, 0]         AG          0.05      chr4  ...
# 11340     42.00         [78, 0, 3, 0]         AG          0.04     chr20  ...
# 11851     48.51         [71, 0, 3, 0]         AG          0.04      chr9  ...
# 12024     52.12         [71, 0, 4, 0]         AG          0.05      chr9  ...
# 13283     56.82        [138, 0, 3, 0]         AG          0.02      chr7  ...
# 13287     49.60        [136, 0, 3, 0]         AG          0.02      chr7  ...
# 13288     49.86        [136, 0, 3, 0]         AG          0.02      chr7  ...
# 13839     48.51       [220, 0, 18, 0]         AG          0.08      chr5  ...
# 15672     39.41        [138, 0, 5, 0]         AG          0.03      chr3  ...
# 16647     45.90        [166, 0, 3, 0]         AG          0.02      chr2  ...
# 17052     43.57        [469, 0, 3, 0]         AG          0.01      chr1  ...
# 17491     45.93        [120, 0, 3, 0]         AG          0.02      chr1  ...
# 17492     45.20        [115, 0, 4, 0]         AG          0.03      chr1  ...
# 18034     44.77        [249, 0, 3, 0]         AG          0.01      chr1  ...
# 18355     50.27        [271, 0, 3, 0]         AG          0.01      chr1  ...
# 19396     48.49         [69, 0, 3, 0]         AG          0.04      chr1  ...
# 19671     45.43        [428, 0, 3, 0]         AG          0.01     chr21  ...
#
#        Class_binary                             wt_sample  \
# 641               1  HEK293T_WT2.WT.outTable_572868058.gz
# 757               1  HEK293T_WT2.WT.outTable_572868058.gz
# 758               1  HEK293T_WT2.WT.outTable_572868058.gz
# 2186              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6184              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6534              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6535              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6536              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6537              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6538              1  HEK293T_WT2.WT.outTable_572868058.gz
# 6539              1  HEK293T_WT2.WT.outTable_572868058.gz
# 7011              1  HEK293T_WT2.WT.outTable_572868058.gz
# 7602              1  HEK293T_WT2.WT.outTable_572868058.gz
# 8811              1  HEK293T_WT2.WT.outTable_572868058.gz
# 8812              1  HEK293T_WT2.WT.outTable_572868058.gz
# 9178              1  HEK293T_WT2.WT.outTable_572868058.gz
# 10172             1  HEK293T_WT2.WT.outTable_572868058.gz
# 11340             1  HEK293T_WT2.WT.outTable_572868058.gz
# 11851             1  HEK293T_WT2.WT.outTable_572868058.gz
# 12024             1  HEK293T_WT2.WT.outTable_572868058.gz
# 13283             1  HEK293T_WT2.WT.outTable_572868058.gz
# 13287             1  HEK293T_WT2.WT.outTable_572868058.gz
# 13288             1  HEK293T_WT2.WT.outTable_572868058.gz
# 13839             1  HEK293T_WT2.WT.outTable_572868058.gz
# 15672             1  HEK293T_WT2.WT.outTable_572868058.gz
# 16647             1  HEK293T_WT2.WT.outTable_572868058.gz
# 17052             1  HEK293T_WT2.WT.outTable_572868058.gz
# 17491             1  HEK293T_WT2.WT.outTable_572868058.gz
# 17492             1  HEK293T_WT2.WT.outTable_572868058.gz
# 18034             1  HEK293T_WT2.WT.outTable_572868058.gz
# 18355             1  HEK293T_WT2.WT.outTable_572868058.gz
# 19396             1  HEK293T_WT2.WT.outTable_572868058.gz
# 19671             1  HEK293T_WT2.WT.outTable_572868058.gz
#
#                                   ko_sample  Region  Position Class_y  \
# 641    HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 757    HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 758    HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 2186   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6184   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6534   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6535   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6536   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6537   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6538   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 6539   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 7011   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 7602   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 8811   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 8812   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 9178   HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 10172  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 11340  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 11851  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 12024  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 13283  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 13287  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 13288  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 13839  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 15672  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 16647  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 17052  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 17491  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 17492  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 18034  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 18355  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 19396  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
# 19671  HEK293T_KO2.KO.outTable_364841872.gz     NaN       NaN     NaN
#
#       RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 641        NaN       NaN        NaN         NaN
# 757        NaN       NaN        NaN         NaN
# 758        NaN       NaN        NaN         NaN
# 2186       NaN       NaN        NaN         NaN
# 6184       NaN       NaN        NaN         NaN
# 6534       NaN       NaN        NaN         NaN
# 6535       NaN       NaN        NaN         NaN
# 6536       NaN       NaN        NaN         NaN
# 6537       NaN       NaN        NaN         NaN
# 6538       NaN       NaN        NaN         NaN
# 6539       NaN       NaN        NaN         NaN
# 7011       NaN       NaN        NaN         NaN
# 7602       NaN       NaN        NaN         NaN
# 8811       NaN       NaN        NaN         NaN
# 8812       NaN       NaN        NaN         NaN
# 9178       NaN       NaN        NaN         NaN
# 10172      NaN       NaN        NaN         NaN
# 11340      NaN       NaN        NaN         NaN
# 11851      NaN       NaN        NaN         NaN
# 12024      NaN       NaN        NaN         NaN
# 13283      NaN       NaN        NaN         NaN
# 13287      NaN       NaN        NaN         NaN
# 13288      NaN       NaN        NaN         NaN
# 13839      NaN       NaN        NaN         NaN
# 15672      NaN       NaN        NaN         NaN
# 16647      NaN       NaN        NaN         NaN
# 17052      NaN       NaN        NaN         NaN
# 17491      NaN       NaN        NaN         NaN
# 17492      NaN       NaN        NaN         NaN
# 18034      NaN       NaN        NaN         NaN
# 18355      NaN       NaN        NaN         NaN
# 19396      NaN       NaN        NaN         NaN
# 19671      NaN       NaN        NaN         NaN
#
# [33 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT2.WT.outTable_572868058.gz_vs_HEK293T_KO2.KO.outTable_364841872.gz.bonafide_final.tsv.anno.filt_refseq.tsv

# %%
### Couple 6
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT3.WT.outTable_110067244.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/HEK293T/outTable_110067244_outTable_597789462_bona_fide_sites_2.tsv"

couple6_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299431            A          1              229
# 1          chrX       299510            A          1              144
# 2          chrX       299568            A          1              137
# 3          chrX       299572            A          1              137
# 4          chrX       299574            A          1              133
# ...         ...          ...          ...        ...              ...
# 20059      chr8    144425879            A          0              158
# 20060      chr8    144440133            A          0              509
# 20061      chr8    144451628            A          0              220
# 20062      chr8    144468337            A          1              422
# 20063      chr8    144931953            A          0              163
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         49.54        [226, 0, 3, 0]         AG          0.01      chrX  ...
# 1         45.65       [121, 0, 23, 0]         AG          0.16      chrX  ...
# 2         52.31        [132, 0, 5, 0]         AG          0.04      chrX  ...
# 3         51.77       [125, 0, 12, 0]         AG          0.09      chrX  ...
# 4         51.55        [130, 0, 3, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 20059     40.91       [124, 0, 34, 0]         AG          0.22      chr8  ...
# 20060     47.75        [1, 0, 508, 0]         AG          1.00      chr8  ...
# 20061     49.34       [169, 0, 51, 0]         AG          0.23      chr8  ...
# 20062     46.23        [0, 0, 422, 0]         AG          1.00      chr8  ...
# 20063     50.32       [39, 0, 124, 0]         AG          0.76      chr8  ...
#
#        gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs  \
# 0            1            35   40.20        [35, 0, 0, 0]         -
# 1            1            36   41.00        [36, 0, 0, 0]         -
# 2            1            34   40.47        [34, 0, 0, 0]         -
# 3            1            40   42.10        [40, 0, 0, 0]         -
# 4            1            37   42.43        [37, 0, 0, 0]         -
# ...        ...           ...     ...                  ...       ...
# 20059        0            39   41.62       [28, 0, 11, 0]        AG
# 20060        0            59   40.75        [0, 0, 59, 0]        AG
# 20061        0            43   40.12        [35, 0, 8, 0]        AG
# 20062        1            34   40.50        [0, 0, 34, 0]        AG
# 20063        0            42   39.76       [15, 0, 27, 0]        AG
#
#       gFrequency        Class  Class_binary  \
# 0           0.00      Editing             1
# 1           0.00      Editing             1
# 2           0.00      Editing             1
# 3           0.00      Editing             1
# 4           0.00      Editing             1
# ...          ...          ...           ...
# 20059       0.28  Not-Editing             0
# 20060       1.00  Not-Editing             0
# 20061       0.19  Not-Editing             0
# 20062       1.00  Not-Editing             0
# 20063       0.64  Not-Editing             0
#
#                                   wt_sample  \
# 0      HEK293T_WT3.WT.outTable_110067244.gz
# 1      HEK293T_WT3.WT.outTable_110067244.gz
# 2      HEK293T_WT3.WT.outTable_110067244.gz
# 3      HEK293T_WT3.WT.outTable_110067244.gz
# 4      HEK293T_WT3.WT.outTable_110067244.gz
# ...                                     ...
# 20059  HEK293T_WT3.WT.outTable_110067244.gz
# 20060  HEK293T_WT3.WT.outTable_110067244.gz
# 20061  HEK293T_WT3.WT.outTable_110067244.gz
# 20062  HEK293T_WT3.WT.outTable_110067244.gz
# 20063  HEK293T_WT3.WT.outTable_110067244.gz
#
#                                   ko_sample
# 0      HEK293T_KO3.KO.outTable_597789462.gz
# 1      HEK293T_KO3.KO.outTable_597789462.gz
# 2      HEK293T_KO3.KO.outTable_597789462.gz
# 3      HEK293T_KO3.KO.outTable_597789462.gz
# 4      HEK293T_KO3.KO.outTable_597789462.gz
# ...                                     ...
# 20059  HEK293T_KO3.KO.outTable_597789462.gz
# 20060  HEK293T_KO3.KO.outTable_597789462.gz
# 20061  HEK293T_KO3.KO.outTable_597789462.gz
# 20062  HEK293T_KO3.KO.outTable_597789462.gz
# 20063  HEK293T_KO3.KO.outTable_597789462.gz
#
# [20064 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#       Region   Position  Class RMSK-Rep RMSK-Reg            RefSeq-Rep  \
# 0       chr1      14610      0        -        -       exon,transcript
# 1       chr1     926744      0        -        -            transcript
# 2       chr1     942909      1        -        -   transcript,CDS,exon
# 3       chr1     953259      0        -        -   transcript,CDS,exon
# 4       chr1     953279      0        -        -   transcript,CDS,exon
# ...      ...        ...    ...      ...      ...                   ...
# 20026   chrX  154531474      1        -        -  3UTR,exon,transcript
# 20027   chrX  154777540      1        -        -  transcript,3UTR,exon
# 20028   chrX  154790991      1        -        -   transcript,CDS,exon
# 20029   chrX  156023071      0        -        -       exon,transcript
# 20030   chrX  156023093      0        -        -       exon,transcript
#
#       RefSeq-Reg
# 0         WASH7P
# 1         SAMD11
# 2         SAMD11
# 3          NOC2L
# 4          NOC2L
# ...          ...
# 20026       G6PD
# 20027       DKC1
# 20028       MPP1
# 20029     WASH6P
# 20030     WASH6P
#
# [20031 rows x 7 columns]
# Common sites annotated with REDItools info:
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0          chrX       299431            A          1              229
# 1          chrX       299510            A          1              144
# 2          chrX       299568            A          1              137
# 3          chrX       299572            A          1              137
# 4          chrX       299574            A          1              133
# ...         ...          ...          ...        ...              ...
# 20026      chr8    144425879            A          0              158
# 20027      chr8    144440133            A          0              509
# 20028      chr8    144451628            A          0              220
# 20029      chr8    144468337            A          1              422
# 20030      chr8    144931953            A          0              163
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0         49.54        [226, 0, 3, 0]         AG          0.01      chrX  ...
# 1         45.65       [121, 0, 23, 0]         AG          0.16      chrX  ...
# 2         52.31        [132, 0, 5, 0]         AG          0.04      chrX  ...
# 3         51.77       [125, 0, 12, 0]         AG          0.09      chrX  ...
# 4         51.55        [130, 0, 3, 0]         AG          0.02      chrX  ...
# ...         ...                   ...        ...           ...       ...  ...
# 20026     40.91       [124, 0, 34, 0]         AG          0.22      chr8  ...
# 20027     47.75        [1, 0, 508, 0]         AG          1.00      chr8  ...
# 20028     49.34       [169, 0, 51, 0]         AG          0.23      chr8  ...
# 20029     46.23        [0, 0, 422, 0]         AG          1.00      chr8  ...
# 20030     50.32       [39, 0, 124, 0]         AG          0.76      chr8  ...
#
#        Class_binary                             wt_sample  \
# 0                 1  HEK293T_WT3.WT.outTable_110067244.gz
# 1                 1  HEK293T_WT3.WT.outTable_110067244.gz
# 2                 1  HEK293T_WT3.WT.outTable_110067244.gz
# 3                 1  HEK293T_WT3.WT.outTable_110067244.gz
# 4                 1  HEK293T_WT3.WT.outTable_110067244.gz
# ...             ...                                   ...
# 20026             0  HEK293T_WT3.WT.outTable_110067244.gz
# 20027             0  HEK293T_WT3.WT.outTable_110067244.gz
# 20028             0  HEK293T_WT3.WT.outTable_110067244.gz
# 20029             0  HEK293T_WT3.WT.outTable_110067244.gz
# 20030             0  HEK293T_WT3.WT.outTable_110067244.gz
#
#                                   ko_sample  Region   Position Class_y  \
# 0      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299431       1
# 1      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299510       1
# 2      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299568       1
# 3      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299572       1
# 4      HEK293T_KO3.KO.outTable_597789462.gz    chrX     299574       1
# ...                                     ...     ...        ...     ...
# 20026  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144425879       0
# 20027  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144440133       0
# 20028  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144451628       0
# 20029  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144468337       0
# 20030  HEK293T_KO3.KO.outTable_597789462.gz    chr8  144931953       0
#
#       RMSK-Rep  RMSK-Reg             RefSeq-Rep            RefSeq-Reg
# 0            -         -   transcript,exon,3UTR                PLCXD1
# 1         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 2         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 3         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# 4         SINE    AluSx1   transcript,exon,3UTR                PLCXD1
# ...        ...       ...                    ...                   ...
# 20026        -         -   transcript,5UTR,exon                 VPS28
# 20027        -         -    transcript,CDS,exon                 TONSL
# 20028        -         -  transcript$transcript  CYHR1$LOC84773-CYHR1
# 20029        -         -    transcript,CDS,exon                 KIFC2
# 20030        -         -    exon,transcript,CDS                 ZNF16
#
# [20031 rows x 38 columns]
# Discared sites (via left join):
#       wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 562        chrX    101345647            A          0              126
# 978       chr12      3045107            A          1              132
# 984       chr12      6493736            A          0              619
# 1236      chr12     56731213            A          0              535
# 1973      chr11     33073863            A          1               64
# 5595      chr15    101769773            A          0               75
# 5596      chr15    101769778            A          0               80
# 5597      chr15    101769787            A          0               84
# 5598      chr15    101769809            A          0               89
# 5599      chr15    101772716            A          0              113
# 6389      chr19     10932101            A          1               78
# 6470      chr19     11694853            A          0               77
# 7405      chr19     57866748            A          1              114
# 7895       chr6     43030136            A          1              310
# 8652      chr22     37608639            A          1               88
# 8653      chr22     37608640            A          1               85
# 8862      chr22     46251158            A          1              100
# 9465       chr9     97858242            A          1               97
# 9466       chr9     97858371            A          1               74
# 9976       chr7     44574073            A          0               68
# 10702      chr5      1347778            A          1              126
# 11017      chr5     71033206            A          0              152
# 11018      chr5     71034220            A          0              141
# 11019      chr5     71034228            A          0              169
# 11020      chr5     71034238            A          0              167
# 12767      chr3     72977881            A          1              110
# 13573      chr2     74832785            A          0              181
# 13578      chr2     74833664            A          0              197
# 15441      chr1    110057607            A          1               52
# 16020      chr1    226309929            A          1              216
# 16025      chr1    227781804            A          1               59
# 16442      chr8     29060575            A          1              102
# 16443      chr8     29060812            A          1              149
#
#        wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 562       46.90        [123, 0, 3, 0]         AG          0.02      chrX  ...
# 978       46.23        [128, 0, 4, 0]         AG          0.03     chr12  ...
# 984       52.09        [613, 0, 6, 0]         AG          0.01     chr12  ...
# 1236      46.75        [532, 0, 3, 0]         AG          0.01     chr12  ...
# 1973      51.23         [59, 0, 5, 0]         AG          0.08     chr11  ...
# 5595      41.95         [69, 0, 6, 0]         AG          0.08     chr15  ...
# 5596      42.40         [75, 0, 5, 0]         AG          0.06     chr15  ...
# 5597      44.49        [74, 0, 10, 0]         AG          0.12     chr15  ...
# 5598      44.63        [77, 0, 12, 0]         AG          0.13     chr15  ...
# 5599      41.37        [108, 0, 5, 0]         AG          0.04     chr15  ...
# 6389      50.29         [75, 0, 3, 0]         AG          0.04     chr19  ...
# 6470      53.31         [71, 0, 6, 0]         AG          0.08     chr19  ...
# 7405      45.65        [108, 0, 6, 0]         AG          0.05     chr19  ...
# 7895      50.04        [307, 0, 3, 0]         AG          0.01      chr6  ...
# 8652      48.92         [84, 0, 4, 0]         AG          0.05     chr22  ...
# 8653      42.25         [81, 0, 4, 0]         AG          0.05     chr22  ...
# 8862      49.69         [97, 0, 3, 0]         AG          0.03     chr22  ...
# 9465      46.15         [94, 0, 3, 0]         AG          0.03      chr9  ...
# 9466      47.18         [71, 0, 3, 0]         AG          0.04      chr9  ...
# 9976      48.43         [65, 0, 3, 0]         AG          0.04      chr7  ...
# 10702     46.98        [122, 0, 4, 0]         AG          0.03      chr5  ...
# 11017     45.61        [149, 0, 3, 0]         AG          0.02      chr5  ...
# 11018     48.72        [132, 0, 9, 0]         AG          0.06      chr5  ...
# 11019     48.66       [159, 0, 10, 0]         AG          0.06      chr5  ...
# 11020     53.53        [164, 0, 3, 0]         AG          0.02      chr5  ...
# 12767     42.05        [103, 0, 7, 0]         AG          0.06      chr3  ...
# 13573     47.13        [178, 0, 3, 0]         AG          0.02      chr2  ...
# 13578     48.27        [194, 0, 3, 0]         AG          0.02      chr2  ...
# 15441     44.31         [49, 0, 3, 0]         AG          0.06      chr1  ...
# 16020     51.22        [212, 0, 4, 0]         AG          0.02      chr1  ...
# 16025     49.51         [56, 0, 3, 0]         AG          0.05      chr1  ...
# 16442     49.92         [99, 0, 3, 0]         AG          0.03      chr8  ...
# 16443     47.25        [144, 0, 5, 0]         AG          0.03      chr8  ...
#
#        Class_binary                             wt_sample  \
# 562               1  HEK293T_WT3.WT.outTable_110067244.gz
# 978               1  HEK293T_WT3.WT.outTable_110067244.gz
# 984               1  HEK293T_WT3.WT.outTable_110067244.gz
# 1236              1  HEK293T_WT3.WT.outTable_110067244.gz
# 1973              1  HEK293T_WT3.WT.outTable_110067244.gz
# 5595              1  HEK293T_WT3.WT.outTable_110067244.gz
# 5596              1  HEK293T_WT3.WT.outTable_110067244.gz
# 5597              1  HEK293T_WT3.WT.outTable_110067244.gz
# 5598              1  HEK293T_WT3.WT.outTable_110067244.gz
# 5599              1  HEK293T_WT3.WT.outTable_110067244.gz
# 6389              1  HEK293T_WT3.WT.outTable_110067244.gz
# 6470              1  HEK293T_WT3.WT.outTable_110067244.gz
# 7405              1  HEK293T_WT3.WT.outTable_110067244.gz
# 7895              1  HEK293T_WT3.WT.outTable_110067244.gz
# 8652              1  HEK293T_WT3.WT.outTable_110067244.gz
# 8653              1  HEK293T_WT3.WT.outTable_110067244.gz
# 8862              1  HEK293T_WT3.WT.outTable_110067244.gz
# 9465              1  HEK293T_WT3.WT.outTable_110067244.gz
# 9466              1  HEK293T_WT3.WT.outTable_110067244.gz
# 9976              1  HEK293T_WT3.WT.outTable_110067244.gz
# 10702             1  HEK293T_WT3.WT.outTable_110067244.gz
# 11017             1  HEK293T_WT3.WT.outTable_110067244.gz
# 11018             1  HEK293T_WT3.WT.outTable_110067244.gz
# 11019             1  HEK293T_WT3.WT.outTable_110067244.gz
# 11020             1  HEK293T_WT3.WT.outTable_110067244.gz
# 12767             1  HEK293T_WT3.WT.outTable_110067244.gz
# 13573             1  HEK293T_WT3.WT.outTable_110067244.gz
# 13578             1  HEK293T_WT3.WT.outTable_110067244.gz
# 15441             1  HEK293T_WT3.WT.outTable_110067244.gz
# 16020             1  HEK293T_WT3.WT.outTable_110067244.gz
# 16025             1  HEK293T_WT3.WT.outTable_110067244.gz
# 16442             1  HEK293T_WT3.WT.outTable_110067244.gz
# 16443             1  HEK293T_WT3.WT.outTable_110067244.gz
#
#                                   ko_sample  Region  Position Class_y  \
# 562    HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 978    HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 984    HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 1236   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 1973   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 5595   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 5596   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 5597   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 5598   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 5599   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 6389   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 6470   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 7405   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 7895   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 8652   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 8653   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 8862   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 9465   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 9466   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 9976   HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 10702  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 11017  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 11018  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 11019  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 11020  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 12767  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 13573  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 13578  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 15441  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 16020  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 16025  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 16442  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
# 16443  HEK293T_KO3.KO.outTable_597789462.gz     NaN       NaN     NaN
#
#       RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 562        NaN       NaN        NaN         NaN
# 978        NaN       NaN        NaN         NaN
# 984        NaN       NaN        NaN         NaN
# 1236       NaN       NaN        NaN         NaN
# 1973       NaN       NaN        NaN         NaN
# 5595       NaN       NaN        NaN         NaN
# 5596       NaN       NaN        NaN         NaN
# 5597       NaN       NaN        NaN         NaN
# 5598       NaN       NaN        NaN         NaN
# 5599       NaN       NaN        NaN         NaN
# 6389       NaN       NaN        NaN         NaN
# 6470       NaN       NaN        NaN         NaN
# 7405       NaN       NaN        NaN         NaN
# 7895       NaN       NaN        NaN         NaN
# 8652       NaN       NaN        NaN         NaN
# 8653       NaN       NaN        NaN         NaN
# 8862       NaN       NaN        NaN         NaN
# 9465       NaN       NaN        NaN         NaN
# 9466       NaN       NaN        NaN         NaN
# 9976       NaN       NaN        NaN         NaN
# 10702      NaN       NaN        NaN         NaN
# 11017      NaN       NaN        NaN         NaN
# 11018      NaN       NaN        NaN         NaN
# 11019      NaN       NaN        NaN         NaN
# 11020      NaN       NaN        NaN         NaN
# 12767      NaN       NaN        NaN         NaN
# 13573      NaN       NaN        NaN         NaN
# 13578      NaN       NaN        NaN         NaN
# 15441      NaN       NaN        NaN         NaN
# 16020      NaN       NaN        NaN         NaN
# 16025      NaN       NaN        NaN         NaN
# 16442      NaN       NaN        NaN         NaN
# 16443      NaN       NaN        NaN         NaN
#
# [33 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/hek_pecori/HEK293T_WT3.WT.outTable_110067244.gz_vs_HEK293T_KO3.KO.outTable_597789462.gz.bonafide_final.tsv.anno.filt_refseq.tsv
