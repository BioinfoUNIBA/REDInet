# %%
##################
### Author: Adriano Fonzino. email: adriano.fonzino@uniba.it
##################
import os
import pandas as pd
import numpy as np


# define util function for downstream analysis
def join_bonafides(bonafide_fp, bonafide_anno_filt):
    ### function to join bonafide with reditools info with bonafide with anno and filtered 
    ### NON-REP only Refseq
    # load bonafide with reditools alignment profiles/data
    bonafide = pd.read_table(bonafide_fp)
    print("Bonafide not-filted with REDItools info:")
    display(bonafide)
    # load annotated table filtered for positives NON-REP being in Refseq
    bonafide_anno_filt = pd.read_table(bonafide_anno_filt_fp)
    print("Bonafide annotated and filtered (NON-REP only Refseq):")
    display(bonafide_anno_filt)
    # inner join between bonafide with and without annotation/filtering
    joined = pd.merge(bonafide, bonafide_anno_filt, 
                      left_on=["wt_Region", "wt_Position"],
                      right_on=["Region", "Position"], how="inner")
    print("Common sites annotated with REDItools info:")
    display(joined)
    # print not common site (not Refseq)
    left_join = pd.merge(bonafide, bonafide_anno_filt, 
                        left_on=["wt_Region", "wt_Position"],
                        right_on=["Region", "Position"], how="left")
    print("Discared sites (via left join):")
    display(left_join[left_join["Class_y"].isna()])
    output_file = bonafide_fp + ".anno.filt_refseq.tsv"
    print("Save on disk joined with annotation and filtering to :", output_file)
    joined.to_csv(output_file, index=None, sep="\t")

    return joined

# %% [markdown]
# ## U87

# %%
### Couple 1
# inputs
bonafide_fp = "/lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/u87/SRR388226_SRR388227.WT.outTable_853538513.gz_vs_SRR388228_SRR388229.KO.outTable_921089530.gz.bonafide_final.tsv"
bonafide_anno_filt_fp = "/lustrehome/pietrolucamazzacuva/filezilla-recas/tissues/independent_datasets/U87/outTable_853538513_outTable_921089530_bona_fide_sites_2.tsv"

couple1_join = join_bonafides(bonafide_fp, bonafide_anno_filt_fp)
# Out:
# Bonafide not-filted with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX     16754311            A          1              146
# 1         chrX     19368150            A          1              144
# 2         chrX     19555884            A          0              187
# 3         chrX     19610250            A          0              294
# 4         chrX     23740019            A          0              101
# ...        ...          ...          ...        ...              ...
# 7302      chr8    134470631            A          0               33
# 7303      chr8    144991176            A          0              325
# 7304      chr8    144992103            A          0              352
# 7305      chr8    145150832            A          1              215
# 7306      chr8    145693720            A          1              118
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        37.49        [144, 0, 2, 0]         AG          0.01      chrX  ...
# 1        37.78        [142, 0, 2, 0]         AG          0.01      chrX  ...
# 2        37.07        [185, 0, 2, 0]         AG          0.01      chrX  ...
# 3        37.65        [292, 0, 2, 0]         AG          0.01      chrX  ...
# 4        37.06         [99, 0, 2, 0]         AG          0.02      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 7302     43.21        [17, 0, 16, 0]         AG          0.48      chr8  ...
# 7303     38.59      [141, 0, 184, 0]         AG          0.57      chr8  ...
# 7304     38.34      [149, 0, 203, 0]         AG          0.58      chr8  ...
# 7305     39.82        [0, 0, 215, 0]         AG          1.00      chr8  ...
# 7306     37.03        [0, 0, 118, 0]         AG          1.00      chr8  ...
#
#       gStrand gCoverage-q30  gMeanQ  gBaseCount[A,C,G,T]  gAllSubs gFrequency  \
# 0           1            18   39.17        [18, 0, 0, 0]         -       0.00
# 1           1            17   35.59        [17, 0, 0, 0]         -       0.00
# 2           0            15   37.47        [15, 0, 0, 0]         -       0.00
# 3           0            23   35.48        [23, 0, 0, 0]         -       0.00
# 4           0            20   36.75        [20, 0, 0, 0]         -       0.00
# ...       ...           ...     ...                  ...       ...        ...
# 7302        0            45   35.93       [27, 0, 18, 0]        AG       0.40
# 7303        0            41   31.78       [16, 0, 25, 0]        AG       0.61
# 7304        0            33   35.52       [18, 0, 15, 0]        AG       0.45
# 7305        1            30   34.30        [0, 0, 30, 0]        AG       1.00
# 7306        1            46   32.70        [0, 0, 46, 0]        AG       1.00
#
#             Class  Class_binary                                     wt_sample  \
# 0         Editing             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 1         Editing             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 2         Editing             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 3         Editing             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 4         Editing             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# ...           ...           ...                                           ...
# 7302  Not-Editing             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7303  Not-Editing             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7304  Not-Editing             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7305  Not-Editing             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7306  Not-Editing             0  SRR388226_SRR388227.WT.outTable_853538513.gz
#
#                                          ko_sample
# 0     SRR388228_SRR388229.KO.outTable_921089530.gz
# 1     SRR388228_SRR388229.KO.outTable_921089530.gz
# 2     SRR388228_SRR388229.KO.outTable_921089530.gz
# 3     SRR388228_SRR388229.KO.outTable_921089530.gz
# 4     SRR388228_SRR388229.KO.outTable_921089530.gz
# ...                                            ...
# 7302  SRR388228_SRR388229.KO.outTable_921089530.gz
# 7303  SRR388228_SRR388229.KO.outTable_921089530.gz
# 7304  SRR388228_SRR388229.KO.outTable_921089530.gz
# 7305  SRR388228_SRR388229.KO.outTable_921089530.gz
# 7306  SRR388228_SRR388229.KO.outTable_921089530.gz
#
# [7307 rows x 31 columns]
# Bonafide annotated and filtered (NON-REP only Refseq):
#      Region   Position  Class RMSK-Rep RMSK-Reg                  RefSeq-Rep  \
# 0      chr1     880170      1        -        -         exon,transcript,CDS
# 1      chr1     880449      1        -        -         transcript,CDS,exon
# 2      chr1     888639      0        -        -         transcript,CDS,exon
# 3      chr1     888659      0        -        -         transcript,CDS,exon
# 4      chr1     949654      0        -        -         transcript,CDS,exon
# ...     ...        ...    ...      ...      ...                         ...
# 7298   chrX  153713859      1        -        -        3UTR,exon,transcript
# 7299   chrX  153759848      1        -        -        3UTR,exon,transcript
# 7300   chrX  154456747      0        -        -         transcript,CDS,exon
# 7301   chrY   21152719      0        -        -  transcript$exon,transcript
# 7302   chrY   21153609      0        -        -  transcript$exon,transcript
#
#          RefSeq-Reg
# 0             NOC2L
# 1             NOC2L
# 2             NOC2L
# 3             NOC2L
# 4             ISG15
# ...             ...
# 7298          UBL4A
# 7299           G6PD
# 7300           VBP1
# 7301  TTTY14$CD24P4
# 7302  TTTY14$CD24P4
#
# [7303 rows x 7 columns]
# Common sites annotated with REDItools info:
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 0         chrX     16754311            A          1              146
# 1         chrX     19368150            A          1              144
# 2         chrX     19555884            A          0              187
# 3         chrX     19610250            A          0              294
# 4         chrX     23740019            A          0              101
# ...        ...          ...          ...        ...              ...
# 7298      chr8    134470631            A          0               33
# 7299      chr8    144991176            A          0              325
# 7300      chr8    144992103            A          0              352
# 7301      chr8    145150832            A          1              215
# 7302      chr8    145693720            A          1              118
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 0        37.49        [144, 0, 2, 0]         AG          0.01      chrX  ...
# 1        37.78        [142, 0, 2, 0]         AG          0.01      chrX  ...
# 2        37.07        [185, 0, 2, 0]         AG          0.01      chrX  ...
# 3        37.65        [292, 0, 2, 0]         AG          0.01      chrX  ...
# 4        37.06         [99, 0, 2, 0]         AG          0.02      chrX  ...
# ...        ...                   ...        ...           ...       ...  ...
# 7298     43.21        [17, 0, 16, 0]         AG          0.48      chr8  ...
# 7299     38.59      [141, 0, 184, 0]         AG          0.57      chr8  ...
# 7300     38.34      [149, 0, 203, 0]         AG          0.58      chr8  ...
# 7301     39.82        [0, 0, 215, 0]         AG          1.00      chr8  ...
# 7302     37.03        [0, 0, 118, 0]         AG          1.00      chr8  ...
#
#       Class_binary                                     wt_sample  \
# 0                1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 1                1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 2                1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 3                1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 4                1  SRR388226_SRR388227.WT.outTable_853538513.gz
# ...            ...                                           ...
# 7298             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7299             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7300             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7301             0  SRR388226_SRR388227.WT.outTable_853538513.gz
# 7302             0  SRR388226_SRR388227.WT.outTable_853538513.gz
#
#                                          ko_sample  Region   Position Class_y  \
# 0     SRR388228_SRR388229.KO.outTable_921089530.gz    chrX   16754311       1
# 1     SRR388228_SRR388229.KO.outTable_921089530.gz    chrX   19368150       1
# 2     SRR388228_SRR388229.KO.outTable_921089530.gz    chrX   19555884       1
# 3     SRR388228_SRR388229.KO.outTable_921089530.gz    chrX   19610250       1
# 4     SRR388228_SRR388229.KO.outTable_921089530.gz    chrX   23740019       1
# ...                                            ...     ...        ...     ...
# 7298  SRR388228_SRR388229.KO.outTable_921089530.gz    chr8  134470631       0
# 7299  SRR388228_SRR388229.KO.outTable_921089530.gz    chr8  144991176       0
# 7300  SRR388228_SRR388229.KO.outTable_921089530.gz    chr8  144992103       0
# 7301  SRR388228_SRR388229.KO.outTable_921089530.gz    chr8  145150832       0
# 7302  SRR388228_SRR388229.KO.outTable_921089530.gz    chr8  145693720       0
#
#      RMSK-Rep  RMSK-Reg            RefSeq-Rep  RefSeq-Reg
# 0           -         -   transcript,CDS,exon       SYAP1
# 1           -         -   transcript,CDS,exon       PDHA1
# 2           -         -   transcript,CDS,exon     SH3KBP1
# 3           -         -   transcript,CDS,exon     SH3KBP1
# 4           -         -   transcript,CDS,exon       ACOT9
# ...       ...       ...                   ...         ...
# 7298        -         -  3UTR,exon,transcript     ST3GAL1
# 7299        -         -   exon,transcript,CDS        PLEC
# 7300        -         -   exon,transcript,CDS        PLEC
# 7301        -         -   transcript,CDS,exon        CYC1
# 7302        -         -   transcript,CDS,exon       KIFC2
#
# [7303 rows x 38 columns]
# Discared sites (via left join):
#      wt_Region  wt_Position wt_Reference  wt_Strand  wt_Coverage-q30  \
# 845      chr11     66036107            A          1               96
# 1920     chr14     23305769            A          1               86
# 1921     chr14     23305771            A          1               90
# 4841      chr3     98700171            A          1              105
#
#       wt_MeanQ wt_BaseCount[A,C,G,T] wt_AllSubs  wt_Frequency ko_Region  ...  \
# 845      37.56         [94, 0, 2, 0]         AG          0.02     chr11  ...
# 1920     39.70         [81, 0, 5, 0]         AG          0.06     chr14  ...
# 1921     40.01         [83, 0, 7, 0]         AG          0.08     chr14  ...
# 4841     40.55        [103, 0, 2, 0]         AG          0.02      chr3  ...
#
#       Class_binary                                     wt_sample  \
# 845              1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 1920             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 1921             1  SRR388226_SRR388227.WT.outTable_853538513.gz
# 4841             1  SRR388226_SRR388227.WT.outTable_853538513.gz
#
#                                          ko_sample  Region  Position Class_y  \
# 845   SRR388228_SRR388229.KO.outTable_921089530.gz     NaN       NaN     NaN
# 1920  SRR388228_SRR388229.KO.outTable_921089530.gz     NaN       NaN     NaN
# 1921  SRR388228_SRR388229.KO.outTable_921089530.gz     NaN       NaN     NaN
# 4841  SRR388228_SRR388229.KO.outTable_921089530.gz     NaN       NaN     NaN
#
#      RMSK-Rep  RMSK-Reg RefSeq-Rep  RefSeq-Reg
# 845       NaN       NaN        NaN         NaN
# 1920      NaN       NaN        NaN         NaN
# 1921      NaN       NaN        NaN         NaN
# 4841      NaN       NaN        NaN         NaN
#
# [4 rows x 38 columns]
# Save on disk joined with annotation and filtering to : /lustre/bio_running/new_basecaller/REDINET_TEST_30_07_2024/REDInet/Package/Results/u87/SRR388226_SRR388227.WT.outTable_853538513.gz_vs_SRR388228_SRR388229.KO.outTable_921089530.gz.bonafide_final.tsv.anno.filt_refseq.tsv
