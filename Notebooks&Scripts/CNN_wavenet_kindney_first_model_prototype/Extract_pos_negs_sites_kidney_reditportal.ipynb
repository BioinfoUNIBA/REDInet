# %%
##################
### Author: Adriano Fonzino. email: adriano.fonzino@uniba.it Date: 11/2023
##################
import pandas as pd
import os
from glob import glob
import pysam
import gzip
from datetime import datetime

# %%
kidney_runs = ['SRR1071807',
 'SRR1080366',
 'SRR1085759',
 'SRR1089504',
 'SRR1105272',
 'SRR1314940',
 'SRR1317086',
 'SRR1325483',
 'SRR1328447',
 'SRR1329154',
 'SRR1340662',
 'SRR1362263',
 'SRR1377578',
 'SRR1380931',
 'SRR1420649',
 'SRR1432650',
 'SRR1435730',
 'SRR1437274',
 'SRR1442708',
 'SRR1445835',
 'SRR1447631',
 'SRR1452888',
 'SRR1456711',
 'SRR1465871',
 'SRR1468426',
 'SRR1469746',
 'SRR1490658',
 'SRR1500261',
 'SRR809943',
 'SRR810007',
 'SRR821356']
print(len(kidney_runs))
# Out:
# 31

# %%
sites_all = []
for SRR in kidney_runs:
    # deduce reditable filepath
    if len(glob( os.path.join('/lustre/biomed/epicardi/ncbi/dbGaP-6698/sra',SRR,SRR+'_dna.txt.gz'))) == 1:
        reditable = glob( os.path.join('/lustre/biomed/epicardi/ncbi/dbGaP-6698/sra',SRR,SRR+'_dna.txt.gz'))[0]
    else:
        continue
    start = datetime.now()
    print(f"\n######################\n[{datetime.now()}] Extracting SNPs and Editing sites for reditable:", reditable)
    # search snps and editing sites
    snps = []
    editing = []
    with gzip.open(reditable) as redi:
        for c,l in enumerate(redi):
            line = l.decode("utf-8").rstrip().split("\t")
            if line[2] == "A":
                if line[4] != "-" and line[9] != "-":
                    if int(line[4]) >= 50 and int(line[9]) >= 10:
                        if "AG" in line[7]:
                            if "AG" in line[12]:
                                AG_rna = eval(line[6])[2]/sum(eval(line[6]))
                                AG_wgs = eval(line[11])[2]/sum(eval(line[11]))
                                if AG_wgs >= 0.4:
                                    if (AG_rna / AG_wgs <= 1.05) and (AG_rna / AG_wgs >= 0.95):
                                        snps.append(line)
                            elif not "AG" in line[12]:
                                AG_rna = eval(line[6])[2]/sum(eval(line[6]))
                                if AG_rna >= 0.01:
                                    editing.append(line)
            if c % 50000000 == 0:
                print(f"\tSites evaluated: {c}")
    print("Total evaluated rows:", c)
    snps = pd.DataFrame(snps)
    editing = pd.DataFrame(editing)
    snps["type"] = "SNP"
    snps["sample"] = SRR
    editing["type"] = "Editing"
    editing["sample"] = SRR
    print("Total extracted SNPs for current sample:", snps.shape[0])
    print("Total extracted Editing sites for current sample:", editing.shape[0])
    stop = datetime.now()
    print(f"[{datetime.now()}] Extraction finished for current sample. Elapsed time: {stop-start}")
    # append to all
    sites_all.append(snps)
    sites_all.append(editing)
    # create an updated version of the global df
    df_sites_all = pd.concat(sites_all, ignore_index=True)
    # save an updated version of the global df to tsv on disk
    df_sites_all.to_csv("kidney_extracted_pos_neg_sites_rediportal_13112023.tsv", sep="\t")
print(f"[{datetime.now()}] Computation Finished")
# Out:
# ######################
# [2023-11-13 21:43:56.698037] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1071807/SRR1071807_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 179057199
# Total extracted SNPs for current sample: 692
# Total extracted Editing sites for current sample: 31808
# [2023-11-13 21:48:12.682736] Extraction finished for current sample. Elapsed time: 0:04:15.984692
#
# ######################
# [2023-11-13 21:48:12.820418] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1080366/SRR1080366_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# 	Sites evaluated: 250000000
# 	Sites evaluated: 300000000
# Total evaluated rows: 310399069
# Total extracted SNPs for current sample: 1145
# Total extracted Editing sites for current sample: 57823
# [2023-11-13 21:55:34.654539] Extraction finished for current sample. Elapsed time: 0:07:21.834120
#
# ######################
# [2023-11-13 21:55:35.015350] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1085759/SRR1085759_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 224741780
# Total extracted SNPs for current sample: 690
# Total extracted Editing sites for current sample: 25787
# [2023-11-13 22:00:54.392174] Extraction finished for current sample. Elapsed time: 0:05:19.376822
#
# ######################
# [2023-11-13 22:00:54.860737] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1089504/SRR1089504_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# 	Sites evaluated: 250000000
# 	Sites evaluated: 300000000
# Total evaluated rows: 325119991
# Total extracted SNPs for current sample: 1163
# Total extracted Editing sites for current sample: 59488
# [2023-11-13 22:08:36.066294] Extraction finished for current sample. Elapsed time: 0:07:41.205554
#
# ######################
# [2023-11-13 22:08:36.805332] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1105272/SRR1105272_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 185277979
# Total extracted SNPs for current sample: 874
# Total extracted Editing sites for current sample: 35458
# [2023-11-13 22:13:02.450718] Extraction finished for current sample. Elapsed time: 0:04:25.645383
#
# ######################
# [2023-11-13 22:13:03.337901] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1314940/SRR1314940_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# 	Sites evaluated: 250000000
# 	Sites evaluated: 300000000
# Total evaluated rows: 319428089
# Total extracted SNPs for current sample: 1419
# Total extracted Editing sites for current sample: 59229
# [2023-11-13 22:20:35.564964] Extraction finished for current sample. Elapsed time: 0:07:32.227062
#
# ######################
# [2023-11-13 22:20:36.677789] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1317086/SRR1317086_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# 	Sites evaluated: 250000000
# Total evaluated rows: 289387051
# Total extracted SNPs for current sample: 1083
# Total extracted Editing sites for current sample: 60512
# [2023-11-13 22:27:27.587782] Extraction finished for current sample. Elapsed time: 0:06:50.909990
#
# ######################
# [2023-11-13 22:27:28.985526] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1325483/SRR1325483_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 221869125
# Total extracted SNPs for current sample: 701
# Total extracted Editing sites for current sample: 41954
# [2023-11-13 22:32:44.622675] Extraction finished for current sample. Elapsed time: 0:05:15.637144
#
# ######################
# [2023-11-13 22:32:46.166604] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1328447/SRR1328447_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 227675304
# Total extracted SNPs for current sample: 800
# Total extracted Editing sites for current sample: 40234
# [2023-11-13 22:38:08.393626] Extraction finished for current sample. Elapsed time: 0:05:22.227019
#
# ######################
# [2023-11-13 22:38:10.088530] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1329154/SRR1329154_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 218365162
# Total extracted SNPs for current sample: 834
# Total extracted Editing sites for current sample: 49703
# [2023-11-13 22:43:21.355603] Extraction finished for current sample. Elapsed time: 0:05:11.267071
#
# ######################
# [2023-11-13 22:43:23.258885] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1340662/SRR1340662_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 229818272
# Total extracted SNPs for current sample: 862
# Total extracted Editing sites for current sample: 39955
# [2023-11-13 22:48:51.273635] Extraction finished for current sample. Elapsed time: 0:05:28.014747
#
# ######################
# [2023-11-13 22:48:53.420908] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1362263/SRR1362263_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 191792482
# Total extracted SNPs for current sample: 652
# Total extracted Editing sites for current sample: 33554
# [2023-11-13 22:53:26.078663] Extraction finished for current sample. Elapsed time: 0:04:32.657752
#
# ######################
# [2023-11-13 22:53:28.426876] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1377578/SRR1377578_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 213768441
# Total extracted SNPs for current sample: 696
# Total extracted Editing sites for current sample: 38701
# [2023-11-13 22:58:30.480947] Extraction finished for current sample. Elapsed time: 0:05:02.054066
#
# ######################
# [2023-11-13 22:58:32.850857] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1380931/SRR1380931_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 218936384
# Total extracted SNPs for current sample: 1090
# Total extracted Editing sites for current sample: 52715
# [2023-11-13 23:03:43.767431] Extraction finished for current sample. Elapsed time: 0:05:10.916571
#
# ######################
# [2023-11-13 23:03:46.340648] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1420649/SRR1420649_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 175355396
# Total extracted SNPs for current sample: 679
# Total extracted Editing sites for current sample: 23693
# [2023-11-13 23:07:50.576002] Extraction finished for current sample. Elapsed time: 0:04:04.235352
#
# ######################
# [2023-11-13 23:07:53.258313] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1432650/SRR1432650_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# 	Sites evaluated: 250000000
# Total evaluated rows: 270258419
# Total extracted SNPs for current sample: 1495
# Total extracted Editing sites for current sample: 62639
# [2023-11-13 23:14:15.234513] Extraction finished for current sample. Elapsed time: 0:06:21.976197
#
# ######################
# [2023-11-13 23:14:18.170802] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1435730/SRR1435730_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 248315672
# Total extracted SNPs for current sample: 1038
# Total extracted Editing sites for current sample: 48704
# [2023-11-13 23:20:07.765269] Extraction finished for current sample. Elapsed time: 0:05:49.594467
#
# ######################
# [2023-11-13 23:20:10.928550] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1437274/SRR1437274_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# Total evaluated rows: 64372448
# Total extracted SNPs for current sample: 160
# Total extracted Editing sites for current sample: 7406
# [2023-11-13 23:21:40.653063] Extraction finished for current sample. Elapsed time: 0:01:29.724510
#
# ######################
# [2023-11-13 23:21:43.829443] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1442708/SRR1442708_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 156383536
# Total extracted SNPs for current sample: 378
# Total extracted Editing sites for current sample: 20522
# [2023-11-13 23:25:21.689525] Extraction finished for current sample. Elapsed time: 0:03:37.860078
#
# ######################
# [2023-11-13 23:25:25.116657] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1445835/SRR1445835_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 243310851
# Total extracted SNPs for current sample: 841
# Total extracted Editing sites for current sample: 46234
# [2023-11-13 23:31:10.168250] Extraction finished for current sample. Elapsed time: 0:05:45.051591
#
# ######################
# [2023-11-13 23:31:13.644877] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1447631/SRR1447631_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 209922560
# Total extracted SNPs for current sample: 959
# Total extracted Editing sites for current sample: 45199
# [2023-11-13 23:36:11.188469] Extraction finished for current sample. Elapsed time: 0:04:57.543588
#
# ######################
# [2023-11-13 23:36:14.861008] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1452888/SRR1452888_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 239258694
# Total extracted SNPs for current sample: 1003
# Total extracted Editing sites for current sample: 45369
# [2023-11-13 23:41:55.549401] Extraction finished for current sample. Elapsed time: 0:05:40.688391
#
# ######################
# [2023-11-13 23:41:59.461984] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1456711/SRR1456711_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 209535737
# Total extracted SNPs for current sample: 688
# Total extracted Editing sites for current sample: 39961
# [2023-11-13 23:46:51.861083] Extraction finished for current sample. Elapsed time: 0:04:52.399097
#
# ######################
# [2023-11-13 23:46:55.828341] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1465871/SRR1465871_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 226298464
# Total extracted SNPs for current sample: 1013
# Total extracted Editing sites for current sample: 59336
# [2023-11-13 23:52:13.934746] Extraction finished for current sample. Elapsed time: 0:05:18.106403
#
# ######################
# [2023-11-13 23:52:18.127620] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1468426/SRR1468426_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 232482360
# Total extracted SNPs for current sample: 788
# Total extracted Editing sites for current sample: 38754
# [2023-11-13 23:57:41.411705] Extraction finished for current sample. Elapsed time: 0:05:23.284082
#
# ######################
# [2023-11-13 23:57:45.825117] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1469746/SRR1469746_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# 	Sites evaluated: 250000000
# Total evaluated rows: 287293747
# Total extracted SNPs for current sample: 1092
# Total extracted Editing sites for current sample: 53576
# [2023-11-14 00:04:26.647090] Extraction finished for current sample. Elapsed time: 0:06:40.821974
#
# ######################
# [2023-11-14 00:04:31.319833] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1490658/SRR1490658_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 180584616
# Total extracted SNPs for current sample: 645
# Total extracted Editing sites for current sample: 29158
# [2023-11-14 00:08:40.673990] Extraction finished for current sample. Elapsed time: 0:04:09.354155
#
# ######################
# [2023-11-14 00:08:45.418962] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR1500261/SRR1500261_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 184204135
# Total extracted SNPs for current sample: 924
# Total extracted Editing sites for current sample: 35076
# [2023-11-14 00:13:00.890195] Extraction finished for current sample. Elapsed time: 0:04:15.471233
#
# ######################
# [2023-11-14 00:13:05.864678] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR809943/SRR809943_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# Total evaluated rows: 96602194
# Total extracted SNPs for current sample: 587
# Total extracted Editing sites for current sample: 21405
# [2023-11-14 00:15:21.795948] Extraction finished for current sample. Elapsed time: 0:02:15.931267
#
# ######################
# [2023-11-14 00:15:26.695085] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR810007/SRR810007_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# 	Sites evaluated: 200000000
# Total evaluated rows: 248167814
# Total extracted SNPs for current sample: 1306
# Total extracted Editing sites for current sample: 50821
# [2023-11-14 00:21:13.841649] Extraction finished for current sample. Elapsed time: 0:05:47.146562
#
# ######################
# [2023-11-14 00:21:18.982741] Extracting SNPs and Editing sites for reditable: /lustre/biomed/epicardi/ncbi/dbGaP-6698/sra/SRR821356/SRR821356_dna.txt.gz
# 	Sites evaluated: 0
# 	Sites evaluated: 50000000
# 	Sites evaluated: 100000000
# 	Sites evaluated: 150000000
# Total evaluated rows: 197481531
# Total extracted SNPs for current sample: 567
# Total extracted Editing sites for current sample: 25113
# [2023-11-14 00:25:53.261665] Extraction finished for current sample. Elapsed time: 0:04:34.278924
# [2023-11-14 00:25:58.564820] Computation Finished
